# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Statistician%22&l=San+Francisco%2C+CA&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 329

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 329

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 28

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                       Title  \
# 0   Data Scientist
# 1   Senior Medical Director, Global Clinical Development
# 2   Director, Biostatistics
# 3   Statistical Scientist- Clinical Development and Personalized Healthcare
# 4   Research Associate - SURU
# 5   Master's Program Coordinator -
# 6   Data Science Engagement Manager Analytic Manager 4
# 7   Senior Manager, Data Scientist
# 8   Sr Investor Analytics Analyst
# 9   Statistician
# 10  Statistician
# 11  Statistician
# 12  Senior Biostatistician II
# 13  Senior Team Manager, Data Scientist
# 14  (Sr) Principal Statistical Scientist
# 15  Research Data Analyst
# 16  Statistical Data Analyst
# 17  Senior Data Scientist - Trust and Safety
# 18  Statistician / Study Coordinator
# 19  Principal Biostatistician
# 20  Medical Director, Global Clinical Development
# 21  Principal Statistician / Associate Director, Early Oncology Statistics
# 22  Senior Platform Engineer
# 23  Data Scientist Technical Lead, YouTube Music
# 24  Sr. Data Scientist - Developer & Studio Ecosystems
# 25  Bioinformatician/Statistician
# 26  Research Statistician - HEOR
# 27  Senior/Principal-Data Science
#
#                          Location                 City State         Zip  \
# 0   San Francisco, CA              San Francisco        CA    None Found
# 1   Novato, CA 94949               Novato               CA    94949
# 2   Novato, CA 94949               Novato               CA    94949
# 3   South San Francisco, CA 94083  South San Francisco  CA    94083
# 4   San Francisco, CA              San Francisco        CA    None Found
# 5   Berkeley, CA                   Berkeley             CA    None Found
# 6   San Francisco, CA              San Francisco        CA    None Found
# 7   San Francisco, CA              San Francisco        CA    None Found
# 8   San Francisco, CA              San Francisco        CA    None Found
# 9   San Francisco, CA              San Francisco        CA    None Found
# 10  Oakland, CA 94612              Oakland              CA    94612
# 11  San Francisco, CA              San Francisco        CA    None Found
# 12  San Francisco, CA              San Francisco        CA    None Found
# 13  San Francisco, CA              San Francisco        CA    None Found
# 14  South San Francisco, CA 94083  South San Francisco  CA    94083
# 15  San Francisco, CA              San Francisco        CA    None Found
# 16  Brisbane, CA 94005             Brisbane             CA    94005
# 17  San Mateo, CA                  San Mateo            CA    None Found
# 18  San Francisco, CA              San Francisco        CA    None Found
# 19  San Francisco, CA              San Francisco        CA    None Found
# 20  Novato, CA 94949               Novato               CA    94949
# 21  Redwood City, CA               Redwood City         CA    None Found
# 22  San Francisco, CA              San Francisco        CA    None Found
# 23  San Bruno, CA                  San Bruno            CA    None Found
# 24  San Mateo, CA                  San Mateo            CA    None Found
# 25  San Francisco, CA 94110        San Francisco        CA    94110
# 26  Oakland, CA                    Oakland              CA    None Found
# 27  San Francisco, CA              San Francisco        CA    None Found
#
#        Country  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  None Found
# 17  None Found
# 18  None Found
# 19  None Found
# 20  None Found
# 21  None Found
# 22  None Found
# 23  None Found
# 24  None Found
# 25  None Found
# 26  None Found
# 27  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Qualifications  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   \nBA/BS in related field, or a combination of relevant experience and education\nExperience and comfort working in a medical setting and with medical providers\nProficient computer and data entry skills including Excel, Access, and PowerPoint\nHigh level of attention to detail and ability to handle a variety of tasks with a high degree of accuracy\nAbility to work both in a team and independently\nKnowledge of and sensitivity to diverse communities, particularly communities of color and gay/lesbian/bisexual/transgender community\n
# 5   None Found
# 6   \n8+ years of experience in one or a combination of the following: reporting, analytics, or modeling\n4+ years of management experience\n2+ years of statistical modeling experience
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  MS or PhD degree in Statistics, Bioinformatics, Biomedical Informatics, Computer Science, Biomedical Engineering, Life Sciences or related fields. At least two years of coursework in undergraduate or graduate-level statistics, or two years of work experience working in a primarily statistical role is required for this position.\nExperience using R, SAS and other statistical software packages\nExperience in analysis of high-throughput next-generation sequencing and gene expression data (e.g. microarrays, RNA-Seq, etc.) preferred\nStrong interpersonal skills and high communication proficiency both verbal and written, in technical and non-technical domains\nSolid problem-solving skills\nStrong presentation skills\nAbility to manage multiple tasks in a fast-paced environment\nAbility to work independently and as a contributing team member\nFlexibility to work on development, clinical or non-clinical projects depending upon company needs\n
# 17  None Found
# 18  None Found
# 19  None Found
# 20  None Found
# 21  None Found
# 22  None Found
# 23  None Found
# 24  None Found
# 25  M.S in Computational Biology, Bioinformatics or related field and 2+ years working experience.\nPhD with experience in Bioinformatics/Statistics (or similar quantitative fields) preferred. At least one year of experience with analysis of sequence data, large biological datasets using R, Python, Perl or equivalent is required. Statistical genetics experience or experience incorporating various biological data types is strongly preferred.\nPrior consulting or industrial experience supporting research is a plus.\nThe successful candidate will have a strong background in computational science, statistical analysis, experimental design, and quantitative analysis of biological systems, as well as a demonstrated ability to communicate and work effectively with all types and levels of internal and external collaborators.
# 26  None Found
# 27  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Skills  \
# 0   None Found
# 1   \nMD degree or MD, PhD degrees, graduating from a high quality medical school.\nMinimum of 4 years of industry experience (rare disease experience preferred but not required)\nTranslational research and early development experience (preferred but not required)\nMust be originally boarded in a medical specialty; optimally in medical genetics, pediatric or adult neurology or other complex clinical fields dealing with chronic diseases and complex pathophysiology, or relevant experience.\nMust be trained in GCP regulations, and be familiar with relevant ICH and FDA guidelines relevant to clinical development. Must have experience designing successful clinical studies in complex diseases requiring the management of patient variation, chronic irreversible disease and related complexities. Must be facile with statistical issues and be able to manage working with a statistician to design the analysis of clinical studies\nExperience across all phases of clinical studies required, understanding and/or experience with post-approval commitments is an advantage\nAbility to write clinical study reports and summaries for regulatory purposes
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# ...
# 25  Responsibilities\nJoin a vibrant team of bioinformaticians and biostatisticians working on diverse biomedical projects.\n\nGladstone Bioinformatics as part of the Institute of Data Science and Biotechnology hosts a convergence zone of cutting edge research, omics analytics, biostatistics and technology development, and is one of the primary centers for the National Resource for Network Biology, an NIH-sponsored resource for broadly distributed network biology software and methods.\n\nWe are seeking a talented Bioinformatician or Statistician at either junior or senior levels to join the dynamic bioinformatics team here at Gladstone Institutes. You will be providing bioinformatics and computational support to the world-class biomedical research conducted in labs at Gladstone Institutes, UCSF, and beyond. Working closely with experimental scientists, you will lead end-to-end studies from hypotheses and experimental design, to analysis plans, implementation and pipelining, to methods assessment and result reporting or publication. You will be working with a variety of data types generated by various platforms and technologies (eg, genome sequencing, bulk RNA-seq, single cell analysis, ChIP-seq, ATAC-seq, metagenomics, CRISPR screens, mass spectrometry, and others). Expertise and knowledge of state of the art sequencing tools/platforms, analysis methods and annotation methods is required. You will have opportunities for teaching, authorship, methods development, grant applications, and further training to develop your expertise and skill sets.\nQualifications\nM.S in Computational Biology, Bioinformatics or related field and 2+ years working experience.\nPhD with experience in Bioinformatics/Statistics (or similar quantitative fields) preferred. At least one year of experience with analysis of sequence data, large biological datasets using R, Python, Perl or equivalent is required. Statistical genetics experience or experience incorporating various biological data types is strongly preferred.\nPrior consulting or industrial experience supporting research is a plus.\nThe successful candidate will have a strong background in computational science, statistical analysis, experimental design, and quantitative analysis of biological systems, as well as a demonstrated ability to communicate and work effectively with all types and levels of internal and external collaborators.\n\nTitle and salary will be commensuarate with education and experience.\nAbout Gladstone\nThe Gladstone Institutes is an independent, not-for-profit research organization affiliated with the University of California San Francisco (UCSF), contributing to the health and well being of all people through medical research, education, and outreach in the areas of heart disease, HIV/AIDS, and neurological disease. Gladstone Bioinformatics as part of the Institute of Data Science and Biotechnology hosts a convergence zone of cutting edge research, omics analytics, biostatistics and technology development, and is one of the primary centers for the National Resource for Network Biology, an NIH-sponsored resource for broadly distributed network biology software and methods. We are located in an award winning building adjacent to UCSF's vibrant and active Mission Bay Campus. In addition to daily seminars and learning opportunities, our campus includes a gym, farmer’s market, advanced medical facilities, biotechnology corridor, food truck court, etc.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 26  Precision Xtract is an award-winning global healthcare market access consultancy within Precision Medicine Group. We provide our clients with unified health economics and outcomes research, global pricing, access strategy and analytics, payer and physician pull-through, and data management.\n\nWe provide powerful research skills to positively impact payer and purchaser decision-making, which allows organizations to assess appropriate populations for therapies and potential expand access for life-saving and altering medical interventions.\n\nWith offices in New York, Boston, Oakland, Vancouver and London, our team has experienced rapid growth and includes a collection of professionals from around the globe with experience across multiple disciplines: former payer executives, academics, pharma marketers, and consultants—all passionate about generating solutions to our customers’ value and access needs.\n\nWe are looking for dedicated Research Statisticians who enjoy a challenge, thrive in the details and flourish in dynamic environments.\n\nDo you consider yourself a highly organized, self starter with a real passion for projects involving innovative health economic concepts? Are you passionate about putting in the hard work to conduct high quality research? Are you a clear and confident communicator among both internal teams and in front of clients? Your dream job is waiting. If you’re a born problem-solver and enjoy when no day is the same - keep reading.\n\nWhat you can expect day-to-day:\nAs Research Statistician, you will perform a wide range of activities including: literature reviews; analysis; preparing reports, slide decks and meeting notes; and quality assurance/review. You will independently complete, evidence synthesis projects, including: client management; systematic literature review (SLR); (network) meta-analysis; economic modeling; and dissemination of results.\n\nEssential duties but are not limited to:\nAssociate Research Statistician\n\nConducting meta-analyses and network meta-analyses using R and OpenBUGS/JAGS\nUsing R and/or SAS conduct statistical analyses to support projects, including:\nEvidence synthesis methods (meta-analyses, summary statistics)\nBayesian statistical modeling methods\nStatistical modeling (logistic, ordinal, ordinary least squares, instrumental variable regressions, etc.)\nTime-to-event (survival/mortality) or repeated measures analyses\nSimulation methods (Markov-models, Monte Carlo, bootstrapping, etc.)\nDraft interim and final project deliverables for clients\nClearly interpret and communicate complex quantitative results to internal and external audiences\nContribute to technical reports, health technology submissions, and peer-reviewed manuscripts\nEnsure the quality of model programming and the robustness of model assumptions\nResearch Statistician\n\nDevelops client-ready deliverables in terms of protocols (SLR of cost-effectiveness modeling), statistical analysis plans (evidence synthesis), technical reports, and slides, identifying necessary deviations from templates to ensure content aligns with objectives\nDevelops content for components of proposals in collaboration with senior team members in terms of proposed methods and scope of work\nAccountable for timely delivery and financial performance of project subcomponents; estimates required hours and identifies challenges early on; and communicates any changes and possible solutions to project lead if necessary\nDrafts and reviews update slides/minutes and actions for overall study and viewed by client as independent researcher for specific study component(s)\nCommunicates with client frequently on calls and supports project lead in responding to emails; may also be involved in face-to-face presentations to clients\nBreaks down complex project tasks or project subcomponents into manageable components and approaches them in logical and clear manner\nHighlights resourcing constraints for project subcomponents to project o ...
# 27  --------------------------------------------\nPosition: Senior/Principal-Data Science\n--------------------------------------------\n\n***********\n\nWho we are:\n***********\n\nOur Company was founded on the idea that there are patterns in people's behavior that, with the right logic, can be used to predict future outcomes. We are a small but rapidly growing organization that works in partnership with our customers to create solutions that are simply not found anywhere else. We work in groups rather than in structured corporate hierarchies; our culture is creative and entrepreneurial where everyone contributes to company goals in very real way. We are a hardworking group, but we have a lot of fun with what we do and are looking for new people with a similar mindset to join the organization.\n\n***********\n\nWhat we do:\n***********\n\nOur proprietary software-as-a-service helps automotive dealerships and sales teams better understand and predict exactly which customers are ready to buy, the reasons why, and the key offers and incentives most likely to close the sale. Its micro-marketing engine then delivers the right message at the right time to those customers, ensuring higher conversion rates and a stronger ROI.\n\n*****************\n\nWhat you will do:\n*****************\n\n\nWe are looking for talented individuals to join our team in building the analytical components of our software that at heart of it uses data analytics and machine learning\nYou will apply machine learning techniques and statistical methods to build core components to the software along with data engineers and software engineers.\nYou are passionate about automating everything and applying scientific methods to solve business and engineering requirements\nYou will perform analyses on large sets of data to extract actionable insights that will help drive decisions across the business\nCommunicate data-driven insights and recommendations to key stakeholders\nYou will work closely with product owners, designers, data engineers, marketing teams and others across the company\nYou will work on challenging projects using cutting-edge technologies\nThis position will bring analytical rigor and statistical methods to the challenges of measuring quality, improving products, and understanding the behavior of end-users\nYou will be the subject matter expert and propose new ideas\n\n******************\n\nWho you are:\n******************\n\n\nMS or PhD in a quantitative discipline (e.g., statistics, operations research, computer science, mathematics, physics, electrical engineering, industrial engineering)\n4/5+ years of industry experience with a Phd or 8+ years of industry work experience with a master's (e.g., as a lead statistician / sr. data scientist / sr. machine learning engineer)\nExperience presenting insights to executives and non-technical audiences around product analytics results into business recommendations\nApplied experience with data analysis and machine learning (such as logistic regression, random forest, gradient boosting, clustering, neural networks) on large datasets\nYou have the technical competence to perform advanced analytics:\nCoding skills such as Python and SQL\nApache Spark platform (including Dataset, SparkML)\nExperience designing and implementing machine learning pipelines in production environments\nExperience with deep learning methods such as RNN, LSTMs a plus\nDemonstrated willingness to both teach others and learn new techniques\nYou are able to work independently but have great collaboration skills\nYou believe in what you do and feel a vested interest in company's success\n\n***********************\n\nExpected Hours of Work:\n***********************\n\nThis is a full-time position. Generally, work is performed Monday through Friday, though holidays and weekends may be required.\n\n*********************************************\n\nWe believe in equal employment opportunities:\n******************************************** ...

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Statistician_SF.csv')
