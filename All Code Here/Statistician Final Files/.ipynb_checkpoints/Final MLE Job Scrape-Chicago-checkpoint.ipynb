# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Statistician%22&l=Chicago%2C+IL&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 322

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 322

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 20

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                               Title  \
# 0   Senior Statistician
# 1   Supervisory Survey Statistician, GG-1530-13, Census-MP-KML
# 2   Senior Statistician
# 3   Research Analyst
# 4   Quality Assurance Monitor
# 5   Data Analyst
# 6   Statistician
# 7   Supervisory Survey Statistician, GG-1530-13,Census-DE-KML
# 8   Research Statistical Analyst
# 9   Director Safety Science Statistics
# 10  Embedded Analyst
# 11  Lead Machine Learning Analyst
# 12  Associate Biostatistics Director
# 13  Senior Manager Central Monitoring
# 14  Consulting Statistician, Manager – US Research & Insights, Deloitte Services LP
# 15  Data Analyst, Trauma Programs
# 16  Senior Survey Statistician
# 17  Survey Statistician, GG-1530-07/09/11/12, Census-MP-KML
# 18  Athletics Event Operations Staff - Game Administration (Pool)
# 19  Sr. Manager, Health Economics and Outcomes Research
#
#                 Location        City State         Zip     Country  \
# 0   Chicago, IL           Chicago     IL    None Found  None Found
# 1   Chicago, IL           Chicago     IL    None Found  None Found
# 2   Chicago, IL           Chicago     IL    None Found  None Found
# 3   Chicago, IL           Chicago     IL    None Found  None Found
# 4   Chicago, IL           Chicago     IL    None Found  None Found
# 5   Chicago, IL           Chicago     IL    None Found  None Found
# 6   Chicago, IL           Chicago     IL    None Found  None Found
# 7   Chicago, IL           Chicago     IL    None Found  None Found
# 8   Chicago, IL           Chicago     IL    None Found  None Found
# 9   Northbrook, IL 60062  Northbrook  IL    60062       None Found
# 10  Chicago, IL           Chicago     IL    None Found  None Found
# 11  Chicago, IL           Chicago     IL    None Found  None Found
# 12  Northbrook, IL 60062  Northbrook  IL    60062       None Found
# 13  Northbrook, IL 60062  Northbrook  IL    60062       None Found
# 14  Chicago, IL 60606     Chicago     IL    60606       None Found
# 15  Chicago, IL 60611     Chicago     IL    60611       None Found
# 16  Chicago, IL           Chicago     IL    None Found  None Found
# 17  Chicago, IL           Chicago     IL    None Found  None Found
# 18  Chicago, IL           Chicago     IL    None Found  None Found
# 19  Deerfield, IL 60015   Deerfield   IL    60015       None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Qualifications  \
# 0   None Found
# 1   \n30% or more disabled\nPersons with Disabilities\nCTAP\nICTAP\n
# 2   \nSuccessful completion of a full 4-year course of study in an accredited college or university leading to a bachelor's or higher degree; OR appropriate combination of education and experience.\n6 years' data analysis/report writing or similar experience.\nExperience with SAS programming language.\nAnalytical skills including critical thinking, data mining, data modeling data warehouse design/develop, database design/ data structure.\nProject Code documentation collaboration and teamwork, cost/benefit analysis, evaluate resources, organizational skills, planning workflow development & documentation.
# 3   None Found
# 4   \nBachelor’s degree in an allied medical profession or other health sciences field or the equivalent combination of education and experience from which comparable skills can be acquired.\nStrong regulatory background as demonstrated by knowledge of the Code of Federal Regulations and Good Clinical Practice guidelines.\n3-5 years prior experience coordinating or monitoring therapeutic clinical trials.\nExperience with data completion or familiarity with data form completion guidelines.\nExperience in staff education and training activities.
# 5   Bachelors degre in social or behavioral sciences, physical science, education, nursing or related health field is required. Master’s degree preferred.\n1-2 years of experience working in a research setting preferred.\nStrong analytical, computational and organizational skills with consistent attention to detail. Strong customer service skills.\nStrong verbal and written communication skills in order to address diverse/large audiences.\nDemonstrated working knowledge of regulatory practices required.\nProficient in Microsoft Word and PowerPoint, with advanced skills in Excel (or similar) for data curation, analysis and basic visualization.\nKnolwedge of / experience with collecting and manipulating data in REDCap and/or orther data capture software.\nExperience with database or statistical tools such as SQL, R, SASS or SPSS preferred.
# 6   None Found
# 7   \nAbility to lead, communicate and motivate a team; complete a project under a tight deadline; provide administrative and technical guidance to a team to accomplish goals.\nAbility to use survey methods such as survey research and data collection in order to develop, monitor reports and analyze surveys.\nSkill in identification and assessment impacts associated with the interpretation of results generated, and the need for procedural or operations changes.\nKnowledge of qualitative and/or quantitative measurement techniques.\nSkill in research, development and implementation of programming specifications which includes monitoring program design, coding, and pilot testing program developed for commercial statistical software packages to work with existing programs or systems.\nAbility to manage, assign work, set priorities, prepares schedules, evaluate performance and provide advice, instructions, and training for subordinate staff.\n
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  \nM.S. or Ph.D. in statistics or equivalent\nMinimum of 8 years' experience in applying statistical methods in biomedical research, extensive pharmaceutical or CRO experience required\nExperience in working on clinical project teams. Good understanding of entire drug development process - ability to see the "big picture".\nExperience as the independent lead statistician in a regulatory submission preferred\nExperience with cross functional process improvement or innovation initiatives\nAdvanced and broad knowledge of statistical methods, along with understanding of industry practices related to the statistical analysis of clinical data\nKnowledge and skills in SAS required and knowledge of other statistical software preferred.\nIn-depth familiarity with processes and procedures in data management and SAS programming\nExperience working in an international environment and demonstrated ability to manage and influence across different locations, time zones and cultures; builds global relationships.\nAbility to work in a matrix environment.\nProven excellent organizational, project and time management skills.\nLeadership skills and ability to delegate appropriately and provide direction to more junior Biostatisticians.\nVery good oral, written, and presentation communication skills. Able to clearly communicate statistical issues and methods to both statisticians and non-statisticians.\nVery good problem solving skills.\nAccurate with a keen eye for detail. Dedication to quality and reliability in all work tasks\nAbility to perform under pressure\n
# 13  \nBS/BA degree in a biological science, statistics, health-related or computer science field. Advanced degree preferred.\nGenerally, 7 plus years related experience in pharmaceutical, clinical research or health services industry with a minimum of 5 years' experience as clinical study manager, data manager or biostatistician, with progressive levels of responsibility.\nDemonstrated data analytical and/or site monitoring skills in multiple development programs, inclusive of all activities from program inception to regulatory submission.\nExperience in multiple Therapeutic Areas or disease state/indications desired.\nRegulatory submission experience.\nProven excellent leadership and subject matter expertise for key process improvement initiatives.\nActive contribution to inspections and major (vendor) audits.\nProven skills in outsourced vendor oversight.\nStrong cross-functional understanding of processes of clinical study management, data management, clinical programming, and biostatistics with senior level expertise expected in at least one of those disciplines.\nStrong computer skills, including database management software, data analysis &reporting tools, project management tools, etc.\nExcellent verbal & written communication and critical thinking skills.\nProven ability to work with and influence individuals across multiple functions and disciplines.\n
# 14  PhD in statistics or one of the quantitative social sciences\n5+ years of experience doing hands-on, statistics-intensive work\nSolid experience working in a consulting statistician capacity: ideating with clients, manifesting good communication skills, balancing multiple projects\nBroad, solid knowledge of statistics with depth in one or more areas such as survey design/analysis, econometrics, or causal inference\nFlair for Exploratory Data Analysis\nKnowledge of core machine learning methods\nAbility and eagerness to keep abreast of data-intensive developments in such fields as text analysis, social network analysis, Computational Social Science\n\nTo apply\nApply with a letter explaining why you are interested in this role and expanding upon your qualifications. Please include a full CV and two writing samples, ideally sole- or first-authored. One sample should be shorter (i.e., <1000 words) and one longer (i.e., >2000 words).
# 15  None Found
# 16  None Found
# 17  \nVRA\n30% or more disabled\nPersons with Disabilities\nCTAP\nICTAP\n
# 18  None Found
# 19  None Found
#
#                                                                                                                                                                                        Skills  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   \nComputer literate in Microsoft Office, Internet, and database use.\nAbility to establish and maintain effective working relationships with physicians, affiliate centers and coworkers.
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  None Found
# 17  None Found
# 18  None Found
# 19  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Responsibilities  \
# 0   None Found
# 1   Develop, monitor, report and analyze progress weekly and monthly on a variety of administrative and data collection programs.\nPlan, develop, design, and implement new ways to report progress on the completion of administrative and data collection programs in the Regional Census Center.\nDesign, conduct, and analyze surveys. Supervise and manage a team involved in data collection.\nAnalyze, review, monitor, evaluate and interpret survey methods, designing, conducting, and analyzing surveys.\nSupervise and administer the work of subordinates or team assigned to a survey or administrative program.\n
# ...
# 16  At Fors Marsh Group (FMG), we combine the power of science and strategy to improve people's lives. Each day, we work with institutions and organizations that seek to disrupt markets, understand or influence behavior, drive action on a national or global scale, and create a positive impact on the world. FMG was created with the vision of becoming a refreshingly different type of research and consulting firm by solving challenges through solutions steeped in scientific theory, methodological rigor, and creativity. This vision has shaped core capabilities led by experts in their field, which include health communications, human capital management, digital marketing and design and data science.\nAs a Certified B Corporation and 2018 AMA Top 50 Market Research Company, FMG's positive impact extends far beyond our client portfolio. FMG makes a difference in the community through pro bono service to nonprofits that are aligned with FMG's corporate values.\nFors Marsh Group (FMG) actively fosters a diverse and culturally inclusive corporate environment. FMG understands that diversity inspires innovation and attracts valued talent. FMG is an equal opportunity employer and interviews and hires without regard to race, color, religion, sex, sexual orientation, gender identity, national origin, disability or veteran status. If you have a disability or special need that requires accommodation, please let us know.\nFMG is seeking an experienced and motivated Senior Survey Statistician to work as part of a team primarily focused on research methods and data analysis. This individual's primary responsibility will be to provide methodological and statistical expertise for surveys designed and executed specifically for our clients.\n\nLocation: Arlington, VA OR Chicago, IL\nResponsibilities include:\nDesigning and executing sampling and weighting plans for various probability and non-probability survey efforts ranging from large national surveys to smaller survey efforts targeting specific populations.\nApplying sophisticated principles in the fields of survey methodology, sampling, survey statistics, and/or other social science disciplines to design, conduct, and analyze complex national surveys.\nPlanning and designing survey administrations to optimize cost, estimate precision, and minimize respondent burden.\nPreparing technical reports, presentations, and executive summaries.\nAdvancing the reputation of our organization through participation at professional conferences, publication of research studies, and continued technical training.\nParticipating in project meetings and assisting project managers with development of research projects.\nServing as a technical lead on research projects with a strong survey methods focus.\nAnalyzing and presenting results for survey data.\nQualifications:\nU.S Citizenship\nKnowledge and experience with sampling, weighting, non-response analysis/adjustments, missing data techniques, questionnaire design, and assessing/minimizing survey bias, variance and error.\nBachelor's degree in survey research, statistics, social sciences or a related field with emphasis on Survey Methodology required (Graduate degree preferred).\nAbility to work effectively as a team leader, team member, or independently.\nExperience with statistical software packages (e.g., SPSS/Stata) and Microsoft Office computer software applications.\nExcellent oral and written communication skills.\nApplicants may be subject to a low-level government security investigation and must meet eligibility criteria for access to sensitive information.\nWe Offer:\nHighly competitive benefit/compensation package\nA highly collegial and intellectually stimulating work environment\nA company culture promoting work/life balance\nvBGcgXtnxS                                                                                                                                                                                                                           ...
# 17  Duties\nSummary\nThe primary mission is a variety of administrative programs and data collection activities, and short range planning and special projects.\n\nThis vacancy is for a Survey Statistician position in the Chicago Regional Census Center duty stationed in Chicago, IL.\n\nResponsibilities\nThe individual selected for this position will:\n\nUse survey methods in order to design, conduct and analyze surveys using statistical software packages.\nAssist with planning work schedules, assignments and communication strategies are utilized to ensure team performances and cost efficiencies.\nAssist with communicate progress of data collection operations to management and other staff.\nAssist with the analysis, review and interpretation of survey data and present the data to others outside the unit or organization\nTravel Required\nOccasional travel - Traveling Occasionally\nSupervisory status\nNo\nPromotion Potential\n12\nJob family (Series)\n1530 Statistics\nSimilar jobs\nStatisticians\nStatisticians, Survey\nSurvey Statisticians\nRequirements\n\nRequirements\nConditions of Employment\nU.S. citizen.\nSuitable for Federal employment.\nRegistered for Selective Service, if applicable. (www.sss.gov)\nYou may be required to complete a financial disclosure (OGE-450).\nTime-in-grade requirements must be met by the announcement closing date.\nApplicants must meet all qualification requirements by the closing date of this announcement.\n\nThis vacancy is advertised under 2 different announcements. Please read the 'Who May Apply' section carefully to determine your eligibility. If you are not eligible under this announcement, please see CHICAGO RO-2020-0001, Survey Statistician, GG-1530-07/09/11/12, CENSUS-DE-KML.\n\nThis is a Temporary Appointment, initial appointment is not to exceed (NTE) 09/26/2020. This appointment may be extended an additional year at management's discretion.\n\nA probationary period may be required.\n\nRelocation expenses may be paid.\n\nThe work schedule for this position is Mixed Tour. With a Mixed Tour work schedule, an employee may be changed between full-time, part-time and intermittent work schedules to accommodate fluctuating workloads and is subject to a signed agreement.\n\nQualifications\nMINIMUM QUALIFICATION REQUIREMENTS:\n\nBasic Entry Requirements for All Grade Levels:\n\nA. Degree: that included 15 semester hours in statistics (or in mathematics and statistics, provided at least 6 semester hours were in statistics), and 9 additional semester hours in one or more of the following: physical or biological sciences, medicine, education, or engineering; or in the social sciences including demography, history, economics, social welfare, geography, international relations, social or cultural anthropology, health sociology, political science, public administration, psychology, etc. Credit toward meeting statistical course requirements will be granted for courses in which 50 percent of the course content appears to be statistical methods, e.g., courses that included studies in research methods in psychology or economics such as tests and measurements or business cycles, or courses in methods of processing mass statistical data such as tabulating methods or electronic data processing.\n\nIf you do not submit sufficient academic documentation necessary to demonstrate that you meet the eligibility and minimum qualification requirements described in this announcement, your application will be deemed incomplete and you will be ineligible for further consideration for this vacancy.\n\nOR\n\nB. Combination of education and experience - courses shown in A above, plus appropriate experience or additional education. The experience should have included a full range of professional statistical work such as (a) sampling, b) collection, computing and analyzing data, and c) applying statistical techniques such as measurements of central tendency, dispersion, skewness, sampling error, simple and multiple correlation,  ...
# 18  Job Summary Work closely with the Assistant Athletic Director for Operations.\nAssist with the overall game day operation of the following varsity sports; volleyball, basketball, baseball, track and field, golf,\nand tennis.\nEvent staff employees are responsible for all other duties assigned in addition to their specific job description.\nEvent staff employees are required to properly setup and breakdown for an athletic event.\nEvent staff employees are required to attend brief and debrief meetings before and following the event to obtain more information\nnecessary to job performance.\nEvent staff employees are required to be knowledgeable of conference and NCAA rules and regulations for the respective sport\nevent.\nMust have the ability to perform duties outdoors in various weather conditions such as, rain, cold/hot days if necessary.\nComplete game duties, promotions and projects as assigned by Administrators.\nHours include days, nights and weekend and possibly holidays.\nWillingness to represent Chicago State University, and our mission and core values, in a positive manner on and off campus.\nJob Description\nScoreboard Operator\nOperate the required equipment to control the scoreboard\nPrepare scorer’s table area for use before the start of assigned games Setup and breakdown of facility\nAssist coaches, officials, and other staff as needed\nScorekeeper\nObtain team roster from coach or a representative prior to ten minutes before the start of the match\nKeep written record of games in the scorebook and/or insure that scoreboard is accurate during games\nAssist coaches, officials, and other staff as needed\nGreeting patrons in the arena area and the front lobby.\nStatistician\nMaintains scores and records for each competitionCompiles statistics for each gameRecords and/or posts individual and team statistics in accordance with official rules and requirements\nLibero Tracker\nTracks the libero position during a volleyball match\nLine Judge\nAssist the game officials during a volleyball match\nMinimum Qualifications\nMinimum Qualifications\nCollege Degree and an interest to work in event, facility or sports management.\nMust be able to lift up to 50 pounds occasionally, with or without reasonable accommodations.\nMust commit to work all Chicago State home games.\nAbility to maintain a professional appearance.\nValid driver’s license.\nPreferred Qualifications                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 19  Around the world, our employees are united by our mission to save and sustain lives. Together, we create a culture that encourages colleagues to pursue rewarding careers - where everyone has the opportunity to do meaningful work as a part of a team they respect, in an environment that values each person’s contributions. We’re happy you’re interested in continuing your career journey with Baxter.\nSummary:\nThe Senior Manager , Health Economics and Outcomes Research (HEOR), is responsible for demonstrating a product’s economic and humanistic value and developing deliverables that communicate this value to the complete range of external stakeholders, including patients, physicians, and payers. The Senior Manager applies his/her clinical and technical skills to conduct appropriate economic and quality of life analyses.\nEssential Duties and Responsibilities:\nDesign and implement outcomes studies that establish the economic and humanistic value of Baxter products\nAssess and integrate economic and patient-reported outcomes into clinical trials\nAssess the psychometric properties of a quality of life instrument through FDA patient-reported outcomes guidance for labeling claims.\nDevelop economic models including, but not limited to, budget impact and cost effectiveness models\nDevelop economic dossiers and other reimbursement-supportive materials\nCollaborate with the statistician on the statistical analysis of outcomes data using clinical trial and administrative databases\nConduct outcomes research to a level such that results are suitable for presentation at scientific meetings and/or publication in peer-reviewed journals.\nCommunicate economic and quality of life value messages to internal and external stakeholders through presentation of outcomes research at medical meetings and through one-on-one interaction.\nProven expertise in designing, conducting, and interpreting outcomes research studies.\nQualifications:\nExcellent interpersonal and communication skills\nAbility to understand and work with clinicians and marketers\nWorking knowledge of reimbursement processes for devices and drugs in major international markets\nExceptional project management skills\nMaster’s degree in health economics, pharmacy administration, epidemiology, public health, or equivalent\nMinimum 7 years of experience in health outcomes research with Master’s degree\nEqual Employment Opportunity\nBaxter is an equal opportunity employer. Baxter evaluates qualified applicants without regard to race, color, religion, gender, national origin, age, sexual orientation, gender identity or expression, protected veteran status, disability/handicap status or any other legally protected characteristic.\n\nEEO is the Law\nEEO is the law - Poster Supplement\nPay Transparency Policy\nReasonable Accommodations\nBaxter is committed to working with and providing reasonable accommodations to individuals with disabilities. If, because of a medical condition or disability, you need a reasonable accommodation for any part of the application or interview process, please send an e-mail to Americas_TTA@baxter.com and let us know the nature of your request along with your contact information.

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Statistician_Chicago.csv')
