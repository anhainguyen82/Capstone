# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Statistician%22&l=New+York%2C+NY&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 345

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 345

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 37

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                                          Title  \
# 0   Data Scientist
# 1   Research Coordinator
# 2   Associate Director, Clinical Development
# 3   Computational Statistician
# 4   Senior Data Scientist
# 5   CIB data+design - Data Scientist Manager - Executive Director
# 6   Associate Director, Biostatistics
# 7   STATISTICIAN
# 8   CIB data+design - Data Scientist - VP
# 9   Computational Geneticist
# 10  Academic Statistician
# 11  CIB data+design - Data Scientist Manager - Executive Director
# 12  Medical Director, Center for Biomedical Research
# 13  Expert Clinical Development Manager
# 14  Machine Learning Engineer
# 15  CIB data+design - Data Scientist - Associate
# 16  Survey Statistician, GG-1530-7/9/11/12, Census-MP-KDA
# 17  Short-Term Casual
# 18  CIB data+design - Data Scientist - VP
# 19  Senior Manager, Statistical Programmng
# 20  Data Scientist Technical Lead
# 21  Consulting Statistician, Manager – US Research & Insights, Deloitte Services LP
# 22  Senior Data Scientist - Statistician, Bayesian Inference
# 23  Clinical Research Administrator
# 24  Clinical Data Processor
# 25  Research Coordinator
# 26  Supervisory Survey Statistician (Regional Survey Manager), GG-1530-7/9/11/12,Census-DE-KDA
# 27  Quantitative Engineer
# 28  Survey Statistician, GG-1530-7/9/11/12,Census-DE-KDA
# 29  Statistical Programmer II
# 30  Senior Vice President, Ipsos Science Center
# 31  Vice President - AML Business Analyst - Data Scientist
# 32  Director, Biostatistics
# 33  Assoc Director, Biostatistics - Oncology
# 34  Senior Data Scientist - Statistician, Causal Inference
# 35  Analysis and Reporting Analyst
# 36  FWS Athletics Event Staff
#
#               Location            City State         Zip     Country  \
# 0   New York, NY        New York        NY    None Found  None Found
# 1   New York, NY 10016  New York        NY    10016       None Found
# 2   East Hanover, NJ    East Hanover    NJ    None Found  None Found
# 3   New York, NY        New York        NY    None Found  None Found
# 4   New York, NY        New York        NY    None Found  None Found
# 5   New York, NY 10179  New York        NY    10179       None Found
# 6   Woodcliff Lake, NJ  Woodcliff Lake  NJ    None Found  None Found
# 7   New York, NY        New York        NY    None Found  None Found
# 8   New York, NY 10179  New York        NY    10179       None Found
# 9   New York, NY        New York        NY    None Found  None Found
# 10  New York, NY        New York        NY    None Found  None Found
# 11  New York, NY 10179  New York        NY    10179       None Found
# 12  New York, NY 10065  New York        NY    10065       None Found
# 13  East Hanover, NJ    East Hanover    NJ    None Found  None Found
# 14  New York, NY        New York        NY    None Found  None Found
# 15  New York, NY 10179  New York        NY    10179       None Found
# 16  New York, NY 10278  New York        NY    10278       None Found
# 17  New York, NY        New York        NY    None Found  None Found
# 18  New York, NY 10179  New York        NY    10179       None Found
# 19  Woodcliff Lake, NJ  Woodcliff Lake  NJ    None Found  None Found
# 20  New York, NY 10011  New York        NY    10011       None Found
# 21  New York, NY 10112  New York        NY    10112       None Found
# 22  New York, NY 10017  New York        NY    10017       None Found
# 23  New York, NY        New York        NY    None Found  None Found
# 24  New York, NY        New York        NY    None Found  None Found
# 25  New York, NY        New York        NY    None Found  None Found
# 26  New York, NY 10278  New York        NY    10278       None Found
# 27  New York, NY 10001  New York        NY    10001       None Found
# 28  New York, NY 10278  New York        NY    10278       None Found
# 29  Cranford, NJ        Cranford        NJ    None Found  None Found
# 30  New York, NY        New York        NY    None Found  None Found
# 31  Jersey City, NJ     Jersey City     NJ    None Found  None Found
# 32  Woodcliff Lake, NJ  Woodcliff Lake  NJ    None Found  None Found
# 33  Woodcliff Lake, NJ  Woodcliff Lake  NJ    None Found  None Found
# 34  New York, NY 10017  New York        NY    10017       None Found
# 35  Manhattan, NY       Manhattan       NY    None Found  None Found
# 36  Hoboken, NJ 07030   Hoboken         NJ    07030       None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Qualifications  \
# 0   \nPh.D. or M.S. in a quantitative field such as Computer Science, Operations Research, Statistics, Econometrics or Mathematics\nExpertise in machine learning and statistical modeling\n2+ years professional or research experience in data science\nPassion to answer Product/Engineering questions with data
# 1   None Found
# 2   None Found
# 3   None Found
# 4   \nYou know how to scope and solve loosely defined problems and come up with actionable insights to guide product development decisions\nExperience applying statistical methods (distribution analysis, classification, clustering, etc.)\nYou have a deep understanding of statistics and experience working with real-world data, as well as a strong business sense\nYou have working experience with:\n C, C++, R, Python, R, Java, SQL including Analytical SQL, SOQL, PL/SQL; preferably Python and R\nData stores like MSSQL, Oracle, Sybase, DB2, Hadoop, MPP Databases like HP Vertica and Redshift, Pig, Hive, Spark, Azure; preferably Azure\nStatistical methods like linear regression, logistic regression, discriminant analysis, neural networks, ARIMA, CHAID, Cluster Analysis, Market Basket Analysis, Classification\nData Visualization and Business Intelligence tools like R Shiny, Power BI, Quicksight, BigQuery BI, Tableau, Kibana, Microstrategy; preferably Power BI\nYou have 5+ years of relevant experience, with a degree in statistics, mathematics, computer science, engineering or related quantitative discipline\n
# 5   None Found
# 6   PhD with at least 5 years or MS with at least 8 years of experience required in related discipline or in the pharmaceutical industry/CRO environment.Demonstrated excellence in statistical skills across multiple areas of pharmaceutical biostatistics, together with broad understanding and experience of the clinical development process.Strong ability to work in a dynamic environment where multi-tasking and changing priorities exist.Experience with CRO oversight and FDA submission preferred.Excellent technical writing and verbal communication skills.Strong teamwork ability/commitment and individual initiative.Strong organizational skills with ability to effectively manage multiple studies.Excellent programming skills in SAS.
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  \nVRA\n30% or more disabled\nPersons with Disabilities\nCTAP\nICTAP\n
# 17  None Found
# 18  None Found
# 19  None Found
# 20  None Found
# 21  PhD in statistics or one of the quantitative social sciences\n5+ years of experience doing hands-on, statistics-intensive work\nSolid experience working in a consulting statistician capacity: ideating with clients, manifesting good communication skills, balancing multiple projects\nBroad, solid knowledge of statistics with depth in one or more areas such as survey design/analysis, econometrics, or causal inference\nFlair for Exploratory Data Analysis\nKnowledge of core machine learning methods\nAbility and eagerness to keep abreast of data-intensive developments in such fields as text analysis, social network analysis, Computational Social Science\n\nTo apply\nApply with a letter explaining why you are interested in this role and expanding upon your qualifications. Please include a full CV and two writing samples, ideally sole- or first-authored. One sample should be shorter (i.e., <1000 words) and one longer (i.e., >2000 words).
# 22  None Found
# 23  None Found
# 24  Bachelor’s Degree in health related field\nProficiency with Microsoft Office software suite, FileMaker Pro\nExperience designing data screens for clinical trial data entry and quality control\nExperience in academic clinical research or in clinical research industry (biotech, pharmaceutical company, CRO) in a clinical data entry or processing position\nExperience with preparing data reports for submission to senior statistician and PI\nProficient communication skills\nDetail-oriented and able to work independently\n
# 25  None Found
# 26  \nAbility to lead, and motivate a team to complete a project under tight deadlines.\nAbility to use survey methods such as survey research, sampling, questionnaires, and data collection in order to design, conduct, interpret and analyze surveys.\nSkill in interviewing applicants, making selections and proposing performance and conducting related actions.\nKnowledge of data collection or analysis to write tabular, graphic or test reports outlining progress or results of surveys.\nAbility to communicate technical and non-technical information to a variety of audiences.\n
# 27  None Found
# 28  \nAbility to use survey methods such as survey research, sampling, questionnaires, and data collection in order to design, conduct, interpret and analyze surveys.\nKnowledge of statistical software packages.\nAbility to lead and motivate a team by establishing priorities, including planning and assigning work to complete a project under a tight deadline.\nSkill in interviewing applicants, making selections and proposing performance and conduct related actions.\nAbility to work with a team to accomplish objectives and goals in a prescribed timeframe.\nKnowledge of data collection or analysis to write tabular, graphic or test reports outlining progress or results of surveys.\nAbility to evaluate cost and progress data and to recommend a course of action to stay on schedule based on analysis of cost and progress data.\n
# 29  \nBachelor or MS degree in relevant scientific majors.\n4 plus years of SAS programming experience in the pharmaceutical industry as a Statistical SAS Programmer. SAS Certification desirable.\nGood SAS (Base/Graph/STAT) and SAS macro programming skills with ability to provide quality output and deliverables for safety and efficacy (ISS/ISE).\nFamiliar with CDISC SDTM/ADaM standards, medical terminology, and clinical trial methodologies.\nStrong experience in QC / validation skills.\nStrong understanding of relational database structure.\nDemonstrate teamwork and interpersonal skills with strong verbal and written communication skills in a global environment.\nKnowledge of pharmaceutical clinical development life cycle (i.e. understanding safety deliverables, efficacy analysis).\nExcellent organizational skills with ability to support multiple assignments with challenging timelines.\nExcellent analytical, problem solving and troubleshooting skills that demonstrate initiative and motivation.\nKnowledge of statistical tests and procedures and ability to apply them effectively.
# 30  None Found
# 31  Bachelor’s degree (or beyond) with outstanding academic credentials\n5 – 8 years of relevant industry experience\nProfessional experience at a large financial institution or financial services data types\nUnderstanding of statistics, different distributions, hypothesis testing, regression etc.\nSelf-sufficiency in SQL (functions, procedures and packages)\nData mining\nTime management skills and ability to execute tasks within tight deadlines\nExcellent Analytical, oral and written communication skills—the ability to communicate with varied audiences and stakeholders (IT, senior management, etc.)\nExcellent interpersonal skills necessary to work effectively with colleagues\nHigh level of computer literacy
# 32  PhD with 10+ years or MS with 15+ years of experience required in related discipline or in the pharmaceutical industry/CRO environment.Demonstrated excellence in statistical skills across multiple areas of pharmaceutical biostatistics, together with broad understanding and experience of the clinical development process.Experience with CRO oversight and FDA submission preferred.Excellent technical writing and verbal communication skills.Strong teamwork ability/commitment and individual initiative.Strong organizational skills with ability to effectively manage multiple studies.Excellent programming skills in SAS or R.
# 33  PhD with 5+ years or MS with 10+ years of experience required in related discipline or in the pharmaceutical industry/CRO environment.Demonstrated excellence in statistical skills across multiple areas of pharmaceutical biostatistics, together with broad understanding and experience of the clinical development process.Experience with CRO oversight and FDA submission preferred.Excellent technical writing and verbal communication skills.Strong teamwork ability/commitment and individual initiative.Strong organizational skills with ability to effectively manage multiple studies.Excellent programming skills in SAS or R.
# 34  None Found
# 35  None Found
# ...
# 33  The Associate Director, Biostatistics within Oncology independently reviews entire protocols and interfaces with clinicians and other functions to understand study requirements and study design elements including sample size calculations, analysis methods, and study durations etc. for multiple studies\n\nThe incumbent develops and/or reviews statistical documents for multiple clinical trials, including SAPs, TLG shells and specifications of variable derivation. This position supports clinical trial related publications.\n\nThe incumbent also provides statistical and validation support for analysis datasets, statistical tables, figures and listings as well as performs and validates statistical analysis. Additionally, this individual will be expected to complete Independent reviews of CSRs and perform data interpretation.\n\nThe Associate Director, Biostatistics works with the internal/CRO statisticians and programmers to ensure the highest quality of CRO deliverables and QA of data outputs. This individual will function as lead statistician in global registration trials and manage all related statistical activities which includes leading preparation of inputs for regulatory documents and helping to prepare for meetings with health authorities. This individual will also lead preparation of responses to health authorities including identification and execution of new analysis required for these responses.\n\nThe Associate Director, Biostatistics manages contract statisticians in the group and provides mentoring and oversight of the assigned work.\nJob Qualifications\nKnowledge/Skills/Abilities Required\n\nPhD with 5+ years or MS with 10+ years of experience required in related discipline or in the pharmaceutical industry/CRO environment.Demonstrated excellence in statistical skills across multiple areas of pharmaceutical biostatistics, together with broad understanding and experience of the clinical development process.Experience with CRO oversight and FDA submission preferred.Excellent technical writing and verbal communication skills.Strong teamwork ability/commitment and individual initiative.Strong organizational skills with ability to effectively manage multiple studies.Excellent programming skills in SAS or R.\nCityWoodcliff Lake\nState\nNew Jersey\nJob TypeFull-time                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 34  About the company\n\nAt Covera Health, we have proven that advanced data science can prevent serious misdiagnoses which result in poor outcomes for patients and increased costs for payers. Using our proprietary framework, we help patients recover better, faster, and more affordably. Today, we are working with some of the largest healthcare payers in the country to potentially impact millions of patient lives. We are passionate about improving healthcare for every patient.\n\n\nAbout the role\n\nWe are looking for a talented Senior Data Scientist in Statistics to join us in our commitment to improve the quality of care for patients in every community across the nation. It is crucial that you have a Masters or PhD with a thesis and work in application of statistics methodologies, especially longitudinal data analysis and causal inference.\n\n\nYou will work with a growing multidisciplinary team of talented data scientists, other statisticians, engineers, and researchers to leverage unique healthcare data (in the form of MRI images, clinical reports, claims data, and beyond) to create new and improved methods for assessing and predicting the quality of care delivered by healthcare providers and determining the impact that care quality has on overall patient outcomes and cost. You will have the opportunity to work with entirely unique healthcare datasets that cover all phases of care delivery (referral, diagnosis, therapy, and outcome/follow-up) from the perspective of all key stakeholders (patients, providers, payers).\n\n\nYour responsibilities will also include helping to further create, extend, and validate the statistical models that we use at Covera Health to power our analytics. You will also help to characterize, interpret, and share the results we achieve in our healthcare research studies. Your responsibilities will also include helping to shape our data analytics strategy by identifying new opportunities and helping to lead and mentor junior members of the analytics team.\nYou will be expected to:\nLeverage a variety of healthcare data, including healthcare provider profile data, longitudinal claims data, and proprietary diagnostic imaging exam quality assessment data, to quantify the relationship between healthcare quality and patient outcomes, costs, and care patterns\n\nCreate, extend, and validate models and methods for causal analysis and outcome prediction\n\nCollaborate with data science team members and other colleagues on data analysis projects and research activities\n\nCommunicate the results of analysis and research projects to internal and external stakeholders\n\nPrepare and contribute material for academic publication and participate in scientific conferences\n\nLead and mentor junior members of the data science team\n\nHelp to shape Covera Health’s data analytics strategy by identifying new opportunities\n\nRequirements\n\n3+ years work experience as a Data Scientist\nPhD in statistics, biostatistics, healthcare economics, applied math, or related field\nExtensive experience with causal inference and related statistical methodologies\nExtensive experience with large and diverse datasets\nExtensive experience with Python and/or R\nExperience developing code that is leveraged by a wider team and/or contributing to a collaborative code base\nExperience designing scientific studies and quantitatively characterizing and sharing their results\nStrong communicator with excellent ability to work in a team environment\nExperience working with medical data\nBenefits\n\nYou will be a full-time employee with competitive salary, stock options, and great benefits. These benefits include medical, dental, and vision insurance (with premiums fully covered), FSA, pre-tax commuter benefits, flexible paid time off, and a comfortable office space filled with a variety of quality snacks and beverages. Most importantly, you’ll get to know each of us and we love to work together to find solutions. We are a smart, fun, focus ...
# 35  Please read this posting carefully to make certain you meet the qualification requirements before applying to this position.\n\nReporting to the Administrator for Analysis and Reporting, the successful candidate will perform detailed analyses and generate reports on projects performance and funding sources administered by the Capital Projects Division (CPD); utilize the information management resources to monitor projects schedules to ensure consistency, monitor construction performance metrics, and perform\nfinancial analyses for on-time obligation and expenditure of funds; and coordinate reporting on special initiatives.\n\nResponsibilities include, but are not limited to the following:\n\n1. Perform analytical and financial analyses of obligations and expenditures to ensure progress in accordance with funding mandates.\n2. Maintain accurate contract warranty/guarantee information.\n3. Manage research and reporting on portfolio funding.\n4. Perform periodic reviews on project schedules and budget to identify and address issues that may adversely impact on-time performance.\n5. Perform comparative analysis on timeliness by department and project managers in delivering projects.\n6. Review portfolio data to identify anomalies and ensure timely corrections are made to ensure accurate reporting.\n7. Monitor activities of projects in special initiatives portfolio and perform analyses as required.\n8. Manage the system for the recording of frontline costs and perform analytics to determine effective usage of time against project cost.\n9. Ensure that contracts and vendors administered by CPD are accurately identified in the financial management system to be able to correctly measure vendors’ capacity and performance.\n10. Generate charts and graphs that will assist in identifying impediments to workflow.\n11. Perform analyses and make recommendations for corrective actions on identified issues.\n12. Update information in APEX and other applications and extract data for comparative analyses to outline trends.\n13. Serve as secondary liaison for development of new or modifications to current reports.\n14. Coordinate activities to gather information from all NYCHA departments to update information on City funded projects for special/required tracking and reporting.\n15. Develop mechanisms to generate reports for elected officials on allocation of funding and performance of projects within the elected officials’ districts.\n16. Plan and attend meetings as required.\n17. Perform training as needed.\n\nNOTE: This position is open to qualified persons with a disability who are eligible for the 55-a Program. Please indicate in your cover letter that you would like to be considered for the position under the 55-a Program. For detailed information regarding the 55-a Program, please visit the link below:\nhttp://www.nyc.gov/html/dcas/downloads/pdf/psb/100_1.pdf\n\n\nMinimum Qual Requirements\n\n1. A master's degree from an accredited college or university in economics, statistics, finance, management, business administration, public administration, public policy or related field; or\n\n\n2. A baccalaureate degree from an accredited college or university, including or supplemented by 24 semester credits in one or more of the course areas of economics, statistics,\n\nfinance, management, mathematics, business administration, public administration, and public policy, 12 semester credits of which must have been in economics; and one year of satisfactory full-time experience in one or more of the\n\nfields of finance; economic, fiscal or statistical research; policy analysis; or quantitative, business, market or financial analysis. Graduate semester credits in any of the areas described in "1" above may be substituted for the undergraduate\n\nsemester credits on the basis that each 3 graduate semester credits may be substituted for 6 of the required undergraduate semester credits.\n\n\nSpecial Note\n\nTo be eligible for placement in Assignmen ...
# 36  Job Description\nThis position is for Stevens students currently enrolled. Must have at least 6 credits. Requirement: Candidate must have received a Federal Work Study on your Financial Aid Award Letter. Students must receive release to work from Financial Aid Coordinator. This position is for Stevens students currently enrolled.\nAthletics FWS Event Staff aid in setting up and breakdown of facility for athletic events. Ball running and or media table responsibilities such as running the shot clock, keeping scorebook, scoreboard operations and any other game day duties as needed. Additional Sports Information responsibilities include public address announcer, statistician, camera, webcast, play by play and music.\nDepartment\nOffice of Athletic Events\nGeneral Submission Guidelines:\nIn order to be considered a candidate for any job at Stevens, you must submit an online application. Please attach a cover letter and resume with each application. Other requirements for consideration may depend on the job.\nStill Have Questions?\nIf you have any questions regarding your application, please contact Jobs@Stevens.edu\nEEO Statement:\nStevens Institute of Technology is an Equal Opportunity Employer. Accordingly, Stevens adheres to an employment policy that prohibits discriminatory practices or harassment against candidates or employees based on legally impermissible factor(s) including, but not necessarily limited to, race, color, religion, creed, sex, national origin, nationality, citizenship status, age, ancestry, marital or domestic partnership or civil union status, familial status, affectional or sexual orientation, gender identity or expression, atypical cellular or blood trait, genetic information, pregnancy or pregnancy-related medical conditions, disability, or any protected military or veteran status.\nStevens is building a diverse faculty, staff and student body and strongly encourages applications from female and minority candidates as well as veterans and individuals with disabilities. Stevens is a federal contractor under the Vietnam Era Veterans' Readjustment Assistance Act (VEVRAA) and the Rehabilitation Act of 1973, as well as other federal statutes.\nJeanne Clery Disclosure:\nIn accordance with the Jeanne Clery Disclosure of Campus Security Policy and Campus Crime Statistics Act (Clery Act), the Department of Public Safety is required to publish an annual security report which includes statistics mandated by the Clery Act. You can obtain a copy of this report by accessing the following web site: http://www.stevens.edu/sit/police

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Statistician_NYC.csv')
