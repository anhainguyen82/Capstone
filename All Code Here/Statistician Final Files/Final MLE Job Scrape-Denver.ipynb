# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Statistician%22&l=Denver%2C+CO&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 360

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 360

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 12

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                               Title            Location  \
# 0   Director, Biostatistics                          Boulder, CO
# 1   Forecasting Analyst, Ads Analytics and Insights  Boulder, CO 80302
# 2   Tableau Developer                                Denver, CO
# 3   Abdominal Radiologist                            Aurora, CO
# 4   Ultimate Hoops Statistician                      Parker, CO 80138
# 5   Senior Manager, Biostatistics                    Boulder, CO
# 6   Professional Research Assistant                  Aurora, CO
# 7   Senior Manager, Biostatistics                    Boulder, CO
# 8   Quantitative Business Analyst                    Boulder, CO 80302
# 9   Director, Biostatistics                          Boulder, CO
# 10  Statistician                                     Denver, CO 80208
# 11  HS Track & Field Head Coach                      Lakewood, CO 80235
#
#         City State         Zip     Country  \
# 0   Boulder   CO    None Found  None Found
# 1   Boulder   CO    80302       None Found
# 2   Denver    CO    None Found  None Found
# 3   Aurora    CO    None Found  None Found
# 4   Parker    CO    80138       None Found
# 5   Boulder   CO    None Found  None Found
# 6   Aurora    CO    None Found  None Found
# 7   Boulder   CO    None Found  None Found
# 8   Boulder   CO    80302       None Found
# 9   Boulder   CO    None Found  None Found
# 10  Denver    CO    80208       None Found
# 11  Lakewood  CO    80235       None Found
#
#                                                                                                                                                                                                                                                                                               Qualifications  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   A letter of application which specifically addresses the job requirements and outlines qualifications\nA current Resume/CV\nThe names, addresses, daytime telephone numbers and e-mail addresses for three professional references, either attached to your resume/CV or uploaded as a separate document
# 4   None Found
# 5   None Found
# 6   \nBA or BS in a relevant field (public health, epidemiology, statistics, etc.)\n1-2 years of experience in data management and statistical analyses using statistical software (e.g., SAS, R)
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                     Skills  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   \nBA or BS in a relevant field (public health, epidemiology, statistics, etc.)\n1-2 years of experience in data management and statistical analyses using statistical software (e.g., SAS, R)
# 7   None Found
# 8   None Found
# 9   None Found
# 10  Excellentorganizational, analytical, and problem-solving skills.\n\nEfficientoral and written communication skills.\n\nAbilityto prioritize and execute multiple tasks and meet deadlines.\n\nAbilityto work independently and the ability to promote a team work environment andparticipate as an active team member.\n\nAbilityto define appropriate statistical methods based on outcome measure.\n
# 11  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Responsibilities  \
# 0   None Found
# 1   \nBuild, test, and deploy statistical and predictive models to improve global operations, including volume forecasting and capacity planning for the Ads Global Customer Care operation, and determining the optimal shift allocation for employees in a call center.\nAnalyze data on operations such as spikes or dips in customer support cases or related metrics using advanced analytics, including statistical modeling (regression, segmentation, machine learning etc.) and develop insights/recommend strategies for business partners.\nCollaborate with tools and platforms teams on timelines/requirements for implementing new/updating existing features for improving Ads operations.\nProvide analytical thought leadership, proposing feasible solutions to business and operational challenges, using context developed through trusted partnerships with business stakeholders.\nDesign or advise on methodologies to appropriately measure impact of tooling changes, customer experience and business initiatives.\n
# 2   None Found
# 3   None Found
# 4   \nAssures all players are checked in and present on official scoresheets\nTracks all relevant statistics during games\nWorks closely with League Coordinator to ensure member satisfaction\nAssists in game preparations and/or clean up as needed\nActively promotes Ultimate Hoops and Life Time Fitness to members and non-members\nArticulates extensive knowledge of Ultimate Hoops and Life Time Fitness programs, products, services, policies and procedures to prospective and current members
# 5   None Found
# 6   None Found
# 7   None Found
# 8   \nAnalyze data on operations and develop insights and strategies for business organizations.\nBe a trusted partner for the business stakeholders understanding their business and strategy.\nPresent regularly at an executive level and engage with stakeholders within the organization.\nProvide thought leadership on deep analytics, identifying issues and opportunities and proposing feasible solutions.\n
# 9   None Found
# 10  \nDesignsstatistical analysis where designs are made complex by the numbers and kinds ofvariables, number of levels of variables, and/or interactions or relationshipsbetween variables. Performs mixed models analysis.\n\nParticipatesin the writing of scientific manuscripts as well as operational reports derivedfrom these analyses.\n\nAssistsin designing studies that can be addressed using the research databases.Implements these study designs using appropriate analytic techniques andPC-based statistical software.\n\nAdvisesinvestigators on appropriate statistical design of studies and performs poweranalysis for proposed studies. Understands the hypotheses and experimentalapproaches and recommends appropriate statistical analyses for balanced andunbalanced designs.\n\nSynthesizes,normalizes, standardizes data, and interprets the results.\n\nMaintainsstatistical information and reports of test data and quality control. Preparesactivity reports and interprets, prepares and distributes statistical dataregarding the laboratory.\n\nDesignsand constructs a server based research database. Imports existing data fromoperational databases located at several different blood banks and assemblesthe various source databases into a single relational database, withappropriate quality control and data cleaning.\n\nDesignsand manages additional research study related databases in a secure SQLenvironment with appropriate quality control and data cleaning.\n
# 11  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                      Education  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  Master'sdegree in related field required, PhD in related field preferred.\n\nKnowledgeof database management principles, quality assurance techniques, and datavalidation methods required.\n\nKnowledgeof statistical software required. (Examples; SAS, S-Plus, SPSS, STATA)\n\nPriorpublication preferred.\n\nKnowledgeof genetic data analysis required.\n\nUnderstandingof relational database concepts required.\n\n
# 11  \nInSideOut Philosophy focuses on the purpose, power, possibility, and privilege of leading and coaching\nWhy do I coach\nWhy do I coach the way I coach\nHow does it feel to be coached by me\nHow do I define success\nAll coaches will receive a copy of the book, “InSideOut Coaching” by Joe Erhmann\nCoaches will work on developing their own purpose statement\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                    Requirement  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   \nHigh School Diploma or GED\nExperience tracking full statistical data for basketball games
# 5   None Found
# 6   \nBA or BS in a relevant field (public health, epidemiology, statistics, etc.)\n1-2 years of experience in data management and statistical analyses using statistical software (e.g., SAS, R)
# 7   None Found
# 8   None Found
# 9   None Found
# 10  Master'sdegree in related field required, PhD in related field preferred.\n\nKnowledgeof database management principles, quality assurance techniques, and datavalidation methods required.\n\nKnowledgeof statistical software required. (Examples; SAS, S-Plus, SPSS, STATA)\n\nPriorpublication preferred.\n\nKnowledgeof genetic data analysis required.\n\nUnderstandingof relational database concepts required.\n\n
# 11  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# ...
# 9   ROLE SUMMARY\nBiostatisticians play a critical role in the advancement of new medicines at Pfizer. The right candidate will partner with senior management, clinicians, clinical pharmacologists, translational medicine, and other scientists to support early clinical development for Oncology. The statistician will be involved in the design, execution, analysis, and reporting phases of clinical protocols and provide statistical expertise on regulatory submissions and ensure the quality and appropriateness of submission deliverables. She/he will support the development of innovative and efficient plans for developing new medicines in a variety of cancer indications. She/he will review scientific literature, promote innovation, efficient design and quantitative decision-making within research and in partnership with other lines, reducing the time and cost of drug development.\nROLE RESPONSIBILITIES\nCore member of scientific teams responsible for determining strategy and delivering results in a timely and high quality environment.\nLeader to bring innovative statistical thinking and methods to help drive the enhanced quantitative drug discovery and development paradigm within Pfizer. Central to this approach is the systematic review of prior information, statistical model building and simulation, utilizing Bayesian methods as appropriate, to design more effective studies.\nFrequently interact with regulatory agencies regarding accelerated clinical development options for indications that have substantial unmet medical need.\nIn depth knowledge of more than one area of statistics, all commonly used, that enables to exert broad influence via advice to numerous project statisticians.\nLeads initiatives to improve understanding and application of statistical methods\nStrong insight into the Business needs and seek out areas where statistics adds most value, influencing others to ensure we focus our efforts on these key areas\nBASIC QUALIFICATIONS\nThe qualified candidate must have a M.S. or Ph.D. in Statistics, Biostatistics, or related field, as well as a minimum of six years experience in applying statistics in a pharmaceutical or related industry. Ideally, this experience would include exposure to the design and analysis of clinical studies in oncology early clinical development. The preferred candidate will have excellent statistical knowledge with the ability to apply this to scientific and clinical problems with experience in computational simulation, analysis of biomarkers, and Bayesian statistics.\nThe preferred candidate will have a proven ability to manage multiple complex projects with a track record of influencing external environment through contributions to scholarship, working parties etc., as evidenced by committee membership, presentations and publications with demonstrated scientific productivity in advancing the state-of-the-art in applied statistical methodologies and prior experience providing statistical support to clinical studies in oncology. Strong communication skills with the ability to influence widely and work collaboratively with clinical project teams and senior management are required.\n"Candidate demonstrates a breadth of diverse leadership experiences and capabilities including: the ability to influence and collaborate with peers, develop and coach others, oversee and guide the work of other colleagues to achieve meaningful outcomes and create business impact."\nPREFERRED QUALIFICATIONS\nThe preferred candidate will have strong computational skills in R, S-plus, or SAS and other statistical applied software systems such as Winbugs.. Must be able to explain statistical techniques and considerations to non-statisticians. Good communication skills and the ability to work collaboratively with the clinical project team are required.\nSunshine Act\nPfizer reports payments and other transfers of value to health care providers as required by federal and state transparency laws and implementing regulations.  ...
# 10  VitalantResearch Institute (VRI) (www.bsrisf.org), internationally respected for itswork to advance blood safety worldwide has established a campus in Denver,Colorado on the grounds of the Vitalant Blood Center, formerly known as Bonfils,to focus on the development of blood products and transfusion methodologies. Weare building a team to conduct the research and cGMP manufacturing ofcryopreserved platelets to support ongoing clinical trials in the USA sponsoredby the US Army, expanding to broaden research and development activities forplatelets and red blood cells for transfusion, and extending manufacturing andoperations research.\n\nVRIDenver is now hiring aBiostatisticianto work in a team. This is a research and development position.\n\n\nUnderminimal supervision, the incumbent is responsible for advanced statisticaldesign and analysis of data for reports and research papers to includedescriptive statistics and commonly used regression analyses as well as complexanalyses, and mixed models analyses. The incumbent must understand thehypotheses and experimental approaches and will recommend appropriate analysesfor balanced and unbalanced designs. The incumbent will assists in interpretingresults of analyses, and is responsible for database design and maintenance ina SAS/SQL or other environment. This is a research and development positiongenerally day shift Monday-Friday.\n\nDuties andResponsibilities Include:\n\nDesignsstatistical analysis where designs are made complex by the numbers and kinds ofvariables, number of levels of variables, and/or interactions or relationshipsbetween variables. Performs mixed models analysis.\n\nParticipatesin the writing of scientific manuscripts as well as operational reports derivedfrom these analyses.\n\nAssistsin designing studies that can be addressed using the research databases.Implements these study designs using appropriate analytic techniques andPC-based statistical software.\n\nAdvisesinvestigators on appropriate statistical design of studies and performs poweranalysis for proposed studies. Understands the hypotheses and experimentalapproaches and recommends appropriate statistical analyses for balanced andunbalanced designs.\n\nSynthesizes,normalizes, standardizes data, and interprets the results.\n\nMaintainsstatistical information and reports of test data and quality control. Preparesactivity reports and interprets, prepares and distributes statistical dataregarding the laboratory.\n\nDesignsand constructs a server based research database. Imports existing data fromoperational databases located at several different blood banks and assemblesthe various source databases into a single relational database, withappropriate quality control and data cleaning.\n\nDesignsand manages additional research study related databases in a secure SQLenvironment with appropriate quality control and data cleaning.\n\n\n\n\nRequirements:\n\nKnowledge/Education:\n\nMaster'sdegree in related field required, PhD in related field preferred.\n\nKnowledgeof database management principles, quality assurance techniques, and datavalidation methods required.\n\nKnowledgeof statistical software required. (Examples; SAS, S-Plus, SPSS, STATA)\n\nPriorpublication preferred.\n\nKnowledgeof genetic data analysis required.\n\nUnderstandingof relational database concepts required.\n\n\nLicenses/Certifications:\n\nNone\n\n\nExperience:\n\nFiveyears related experience required.\n\nExperienceworking with large, complex databases and integrating data from a variety ofsources and formats required.\n\nPriorcontribution to analysis of research projects required.\n\nKnowledgeof PC-based statistical software required.\n\nExperiencein writing programs in SQL required.\n\nSASprogramming skills such as Macro 7 required.\n\n\nSkills/Abilities:\n\nExcellentorganizational, analytical, and problem-solving skills.\n\nEfficientoral and written communication skills.\n\nAbilityto prioritize and execute multiple tasks and meet deadline ...
# 11  DENVER CHRISTIAN ATHLETIC PHILOSOPHY\nInterscholastic athletics are an integral part of a Denver Christian education. Denver Christian School is dedicated to providing a Christ-centered education that develops the whole child; this includes developing the academic, social/emotional, spiritual, creative/artistic, and kinesthetic/athletic. In order to glorify God in athletics, our athletes must pursue the goal of excellence within a Christian framework. The success of our athletic program is more than the outcome of a competition between two different schools; it means capturing every aspect of athletics (practice, traveling, competing, etc.) as an opportunity for learning, physical development, and discipleship. As Christians, we are called to excellence (performance to the best of our ability) in all areas of life because God rules over every area of our life … including athletics, and He has given us gifts to use for His glory.\nATHLETIC GOALS\nDenver Christian provides the opportunity for our students to participate in athletics:\nTo help our students understand that God is in every part of their lives, whether that is in the classroom, on the athletic field, or in their home life.\nTo develop physically, mentally, emotionally, and spiritually, recognizing that each individual student is a unique creation of God.\nTo provide athletic experiences where our teams participate in such a way that we honor our God, our school, our team, and our community.\nTo develop our students into athletes who play fairly, observe regulations and policies, treat other with courtesy and take adversity without complaining.\nTo demonstrate respect and courtesy toward teammates, opponents, and officials at all times.\nTo help our students gain experience through athletic participation that will develop Christian character and reflect Christ to others.\nTo help our students understand that our motto “TO GOD BE THE GLORY” is achieved when God is glorified through our effort, attitude, and performance. Our teams will train hard to win without submitting to the “win at all costs” view that is so prevalent in today’s culture.\nCOACH EXPECTATIONS\nAthletics is one of the many means of discipleship DC uses to bring students to a deeper relationship with Christ. Participating in a sport provides daily opportunities for students to grow in their walk with Christ by experiencing struggles, failure, success, and relationships through a Biblical framework. Coaches are the primary guide throughout this process. At all times, coaches should represent Christ, the school, and themselves in a way that honors God. Coaches are called to teach their athletes to do the same. In addition to discipleship, coaches must demonstrate excellence in their field and a growth mindset to be ever improving.\nCoaches should have a clear profession of their faith in Christ and a discipling attitude about coaching/athletics\nCoaches must have demonstrated knowledge of the game either as a player or as a coach; varsity coaches must have successful prior coaching experience.\nCoaches must meet the requirements found in the employee handbook (add link to employee handbook)\nCoaches must have a view of athletics consistent with the Denver Christian Athletic program, as outlined in this document.\nCOACHES UNDERSTAND/AGREE TO THE FOLLOWING:\nAthletics is a ministry / discipling opportunity\nStudents who participate in a sport are voluntarily placing themselves in your “classroom” for hours each week.\nCoaches understand their sport is a platform in which to model and teach lessons which will last well beyond the student’s athletic career.\nInvolvement in athletics, which by nature is a high profile part of the school, allows ministry opportunities with opponents, fans, and the community, as they observe how the Christian life is lived out in an athletic arena.\nDC Athletics is an opportunity to teach Biblical principles\nAthletics at DC supports it mission to “inspire and equip studen ...

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Statistician_Denver.csv')
