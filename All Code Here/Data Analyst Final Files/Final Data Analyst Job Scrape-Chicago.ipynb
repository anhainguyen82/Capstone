# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Data+Analyst%22&l=Chicago%2C+IL&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 326

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 326

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 170

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                          Title           Location      City  \
# 0    Clinical Data Analyst                      Chicago, IL 60612  Chicago
# 1    Marketing Data Analyst                     Chicago, IL 60666  Chicago
# 2    Bank Operational Data Analyst & Scientist  Chicago, IL        Chicago
# 3    Product Data Analyst                       Chicago, IL        Chicago
# 4    Data Analyst                               Chicago, IL 60602  Chicago
# ..            ...                                             ...      ...
# 165  Data Analyst II (Actuarial Services)       Chicago, IL        Chicago
# 166  Data Analyst                               Rosemont, IL       Rosemont
# 167  Business Intelligence Analyst              Chicago, IL 60601  Chicago
# 168  Lead Data Analyst                          Chicago, IL        Chicago
# 169  Marketing Analytics Specialist             Chicago, IL 60666  Chicago
#
#     State         Zip     Country  \
# 0    IL    60612       None Found
# 1    IL    60666       None Found
# 2    IL    None Found  None Found
# 3    IL    None Found  None Found
# 4    IL    60602       None Found
# ..   ..      ...              ...
# 165  IL    None Found  None Found
# 166  IL    None Found  None Found
# 167  IL    60601       None Found
# 168  IL    None Found  None Found
# 169  IL    60666       None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Qualifications  \
# 0    None Found
# 1    None Found
# 2    \nIndependently or with limited supervision: Analyze, design, deliver, and implement analytic development projects, with the use of BMO analytics tools, such as SAS, ACL, Business Objects, Python, SQL, Spotfire, Excel, etc.\nKnowledge of relational database structures & underlying concepts\nExamine opportunities to integrate data analytics into BMO audits and credit portfolios by assisting Corporate Audit & Loan Review teams in performing testing of internal controls across the Bank\nUse analytical tools and methodologies to analyze data, make observations, and make recommendations to improve policies, procedures, and controls to mitigate risk or increase efficiency\nEnsure audit & credit data analytics are efficiently performed and accurately interpret & present the results against defined criteria\nEnsure that audit & credit analytic project activities are accomplished within approved time frames, scope, and budgets\nConfirm that projects adhere to development standards and guidelines\nUse technical data analytics tools to perform analysis, conduct research and present findings to the audit team\n
# 3    None Found
# 4    None Found
# ..          ...
# 165  None Found
# 166  None Found
# 167  None Found
# 168  \nBachelor’s degree in analytical, quantitative or STEM field\n4+ years of relevant experience\n4+ years of experience in data manipulation using SQL and other scripting languages development (advanced/expert level)\nFamiliarity with analytics methods/theory (statistics, ML, etc.) and analytical programs/tools (e.g., SAS, R, Python, etc.)\n3+ years of experience building and creating dashboards for business consumption, including synthesizing data in graphical format
# 169  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Skills  \
# 0    None Found
# 1    None Found
# 2    \nAdvanced MS Office skills – Word, Outlook, Excel and PowerPoint\nExcellent communication, relationship, and collaboration skills to architect data driven ways to effectively test credit controls within the BMO enterprise.\nKnowledge of reporting tools such as, SAS, MSBI, BOBJ and/or audit specific data analysis tools such as ACL.\nKnowledge of design, development, and implementation utilizing current analytics technologies and architecture, as well as data warehouse concepts and methodologies\nMUST have strong programming skills demonstrated via education and work experience in SQL and one programming language: Python, Java/scala, or C/C++ , C#. Scripting experience in shell, Perl or Python is a strong asset.\nData mining and analysis using package such as R, Spark, Python libraries or similar\nVisualization experience using Tableau, SpotFire, or similar\nExposure to and working knowledge of one or more of the major database platforms: MS-SQL, Oracle, DB2, Netezza, Hadoop, HDFS, etc. is preferred.\nExposure to a wide variety of technology platforms and systems\nExpert analytical and system thinking skills\nAbility to undertake self-directed learning to understand processes and systems\nStrong problem solving and conflict resolution skills with the ability to exercise mature judgment\nIn-depth interpersonal, communication, negotiating, influencing, and relationship management skills
# 3    None Found
# 4    None Found
# ..          ...
# 165  None Found
# 166  None Found
# 167  \n1-2 years of experience in business analytics, data analysis or a similar field\n1-2 years of experience using Salesforce Sales Cloud (Administration experience strongly preferred)\nProficiency in SQL and Excel\nExperience with Hubspot preferred, and experience with or strong interest in learning marketing automation software (HubSpot, Marketo, Pardot, etc.) required\nProficiency with business intelligence visualization tools such as Tableau, Looker, DOMO, etc (Tableau preferred)\nAbility to partner with other departments and leadership to identify project requirements and execute those projects\nAbility to multi-task and meet urgent deadlines\nExcited about the opportunity and challenge that live within the ambiguity of our work, and an ability to shift between priorities that come from different departments (aka, you are flexible and adaptable)\nAble to work both collaboratively and independently\nPassion for expanding and embedding data-first mentality in company culture\n
# 168  None Found
# 169  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Responsibilities  \
# 0    None Found
# 1    None Found
# 2    \nProactively identify business, operational, and credit strategy changes, emerging risks and regulatory developments to enhance the efficiency and effectiveness of the 3rd line of defense.\nProvide auditors and loan reviewers with meaningful analytics and insights on efficiency opportunities observed within client functions.\nDemonstrate good judgment in application of advanced data analytics.\nProvide timely and insightful support.
# 3    None Found
# 4    None Found
# ..          ...
# 165  None Found
# 166  None Found
# 167  \nServe as the Salesforce administrator for an 85+ person company\nWork directly with internal dscout departments to understand their data needs and transform requirements into reporting and or data visualization\nAssist with the management of the marketing technology systems - automation, attribution and other solutions used by the marketing team\nIdeate, build and maintain dashboards to visually communicate metrics catered to internal dscout departments\nOwn and improve existing reporting processes (using Tableau, SQL, Salesforce, and Excel)\nDocument and organize information related to data structures, relationships, definitions and processes\nMaintain data quality standards through data entry and cleaning\nExtensively document and maintain resources and guides for Salesforce and general reporting best practices\nPlan and conduct internal training sessions related to Salesforce and reporting best practices, and then hold teams accountable to those standards
# 168  None Found
# 169  None Found
#
#       Education Requirement  \
# 0    None Found  None Found
# 1    None Found  None Found
# 2    None Found  None Found
# 3    None Found  None Found
# 4    None Found  None Found
# ..          ...         ...
# 165  None Found  None Found
# 166  None Found  None Found
# 167  None Found  None Found
# 168  None Found  None Found
# 169  None Found  None Found
#
# ...
# 167  We are dscout. At our core, we are People Nerds. We empower our customers to meet the people who matter to them in the moments that matter most. Customer-obsessed companies like Lyft, REI, Sonos, and IDEO use dscout to build better products and services because of people like you. We are building a smart and driven team in our Chicago HQ, and we would love for you to join us.\n\nWe are looking for a Business Intelligence Analyst to grow our Business Intelligence team from one to two. You'll work directly with our Director of Business Intelligence to support the internal dscout teams through ad-hoc analysis, dashboard creation, and improvement of the reporting infrastructure. You'll serve as the Salesforce administrator for the company and the general go-to person for reporting best practices. This is a brand new role, which means you have the opportunity to really build this work from the ground up!\n\nAs a combination of data analyst and internal analytics consultant, you will have a chance to help inform strategic decisions by providing the data to inform them. You are an incredible communicator and a genuine, creative problem-solver. You are a numbers- focused individual with significant analytics experience, including experience with Salesforce. If this sounds like you, apply today!\n\nWhat you will do (let's call them Responsibilities):\n\nServe as the Salesforce administrator for an 85+ person company\nWork directly with internal dscout departments to understand their data needs and transform requirements into reporting and or data visualization\nAssist with the management of the marketing technology systems - automation, attribution and other solutions used by the marketing team\nIdeate, build and maintain dashboards to visually communicate metrics catered to internal dscout departments\nOwn and improve existing reporting processes (using Tableau, SQL, Salesforce, and Excel)\nDocument and organize information related to data structures, relationships, definitions and processes\nMaintain data quality standards through data entry and cleaning\nExtensively document and maintain resources and guides for Salesforce and general reporting best practices\nPlan and conduct internal training sessions related to Salesforce and reporting best practices, and then hold teams accountable to those standards\n\nWhat you need to have (we can call them Desired Skills and Background):\n\n1-2 years of experience in business analytics, data analysis or a similar field\n1-2 years of experience using Salesforce Sales Cloud (Administration experience strongly preferred)\nProficiency in SQL and Excel\nExperience with Hubspot preferred, and experience with or strong interest in learning marketing automation software (HubSpot, Marketo, Pardot, etc.) required\nProficiency with business intelligence visualization tools such as Tableau, Looker, DOMO, etc (Tableau preferred)\nAbility to partner with other departments and leadership to identify project requirements and execute those projects\nAbility to multi-task and meet urgent deadlines\nExcited about the opportunity and challenge that live within the ambiguity of our work, and an ability to shift between priorities that come from different departments (aka, you are flexible and adaptable)\nAble to work both collaboratively and independently\nPassion for expanding and embedding data-first mentality in company culture\n\nWhat will you get?\n\nHere at dscout, we are a team of passionate research, sales, technical, marketing, design, success, and operations professionals. We are driven by the power of research—how in-context insights from real people can build products and services that are more people-centric. We value learning, sharing, and building. We deeply value being a diverse and inclusive team and company, and we are looking for team members who align with that belief. We are proud of what dscout is today and we are excited to build our future with you.\n\nIn addition to joining a smart a ...
# 168  Who We Are\nMore than 30 years ago, E*TRADE pioneered the online brokerage industry by executing the first-ever electronic individual investor trade. While the landscape of our industry has changed dramatically, our culture of innovation and drive to make online trading accessible to everyone continues to drive us forward. We believe in challenging the status quo, fostering an environment of curiosity and learning, and, above all, putting our customers first.\nAbout the Role\nThe role is part of the Data Insights & Initiatives team. You will join a team of ambitious and passionate associates, driven by ideas and with a bias towards execution. We look for associates willing to think beyond traditional organizational structures and with a strong desire to experiment, build and learn as well as grow personally and professionally.\nAs a Lead Data Analyst, you will work on programs and projects from start to end and deliver high-quality data solutions to grow E*TRADE. You will partner with various stakeholders to design and develop data driven insights that inform business and product decisions. Additionally, you will be responsible for identifying, researching, and resolving complex technical problems that enhance E*TRADE's business decision making capabilities. Your technical skills, business acumen, and creativity will be essential as you build tools to automate reporting and generate timely business insights.\nRESPONSIBILITIES:\nCollect and analyze data to support business partners, working closely with finance, product and operational leaders to understand their analytical needs and deliver rigorous analysis to drive business results.\nLeverage technology and critical thinking skills to continually innovate and automate existing methodologies, processes and reporting. Design, develop, test, and implement new approaches.\nPartner with Engineering teams to operationalize / scale data solutions to improve E*TRADE’s business intelligence and analytical platforms, such as querying, reporting and analytical tools\nLeverage SQL, Tableau, and other analytic platforms to gather, clean, and prepare data; create dashboards/reports; develop KPIs; analyze trends; provide insights\nIntegrate new tools, software, and technology to streamline processes, improve efficiency, and improve working methods and culture within the analytics team\nQualifications\nBASIC QUALIFICATIONS:\nBachelor’s degree in analytical, quantitative or STEM field\n4+ years of relevant experience\n4+ years of experience in data manipulation using SQL and other scripting languages development (advanced/expert level)\nFamiliarity with analytics methods/theory (statistics, ML, etc.) and analytical programs/tools (e.g., SAS, R, Python, etc.)\n3+ years of experience building and creating dashboards for business consumption, including synthesizing data in graphical format\n\nPREFERRED QUALIFICATIONS:\nExperience working in high data volume environments\nExcellent communication and relationship skills, especially ability to manage relationships with executive level stakeholders\nExperience with analytics projects, including modeling, tuning and productionizing solutions\n3+ years of working with statistical and analytical programs/tools such as SAS, R, Python\n2+ years of developing solutions using data tools (Hive, Hadoop, etc.)\n3+ year experience in designing and delivering data warehousing, business intelligence, and reporting solutions\nAbility to thrive in environments with multiple cross functional stakeholders with competing agendas by bringing people together to achieve a common goal\nExcellent stakeholder management skills including expectation setting, education, conflict management, prioritization, etc.\nHigh level of autonomy and initiative\nExperience in Finance or Financial Analysis\nWe offer a competitive and comprehensive benefits package. Please visit https://www.etradecareers.com/why-work-at-etrade/employee-benefits/ to learn more about the opportunities ...
# 169  Start a Rewarding Career with Alliant\nWhy Alliant?\n\nWe’re not a typical financial institution – we’re better. We’re an innovative, fun-loving, highly-engaged group of professionals that are committed to our company and the communities we do business in. We love to recognize and celebrate each other.\n\nOver 90% of our employees say we are a great workplace that is focused on our mission, vision and the future of banking.\n\nWhat will your day look like?\n\nYou will be responsible for ensuring marketing data accuracy and timeliness, to ensure the team can make real-time, data-driven decisions. The incumbent will work closely with marketing, product management, technology and finance teams to identify data capture requirements and create a technical implementation plan for an analytics solution across Marketing and Digital Channels web properties; configure reports within and pull reports from analytics platforms; maintain accuracy of analytics data; and perform measurement and reporting of web-based activity. The Marketing Analytics Specialist will have a deep understanding of analytics and analytics tools, and will have experience creating reports, setting benchmarks and developing tracking requirements, and will have proven experience with the technical implementation of an analytics platform. The incumbent will also be comfortable facilitating dashboarding in Tableau; developing a schema and taxonomy to ensure accurate cross-channel reporting; and troubleshoot reporting and analytics issues.\n\nResponsibilities\nDo you see yourself doing this?\n\nWork with development teams to integrate analytics requirements into development cycles, QA, etc.\nDefine analytics best practices\nFacilitate tracking of A/B testing through proper analytics setup\nEnsure analytics platform is set up in an optimal way for the needs to marketing and digital channels teams\nGather requirements and create automated reports across platforms\nCreate views, conversion goals, automated reports, etc.\nAct as subject matter expert on all things analytics; add and QA tags, triggers, etc., as needed\nWork with third-party vendors like ad agencies, SEO agencies, etc. to ensure accurate tracking and setup of analytics tools\nEnsure accurate tracking of keywords via SEO tool\nBuild reports in Tableau\nGather tracking requirements and make recommendation on analytics tools, features and capabilities\nAs needed, develop implementation plan for analytics tool\nDevelop a data schema and taxonomy to ensure accurate reporting across channels (organic, paid, social, email, etc.)\nDevelop and maintain benchmarks/KPIs across channels\nDocument policies, standards and procedures related to compiling data and reports\nEnsure accurate data capture of A/B and multivariate tests, personalization\nBuild roadmap for analytics optimization\nSupport performance marketing, business intelligence, product teams in defining data to be captured\nWork with Marketing Data Analyst and internal data teams to identify anomalies in data and fix reporting as necessary\nUnderstand business systems and data\nQualifications\nWhat makes you a great fit?\n\nYou’ll be a great fit if in addition to the completion of a Bachelor’s degree in marketing, finance, computer science or similar required, and you have:\n\n5+ years’ experience in highly analytical role within marketing, sales or e-commerce required\nProven experience with analytics tools such as Google Analytics, required\nProven experience with analytics tools aside from Google analytics (Adobe Analytics, IBM Unica NetInsight, etc.), required\nProven experience taking disparate data and organizing it into a format that is actionable, required\nExperience with other elements of the marketing tech stack including marketing automation tool, social media, SEO platform, CMS, etc.\nExperience with business systems analysis or data analytics / business intelligence requirements gathering\nExperience with Business Objects, Tableau and simila ...
#
# [170 rows x 12 columns]

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_DataAnalyst_Chicago.csv')
