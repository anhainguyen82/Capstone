# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Data+Analyst%22&l=Houston%2C+TX&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 343

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 343

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 79

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                          Title             Location  \
# 0   IT Business Analyst Intern                  Houston, TX 77010
# 1   Data Analyst                                Houston, TX
# 2   Data Analyst- MATLAB Developer              Houston, TX
# 3   Hospital Based Physicians-Data Analyst      Houston, TX
# 4   Data Analyst Clinically Integrated Network  Houston, TX 77002
# ..                                         ...                ...
# 74  Research Analyst, Behavioral Health         Houston, TX
# 75  Entry-Level Data Analyst / Economist        Cambridge, MA 02142
# 76  Data Analyst                                Houston, TX
# 77  Data Analyst I or II - Structured Finance   Houston, TX 77002
# 78  Customer - Data Analyst                     Houston, TX
#
#          City State         Zip     Country  \
# 0   Houston    TX    77010       None Found
# 1   Houston    TX    None Found  None Found
# 2   Houston    TX    None Found  None Found
# 3   Houston    TX    None Found  None Found
# 4   Houston    TX    77002       None Found
# ..      ...    ..      ...              ...
# 74  Houston    TX    None Found  None Found
# 75  Cambridge  MA    02142       None Found
# 76  Houston    TX    None Found  None Found
# 77  Houston    TX    77002       None Found
# 78  Houston    TX    None Found  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Qualifications  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# ..         ...
# 74  None Found
# 75  None Found
# 76  None Found
# 77  None Found
# 78  \nBachelor's degree in Computer Science, Social Science, Statistics, Data Science, Data Analytics, or Market Research.\n2-4 years of experience in similar roles.\nExperience in Omni-channel marketing analytics.\nProven analytic skills, including mining, evaluation, analysis, and visualization.\nTechnical writing experience in relevant areas, including queries, reports, and presentations.\nStrong SQL or Excel skills with the ability to learn other analytic tools.\nPrior experience with database and model design and segmentation techniques.\nPractical experience in statistical analysis using statistical packages including Excel, SPSS, MicroStrategy and SAS.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Skills  \
# 0   None Found
# 1   None Found
# 2   Strong experience in signal pre-processing techniques including signal de-noising, alignment, resampling, smoothing, reconstructing missing data, peak analysis, dynamic time warping, envelop extraction, harmonic distortion, band power, and bandwidth.Strong experience in signal processing techniques including FFT-based nonparametric methods, such as Welch's method or the periodogram, parametric and subspace methods, such as Burg's and Yule-Walker, and incorporating prior knowledge of the signal and yielding more accurate spectral estimates.Strong experience in signal filtering, probability, multi-dimensional random processes, wavelet analysis, and Kalman filtering techniques.Proficiency in system simulation packages including, Matlab, Simulink, SimscapeStrong expertise in C/C++/C#, Python and R is a must.Experience with DOE and real-time implementation.
# 3   None Found
# 4   Experience with the use of healthcare data (ambulatory, hospital, health plan, EHR, claims, billing, etc.) and the development of actionable and performance tracking reports.
# ..                                                                                                                                                                             ...
# 74  \nBoard Certified Behavioral Analyst preferred\nProgramming skills in SQL SAS or R\nStatistical Expertise\nProfessional writing skills for manuscripts and research reports\nExcellent communication skills both written and verbal.\nKnowledge of MS Office
# 75  \nStrong and adaptable research and analytical skills, including ability to interpret data and research, and write/produce structured, compelling reports\nStatistical / modeling experience, preferably in EViews\nExposure to Python and Power BI is a plus\nCoordination skills; ability to prioritize own workload and work to deadlines and under pressure\nExcellent English speaking and writing capabilities\nStrong team spirit
# 76  None Found
# 77  \nExcellent analytical and problem-solving skills\nStrong verbal and written communication skills\nExcellent attention to detail\nExercises independent judgment and multi-task oriented\nTakes initiative and ownership of job responsibilities\nMust be able to work well in a team environment\nMust be able to perform essential job duties accurately and timely\nMust adhere to deadlines and targets given\n
# 78  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Responsibilities  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# ..         ...
# 74  None Found
# 75  \nCompile global production, capital expenditure and capacity data from company reports and other sources\nCalculate endmarket demand factors for steel and other metals\nCreate and maintain a supply-demand forecast model for the global metals market\nWork on other research projects as needed
# 76  \nInterface with the Leadership team to analyze and explore opportunities to drive our key success metrics related to our customer support experience, cost, quality, efficiency, impact of improvements and continuous improvement\nUnderstand and analyze our customer life-cycle process, focusing on conversion, churn/retention, engagement, revenue drivers, up-sell opportunities, and overall health\nPartner closely with Customer Success teams by providing recommendations and insights to drive business outcomes on Self-Service, Customer Engagement and Health\nCreate, maintain and enhance CS reporting/dashboards with respect to (CS) forecast, retention, up-sell, overall health of the existing customer base\nEffective use of SQL and/or Tableau to complete ad-hoc analysis requests with the ability to visualize and present key insights that influence our decisions\nEffectively troubleshoot (Zendesk/Salesforce) system issues, performing Root Cause Analysis (RCA), and suggesting configuration improvements based on the disposition of the RCA
# 77  None Found
# 78  Identify trends and opportunities for growth through analysis of complex data sets.\nEvaluate organizational methods and provide source-to-target mappings and information-model specification documents for data sets.\nCreate best-practice reports based on data mining, analysis, and visualization.\nEvaluate internal systems for efficiency, problems, and inaccuracies, developing and maintaining protocols for handling, processing, and cleaning data.\nWork directly with management and users to gather requirements, provide status updates, and build relationships.\nSupport major Marketing initiatives through value added measurement that not only communicates results but can identify improvement actions.\nConduct testing and What If analysis to support business decisions.\nManages relationships with external suppliers of data and specialized analysis/research organizations.\nStitching together disparate pieces of data to form cohesive business cases for improvement.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                    Education  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   Bachelor’s Degree
# ..                ...
# 74  \nMaster’s Degree in Behavioral Sciences, Social Work or Psychology. Doctoral Degree preferred.\nMay substitute required education with equivalent years of experience beyond the minimum experience requirement.
# 75  \nStrong and adaptable research and analytical skills, including ability to interpret data and research, and write/produce structured, compelling reports\nStatistical / modeling experience, preferably in EViews\nExposure to Python and Power BI is a plus\nCoordination skills; ability to prioritize own workload and work to deadlines and under pressure\nExcellent English speaking and writing capabilities\nStrong team spirit
# 76  None Found
# 77  None Found
# 78  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Requirement  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# ..         ...
# 74  None Found
# 75  None Found
# 76  \nMinimum 3+ years in an analyst (Business/Data) function, preferably in a Customer Success environment\nPrior knowledge/experience with Salesforce/Tableau/Zendesk\nHigh degree of professionalism, as this role will require heavy interaction with leadership at all levels\nStrong mathematical, analytical and organization skills\nStrong proficiency with MS Office (Excel and Powerpoint)\nMust have strong communication, interpersonal and presentation skills. Self-motivated and must excel in a minimally managed, high profile position
# 77  None Found
# 78  None Found
#
# ...
# 76  About Bill.com\n\nBill.com is a leader in financial process automation for small businesses and mid-size companies. Making it simple to connect and do business, the Bill.com Back Office Cloud digitizes, automates and simplifies legacy payment and financial processes. With an integrated, end-to-end platform, Bill.com leverages artificial intelligence to reduce manual work, and provides a cloud workspace to help run your business anytime, anywhere. The company partners with four of the largest U.S. financial institutions, more than 70 of the top 100 U.S. accounting firms, and major accounting software providers. Bill.com manages more than $70B in annual payment volume across ACH, virtual cards, checks, and international payments. The company has offices in Palo Alto, California and Houston, Texas. For more information, visitwww.bill.com or follow @billcom.\n\nMission: We are turning our Customer Success (CS) organization into a competitive force, evolving beyond great operational execution towards customer experience, advocacy and moving to become a key differentiator in our industry. We’re looking for a Data Analyst who can dive in, research and gather insights, digest findings, and deliver potential strategies the organization can pursue; This is a key analytical role reporting to the Director, Customer Success Operations.\nResponsibilities:\nInterface with the Leadership team to analyze and explore opportunities to drive our key success metrics related to our customer support experience, cost, quality, efficiency, impact of improvements and continuous improvement\nUnderstand and analyze our customer life-cycle process, focusing on conversion, churn/retention, engagement, revenue drivers, up-sell opportunities, and overall health\nPartner closely with Customer Success teams by providing recommendations and insights to drive business outcomes on Self-Service, Customer Engagement and Health\nCreate, maintain and enhance CS reporting/dashboards with respect to (CS) forecast, retention, up-sell, overall health of the existing customer base\nEffective use of SQL and/or Tableau to complete ad-hoc analysis requests with the ability to visualize and present key insights that influence our decisions\nEffectively troubleshoot (Zendesk/Salesforce) system issues, performing Root Cause Analysis (RCA), and suggesting configuration improvements based on the disposition of the RCA\nRequirements:\nMinimum 3+ years in an analyst (Business/Data) function, preferably in a Customer Success environment\nPrior knowledge/experience with Salesforce/Tableau/Zendesk\nHigh degree of professionalism, as this role will require heavy interaction with leadership at all levels\nStrong mathematical, analytical and organization skills\nStrong proficiency with MS Office (Excel and Powerpoint)\nMust have strong communication, interpersonal and presentation skills. Self-motivated and must excel in a minimally managed, high profile position\nHighly Preferred:\nSalesforce or Zendesk admin certification\nCertified Tableau Associate/Professional\nKey Milestones within 30 days:\nFull functional understanding of Bill.com’s products and services\nFunctional understanding of key CS functions and how they interact it with customers/partners\nAssessment of key business and operational metrics, pertaining to CS\nStrong understanding of our systems and tools\nWithin 90 days:\nAbility to develop actionable plans with the ability to measure success from thorough data analysis\nStrong understanding of weekly/monthly/quarterly trends and areas for improvement on SLAs, CSAT, NPS, and Churn drivers\nDevelop solid working relationships with other key teams\nBe a subject matter expert/administrator of Zendesk/Salesforce\nWithin 120 days:\nStrong understanding of customer contact volume trends and the ability to analyze, communicate and execute based off those trends for efficiency improvements\nFully understand Bill.com’s strategy for key fiscal year initiatives\nContinually re-e ...
# 77  Position can be level I or II depending on the candidate's experience.\n\n\nMonitors and manages large volumes of transactions, updates data in systems and performs reconciliations on a daily basis. Assists with various tasks related to deal management. Communicates with internal and external parties, regarding deal-specific items.\n\nPrepares daily reconciliation of cash transactions\nManages large volumes of transactions and monitors account balances\nActively researches discrepancies with various agents and clients\nLiaison with counterparts to ensure accuracy of transaction flow and follows up on outstanding issues\nProactively and effectively communicates with clients, as needed\nProcesses and reconciles data in various systems\nWorks closely with others to resolve issues effectively and timely\nPrepares various reports needed by internal employees and handles client requests relating to cash management\nActively monitors securities settlement process and initiates resolution within scope of authority, as needed\nAssists in monthly report preparation\nPrepares deal hypotheticals, as needed\nOther duties as assigned by Management\n\n\nRequired Skills\n\n\nTechnical or Administrative Knowledge:\n\nHighly proficient in Microsoft Suite\nBasic Bloomberg knowledge desired\nBasic knowledge of securities\nSpecial Skills and/or Abilities:\n\nExcellent analytical and problem-solving skills\nStrong verbal and written communication skills\nExcellent attention to detail\nExercises independent judgment and multi-task oriented\nTakes initiative and ownership of job responsibilities\nMust be able to work well in a team environment\nMust be able to perform essential job duties accurately and timely\nMust adhere to deadlines and targets given\n\n\nRequired Experience\nBachelor’s Degree required\nMinimum 3 years experience in Accounting or Finance                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 78  Equal Opportunity Employer: Minority/Female/Disability/Veteran\n\n\nWaste Management (WM), a Fortune 250 company, is the leading provider of comprehensive waste and environmental services in North America. We are strongly committed to a foundation of operating excellence, professionalism and financial strength. WM serves nearly 25 million customers in residential, commercial, industrial and municipal markets throughout North America through a network of collection operations, transfer stations, landfills, recycling facilities and waste-based energy production projects.\n\n\nThe Enterprise Analytics & Data Management team is part of the Waste Management’s Digital organization. Our mission is to accelerate business growth and drive operational efficiencies by extracting insights from data, predicting business outcomes and embedding intelligence into business processes. As a member of EADM you will deliver insights and solutions across the organization in areas such as routing, logistics, revenue management, customer experience, people analytics, business operations and more.\nWe are currently seeking a Customer Data Analyst.\n\n\nI. Job Summary\n\nThe Customer Data Analyst will provide insight beyond fact-based reporting and will interpret results in the context of the business environment. The ability to turn data into compelling narratives that resonate with the customer is a key aspect of this role.\nThe ideal candidate should be highly skilled in all aspects of data analytics, including mining, generation, and visualization. Additionally, S/he should be committed to transforming data into readable, goal-driven reports for continued innovation and growth.\n\n\nII. Essential Duties and Responsibilities\n\nTo perform this job successfully, an individual must be able to perform each duty satisfactorily. Other ancillary duties may be assigned.\nIdentify trends and opportunities for growth through analysis of complex data sets.\nEvaluate organizational methods and provide source-to-target mappings and information-model specification documents for data sets.\nCreate best-practice reports based on data mining, analysis, and visualization.\nEvaluate internal systems for efficiency, problems, and inaccuracies, developing and maintaining protocols for handling, processing, and cleaning data.\nWork directly with management and users to gather requirements, provide status updates, and build relationships.\nSupport major Marketing initiatives through value added measurement that not only communicates results but can identify improvement actions.\nConduct testing and What If analysis to support business decisions.\nManages relationships with external suppliers of data and specialized analysis/research organizations.\nStitching together disparate pieces of data to form cohesive business cases for improvement.\nIII. Supervisory Responsibilities\nNone required.\n\n\nIV. Qualifications\nThe requirements listed below are representative of the qualifications necessary to perform the job.\n\nBachelor's degree in Computer Science, Social Science, Statistics, Data Science, Data Analytics, or Market Research.\n2-4 years of experience in similar roles.\nExperience in Omni-channel marketing analytics.\nProven analytic skills, including mining, evaluation, analysis, and visualization.\nTechnical writing experience in relevant areas, including queries, reports, and presentations.\nStrong SQL or Excel skills with the ability to learn other analytic tools.\nPrior experience with database and model design and segmentation techniques.\nPractical experience in statistical analysis using statistical packages including Excel, SPSS, MicroStrategy and SAS.\n A. Domain Experience\nExperience analyzing customer data to support the acquisition of customer, cross-selling, customer retention, customer experience, and customer lifetime value.\nExperience in digital analytics / customer analytics / omni-channel analytics with a demonstrated track record of results  ...
#
# [79 rows x 12 columns]

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_DataAnalyst_Houston.csv')
