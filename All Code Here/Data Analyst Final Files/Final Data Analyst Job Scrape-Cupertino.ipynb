# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Data+Analyst%22&l=Cupertino%2C+CA&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 313

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 313

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 178

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                          Title  \
# 0    Digital Marketing Data Analyst
# 1    Business Analyst
# 2    Data Analytics Teaching Assistant - UC Berkeley (Belmont)
# 3    Software Engineer
# 4    Assessment & Evaluation Associate
# ..                                 ...
# 173  Technology Data Analyst : 19-04186
# 174  Data Analyst
# 175  Data Analytics Instructor - UC Berkeley (Belmont)
# 176  Sales Operations Analyst
# 177  Finance Business Intelligence Analyst
#
#                     Location           City State         Zip     Country  \
# 0    Mountain View, CA 94043  Mountain View  CA    94043       None Found
# 1    Santa Clara, CA          Santa Clara    CA    None Found  None Found
# 2    Belmont, CA              Belmont        CA    None Found  None Found
# 3    San Mateo, CA 94402      San Mateo      CA    94402       None Found
# 4    Stanford, CA             Stanford       CA    None Found  None Found
# ..            ...                  ...       ..           ...         ...
# 173  San Jose, CA 95125       San Jose       CA    95125       None Found
# 174  Mountain View, CA        Mountain View  CA    None Found  None Found
# 175  Belmont, CA              Belmont        CA    None Found  None Found
# 176  Palo Alto, CA            Palo Alto      CA    None Found  None Found
# 177  Mountain View, CA        Mountain View  CA    None Found  None Found
#
#     Qualifications  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    None Found
# ..          ...
# 173  None Found
# 174  None Found
# 175  None Found
# 176  None Found
# 177  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Skills  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    None Found
# ..          ...
# 173  Understand Client's tax data and related systems.\nFacilitate automation within the tax team, through tax reporting, dashboarding utilizing your deep analytical skills using tools such as SQL, Adaptive.\nIdentify opportunities to streamline use of data, identify process improvements and coordinate with the finance and tax team on increasing efficiencies through technology.\nCommunicate effectively across teams regarding priorities, status and delivery.\nDevelop and implement KPIs for ongoing tax reporting metrics and special projects.\n
# 174  None Found
# 175  \nPython Pandas\nMatplotlib\nBeautiful Soup\nJavaScript\nHTML5\nCSS3\nD3\nLeaflet\nSQL, noSQL\nTableau\nMachine Learning, Hadoop\n
# 176  None Found
# 177  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Responsibilities  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    Research, design, and update computer programs to build and maintain the Company’s interactive on-line new media platform\nWork with the UI/UX designer to modify the user interface of the company’s interactive online new media platform\nImplement the whole platform on AWS.\nInvolved in backend coding based on user’s information, retrieve, store and analyze user’s data, provide suggestions on improvement\nWork with data analyst to develop the information analysis system based on users’ data（age, gender, education level, etc. to determine the demographics of users of Tech Trends Inc.) using Python and SQL.\nPrepare test plans, write Unite Test to improve the efficiency of basic tests, verity accuracy and validity of programs\nCompile and document the program development and subsequent revisions, insert comments on the coded instructions so other contract software developers can understand the program.\nPerform search engine analysis and conduct search engine optimization and marketing to improve website traffic for the purpose of attracting potential advertising clients.\n
# 4    None Found
# ..          ...
# 173  None Found
# 174  \nBuild and maintain critical data infrastructure for People Development including back-end data tables, data pipelines, and dashboards.\nManipulate and analyze large data sets to distill insights from data and convey findings to executive audiences.\nWork across People Development teams and understand all People Development data including learning programs, evaluation strategies, education reimbursements, and talent management.\nPartner with People Development teams to gain a rich understanding of business processes, analytical and reporting needs and gaps.\nCollaborate with partner Business Intelligence and Analyst teams, ensuring our solutions and analysis support POps, while also looking for innovative opportunities to drive big insights and impact.\n
# 175  None Found
# 176  None Found
# 177  None Found
#
#       Education  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    None Found
# ..          ...
# 173  None Found
# 174  None Found
# 175  None Found
# 176  None Found
# 177  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Requirement  \
# 0    None Found
# 1    None Found
# 2    \nPython Pandas\nMatplotlib\nBeautiful Soup\nJavaScript\nHTML5\nCSS3\nD3\nLeaflet\nSQL, noSQL\nTableau\nMachine Learning, Hadoop\n
# 3    Python, Django, React and AWS\nPHP, MySQL, Python, Assembly\nLinux, CodeIgniter (MVC), Wireshark, OPNET, MATLAB\nKnowledge of C, C++, C#, and Java;\nSkill with Haskell, or JavaScript\nRelational databases and SQL;\nSoftware development tools: Code editors (VIM or Emacs), and revision control systems (Subversion, GIT, or Perforce)\nCore web technologies: HTML, CSS, RESTful API.\nData processing, programming languages, databases, networking, operating systems, computer graphics, or human-computer interaction.\nApplying algorithms and core computer science concepts to real world systems\nFluent in Both English and Chinese Mandarin
# 4    None Found
# ..          ...
# 173  Understand Client's tax data and related systems.\nFacilitate automation within the tax team, through tax reporting, dashboarding utilizing your deep analytical skills using tools such as SQL, Adaptive.\nIdentify opportunities to streamline use of data, identify process improvements and coordinate with the finance and tax team on increasing efficiencies through technology.\nCommunicate effectively across teams regarding priorities, status and delivery.\nDevelop and implement KPIs for ongoing tax reporting metrics and special projects.\n
# 174  None Found
# 175  \nBachelor's Degree\nMinimum of 5 years of work experience\nA positive attitude\nAbility to deliver our lesson plans that are taught in classrooms across the country to the student body\nShare your own professional experiences and industry insight with the students\nSupport our students individually as they go through an emotional roller coaster\nBe able to infuse empathy, support, encouragement, and fun into the student experience\n
# 176  None Found
# 177  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0    Synopsys is looking for an experienced Data Analyst who will lead the development and execution of fact-based reporting, analysis and analytical models used to enhance decision making across the marketing function. This role will support the organization with insights used to produce improved results.\nResponsibilities\nLead efforts to define and implement frameworks for measuring, reporting and analyzing marketing results\nCreate and maintain appropriate marketing key performance indicators and ROI models for marketing campaigns to determine effectiveness\nDevelop dashboards and standardized reports to provide ongoing insight to marketing stakeholders, then work to ensure utilization and adoption of reporting by these stakeholders\nDevelop data processes, integrate data from various sources, perform audits, update analytics configurations and improve data quality to support marketing analytics and enhance business intelligence\nEffectively integrate, analyze and mine both structured and unstructured data from a variety of sources to drive product centric as well as user centric insights\nEnsure analytics data is flowing through various stages of digital customer journeys using a variety of tools including Adobe Analytics, Adobe Dynamic Tag Management (DTM), Adobe Target, Audience Manager, etc.\nDevelop multi-touch attribution methodologies to assess effectiveness of multi-vehicle marketing campaigns\nRespond to ad hoc data and analytics requests from business leaders\nPerform weekly and monthly analyses of KPIs for business leads\nRequirements\nBachelor's degree in Marketing, Computer Science, Data Management, or similar technical discipline\n4+ years of experience in web analytics-focused roles, with experience in digital marketing analytics capture and reporting a plus\n3+ years of hands-on experience with reporting tools (i.e. Adobe Analytics, Tableau, Domo, Adobe Insights, etc.)\nExperience in creating polished, repeatable and actionable dashboards and reports\nExperience building and running multi-touch attribution framework for Growth channels and campaigns\nExperience with relational and un-structured databases is a plus\nExperience with Python, R and Statistical modeling is a big plus\nFamiliarity with leading marketing technologies and tools such as Google Analytics, DMPs, DTMs, automation, etc.\nAbility to convey complex information simply and clearly to Sr. business leaders and executives and to effectively communicate with business, marketing and engineering teams\nExcellent verbal and written communication skills with the ability to work cross-functionally\n#LI-DNI\n\nJob CategoryBusiness Development\nHire Type\n\nEmployee\n\nCountryUnited States                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 1    Abbott is a global healthcare leader that helps people live more fully at all stages of life. Our portfolio of life-changing technologies spans the spectrum of healthcare, with leading businesses and products in diagnostics, medical devices, nutritionals and branded generic medicines. Our 103,000 colleagues serve people in more than 160 countries.\nJob Description\nThe Business Analyst plans and performs business process reviews at a department or company level.\nResponsibilitiesIdentifies opportunities to improve the efficiency and effectiveness of the systems and process being examined (process improvement/reengineering projects).Evaluates internal control systems and recommends improvements in controls (control projects).Works with the co-sourcing partners to plan the project, draft project reports and conduct the fieldwork, which includes interviews, process flow determination, critical analysis of activities as value added/non-value added, financial analysis, system data analysis and transaction testing.Administers the project time, budgeting and reporting and coordination of team schedules.Participates in special projects as they arise, including compliance reviews, financial audits, and due diligence reviews.Begins establishing and cultivating a network of internal resources to facilitate completion of tasks.Individual influence is typically exerted at the peer level.Completes daily work to meet established schedule with guidance from supervisor on prioritization of tasks.May exercise authority within pre-established limits and approval.\nQualifications\nBachelors Degree and 0-2+ years experience or an equivalent combination of education and experience.\nExperience/skills\nMinimum 2 years related work experience with a basic understanding of specified functional area.\nGeneral knowledge and basic application of business concepts, procedures and practices.\nWill perform this job in a quality system environment.\nFailure to adequately perform tasks can result in noncompliance with governmental regulations.\nLearns to use professional concepts and company policies and procedures To solve routine problems. Works on problems of limited scope.\nMinimal independent decision making.\nNO RELOCATION ASSISTANCE IS AVAILABLE FOR THIS POSITION.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 2    Trilogy Education partners with universities to offer programs in Web Development, Data Analytics, UX/UI Design, and Cybersecurity. Our platform combines a market-driven curriculum, robust career services, and a multinational community of universities, instructors, and employers to prepare adult learners for careers in the digital economy.\n\nThe Job:\nTrilogy Education is seeking an experienced Data Analyst who has a passion for teaching individuals how to code. Our students have a diverse background, from working professionals to fresh-out-of-college people who seek to transition into careers in web development positions.\n\nWhy teach why us?\n\nInstructors lead classroom discussions, guide inquiry, emphasize the meta-skills and core concepts, support students in their projects and challenges, and provide feedback to students and teaching assistants.\n\nYou don't have to have a ton of experience instructing! You just have to be a lifelong learner, proven teacher or mentor and love to help people change their lives and succeed.\n\nWhat You Will Do:\n\nTake attendance at the start of class via Bootcampspot\nEnsure the Instructor is staying on track with regards to time\nWalk around class during code activities and projects to assist students\nResearch and answer student questions when the instructor is unable to\nGrade all homework assignments\n\nWhat makes your a great fit (Requirements):\nProficient in the following languages:\n\nPython Pandas\nMatplotlib\nBeautiful Soup\nJavaScript\nHTML5\nCSS3\nD3\nLeaflet\nSQL, noSQL\nTableau\nMachine Learning, Hadoop\n\nPay is commensurate with experience for this contract role.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# ...
# 175  Trilogy Education partners with universities to offer programs in Web Development, Data Analytics, UX/UI Design, and Cybersecurity. Our platform combines a market-driven curriculum, robust career services, and a multinational community of universities, instructors, and employers to prepare adult learners for careers in the digital economy.\n\nOur programs have been in existence since 2015, and since then, we've launched an additional 300 classes across the nation. We have hired more than 1,900 Instructors and Teaching Assistants to support our students.\n\nThe Job:\nWe are looking for an experienced Data Analyst to teach our part time Data Analytics and Visualization class at UC Berkeley. Our instructors are an essential piece to our students experience with us. You must bring a positive attitude and be able to infuse empathy, support, encouragement and fun into the classroom. As an instructor you will need to have the ability to deliver our lesson plans that are being taught across the country; while at the same time, sharing your own professional experiences and industry insight with the students.\n\nOur Data Analytics and Visualization Program:\nFor too many companies, Big Data isn't the solution to a problem—Big Data is the problem. The Data Analytics and Visualization course provides learners with the knowledge, skills, and expertise to turn data into insights, and into actionable recommendations to improve processes and drive company growth. Starting with Microsoft Excel⎼and advancing through Python, JavaScript, HTML/CSS, API Interactions, Social Media Mining, SQL, Hadoop, Tableau, Advanced Statistics, Machine Learning, R, Git/GitHub, and more⎼students work their way through the industry's most popular programming languages, software, and libraries in data analytics.\n\nWhy teach with us?\n\nAre you passionate about education and making an impact? Do you love empowering others to find life-changing opportunities. We'd love to hear from you! If you bring knowledge, strong communication, and a positive energy to the classroom, you're going to help our students along their transformative path to a successful and rewarding career. Prior teaching experience isn't a prerequisite for success as an Instructor or Teaching Assistant within Trilogy.\n\nWe'll provide the guidance, training, lesson plans, and tools to support you on your journey of impacting lives in the classroom.\n\nWhat You Will Do:\n\nLead lectures and educational coding activities\nAnswer questions from the stage\nWalk around the classroom during coding activities and in-class projects to assist the students, as needed\nEnsure Panopto is turned on and actively recording the class lecture to help us continuously improve\nUpload all class content to Students Git Repository\nCreate Homework Assignments in Bootcampspot\nEnsure that homework is graded on-time; and occasionally assist with grading\n\nTechnology Language Skills:\n\nPython Pandas\nMatplotlib\nBeautiful Soup\nJavaScript\nHTML5\nCSS3\nD3\nLeaflet\nSQL, noSQL\nTableau\nMachine Learning, Hadoop\n\nWhat makes you a great fit (Requirements):\n\nBachelor's Degree\nMinimum of 5 years of work experience\nA positive attitude\nAbility to deliver our lesson plans that are taught in classrooms across the country to the student body\nShare your own professional experiences and industry insight with the students\nSupport our students individually as they go through an emotional roller coaster\nBe able to infuse empathy, support, encouragement, and fun into the student experience\n\nLogistics:\n\n24-week program\nMon/Wed/Sat OR Tue/Thu/Sat Schedule\nWeekday Classes: 5:45pm - 10pm (includes office hours and break)\nSaturday Classes: 9:30am - 2:30pm (includes office hours and lunch break)\nzr\n\n                                                                                                                                                                                                                                 ...
# 176  The Sales Operations Analyst supports functions essential to sales organization productivity. Reporting to the Senior Director, Sales Operations, this individual will:\n\nResponsibilities\n\n\nPerform analysis activities for sales operations providing data driven insights.\nAttend forecast meetings and publish forecast reports.\nProvide first level of support, manage and resolve inquiries on quotes and process from Sales and Account Management teams.\nMaintain and enhance CRM functionality including data entry, ad hoc reporting, communicate new processes and updates to Sales staff.\nCoordination of resources for sales events, meetings, and non marketing coordinated functions.\nReview Non-Standard Pricing requests and provide deal analysis to upper management.\nGenerate forecast and metric reports & provide analysis for Sr. Dir, Sales Operations\nPartner with Sales Management on business planning and strategy for their respective sales areas.\nSetup, maintain, and modify sales territories and provide comprehensive analysis.\nAssist in administering of compensation plans.\nDevelop a working partnership with the sales and account team members.\nPrepare presentations based on Sales Management objectives.\nOther projects and initiatives as necessary .\n\nRequirements\n\n\nBachelor Degree\nExperience as business or sales analyst\nDemonstrate excellent communication and teamwork\nExceptionally strong project management, process development, and interpersonal collaboration skills\nExcellent working knowledge of Google Sheets / Google Slides\nExcellent knowledge of CRM & analysis tools (HubSpot, SFDC, Tableau, Domo)\nMust be able to excel in a dynamic, fast-paced environment with changing objectives and ambiguous situations\nStrong self-drive with problem solving mindset and strong sense of curiosity.\n\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ...
# 177  Waymo is the self-driving technology company with a mission to make it safe and easy for people and things to move around. Building on software and sensor technology developed at Google, Waymo is now launching the world’s first fully self-driving transportation service that will take members of the public from A to B at the touch of a button.\n\nOur cars may be self-driving, but Waymo’s finances are steered by experts like you. The Finance and Accounting group manages all aspects of our finances and serves as trusted advisors for all our strategic and enterprise endeavors. Along with managing compilation of our financial statements, looking after our cash and overseeing compliance, we partner closely with the business in overseeing company wide resource allocation, developing cutting edge compensation initiatives and generating detailed financial analyses to drive the business forward. We also develop advanced capital strategies to support the company’s short- and long-term future.\n\nIn this role, you'll:\n\nBe a technical lead for multiple BI projects including requirement gathering, planning, development, implementation, stakeholder management and on-going support\n\nWork closely with business teams to understand their information needs and ensure the solutions we develop and deliver are an excellent fit to their evolving needs\n\nApply proven expertise to build production quality reporting and analytics solutions, balancing performance and usability\n\nDesign, build and launch accessible, reliable dashboards that provide actionable insights across cross-functional teams\n\nOwn the end-to-end solution, partnering with data engineering to productionalize ETL pipelines / reporting and business users to ensure fit for purpose end solutions\n\nContribute to the tactical and strategic development of Waymo’s BI Infrastructure including the Business applications interfaces, Data Warehouse and reporting applications\n\nAt a minimum we'd like you to have:\n\nA passion for data and helping others to use it! Genuine excitement for analyzing large and complex data sets and converting them into the information which drive business decisions\n\nBachelors in a quantitative or STEM discipline (e.g., Computer Science, Information Systems, Statistics, Economics), or 8+ years of relevant work experience in data analysis\n\nIntermediate/Advanced SQL; strong database development and query knowledge including proficiency in SQL coding across standard relational environment (e.g., Oracle, Teradata, etc.)\n\nProven experience with code collaboration, version control (e.g., Git) and bringing solutions all the way from requirements gathering through to production\n\nAbility to navigate ambiguity, drive solutions forward, and bring stakeholders along\n\nDistinctive problem solving and analytical skills with a high degree of analytical rigour; capability of managing multiple projects and reporting simultaneously across different groups\n\nIt's preferred if you have:\n\nExperience with front end reporting tools such as Tableau, Data Studio, QlikView, and other industrial reporting and analysis platforms a strong plus\n\nData exploration & analysis experience using popular statistical packages such as R or Python                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
#
# [178 rows x 12 columns]

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_DataAnalyst_Cupertino.csv')
