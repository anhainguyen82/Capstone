# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Data+Analyst%22&l=Denver%2C+CO&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 330

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 330

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 120

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                 Title             Location        City State  \
# 0    Data Analytics Lead (Marketing)   Englewood, CO 80110  Englewood   CO
# 1    GIS Data Analyst                  Denver, CO           Denver      CO
# 2    Professional Research Assistant   Aurora, CO           Aurora      CO
# 3    Business Intelligence Analyst II  Denver, CO 80014     Denver      CO
# 4    Data Analyst, Field Operations    Englewood, CO        Englewood   CO
# ..                              ...              ...              ...   ..
# 115  Sr. Data Analyst                  Denver, CO 80202     Denver      CO
# 116  Digital Marketing Strategist      Denver, CO           Denver      CO
# 117  Sales Data Analyst                Aurora, CO 80014     Aurora      CO
# 118  Data Analyst, Data Configuration  Denver, CO 80202     Denver      CO
# 119  Medical Economics Analyst         Centennial, CO       Centennial  CO
#
#             Zip     Country  \
# 0    80110       None Found
# 1    None Found  None Found
# 2    None Found  None Found
# 3    80014       None Found
# 4    None Found  None Found
# ..          ...         ...
# 115  80202       None Found
# 116  None Found  None Found
# 117  80014       None Found
# 118  80202       None Found
# 119  None Found  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Qualifications  \
# 0    \nA strategic and innovative thinker who is agile and possesses business-focused mindset.\n4+years with SQL and database skills in SQL.\nStrong Google suite skills – Docs, Sheets, Slides, etc.\nProficiency in SAS, Tableau and/or other complex analytical tools a strong plus.\nExperience in analyzing data and providing recommendations; ability to train and mentor junior members on the team is a strong plus.\nBS, BA or equivalent in Economics, Statistics, Math, Computer Science or related fields required; MBA or MS in Statistics, Math or related fields a plus; or combination of education and relevant work experience
# 1    Prefer bachelor's degree in Graphic Information Systems (GIS), Computer Science, or related Geoscience discipline\n2+ years of experience in GIS database operations preferably in the Oil and Gas Industry.\nStrong knowledge and working experience with GIS automated mapping, spatial information processing systems, methods and techniques.\nKnow the principals and practices of cartography and automated mapping, map projections & coordinate systems.\nGeneral knowledge of the Oil and Gas Industry and terminology related but not limited to land acreage, well databases, and well plan maps.\nFamiliarity with Drilling Info web based platform and other state Oil and Gas commissions and databases.\nCritical thinker with the ability to solve problems independently, demonstrate innovative approach.\nDetail oriented -needs to be organized, responsible and detail orientated. Skill to perform work accurately and thoroughly with devotion to detail.\nProactive - must be able to rapidly, concisely, and aggressively manage up to ensure critical issues are escalated to management, resolved, and acted upon before there is impact on the organization.\nAbility to prioritize - must be able to prioritize a lot of dissimilar issues across multiple project and offer guidance to other resources on what is most important, and also escalate critical issues to management for follow-up action.\nAbility to meet deadlines - must be able to hit critical deadlines by a certain time without exception.
# 2    Minimum of Bachelor's degree or equivalent in biological or health-related Field.Minimum of 2 years of experience adhering to research or clinical protocols.Available to work on Monday-Friday as early as 7:00 am on rare occasions when needed.Valid driver's license, reliable personal transportation and the ability to travel overnight for investigator meetings.Experience with conducting the Informed Consent Process.COMIRB and HIPAA requirement for researchers must be met during week 1 of employment.Must abide by hospital, University, local, state, and national regulations regarding human subject research.
# 3    \nBachelor's degree in STEM, Business, Economics, or related field or equivalent work experience\n2-4 years' experience as a Business Intelligence Analyst, Data Analyst, and/or Reporting Analyst\n2+ years' experience in development, design, and implementation with Qlik Sense or similar BI platform such as Tableau, Looker, PowerBI, etc.\nIntermediate SQL skills and experience with creating de-normalized or star-schema database models\nIntermediate programming/scripting skills (Python, R, VBA, and JavaScript a plus)\nIntermediate to Advanced Microsoft Excel skills (e.g., nested logical and lookup functions, pivot tables, macros)\nUnderstanding of statistics and analytical techniques, such as linear regressions, time series analysis, etc.\nDemonstrated problem-solving and analytical skills with open-ended problems\nAbility to work independently and in a cross-functional team environment\nPositive attitude, strong work ethic, time-management skills, and ability to communicate effectively with internal and external teams\nVery detail-oriented and highly organized\nLeadership and/or Project Management skills a plus\nUnderstanding of IT asset management, networking equipment, and contract management a plus
# 4    None Found
# ..          ...
# 115  None Found
# 116  None Found
# 117  \nRTD EcoPass which can be used seven days a week. We are across the street from Iliff Light Rail Station.\nDiscount Home Warranty program.\nOn-site fitness center in Aurora.\nModern and professional work environment.\nMany great events such as Monthly Social Gatherings, Social Responsibility Events, Jeans Days, and on-site food trucks (typically 2–3 days a week).
# 118  None Found
# 119  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Skills  \
# 0    \nA strategic and innovative thinker who is agile and possesses business-focused mindset.\n4+years with SQL and database skills in SQL.\nStrong Google suite skills – Docs, Sheets, Slides, etc.\nProficiency in SAS, Tableau and/or other complex analytical tools a strong plus.\nExperience in analyzing data and providing recommendations; ability to train and mentor junior members on the team is a strong plus.\nBS, BA or equivalent in Economics, Statistics, Math, Computer Science or related fields required; MBA or MS in Statistics, Math or related fields a plus; or combination of education and relevant work experience
# 1    None Found
# 2    None Found
# 3    \nBachelor's degree in STEM, Business, Economics, or related field or equivalent work experience\n2-4 years' experience as a Business Intelligence Analyst, Data Analyst, and/or Reporting Analyst\n2+ years' experience in development, design, and implementation with Qlik Sense or similar BI platform such as Tableau, Looker, PowerBI, etc.\nIntermediate SQL skills and experience with creating de-normalized or star-schema database models\nIntermediate programming/scripting skills (Python, R, VBA, and JavaScript a plus)\nIntermediate to Advanced Microsoft Excel skills (e.g., nested logical and lookup functions, pivot tables, macros)\nUnderstanding of statistics and analytical techniques, such as linear regressions, time series analysis, etc.\nDemonstrated problem-solving and analytical skills with open-ended problems\nAbility to work independently and in a cross-functional team environment\nPositive attitude, strong work ethic, time-management skills, and ability to communicate effectively with internal and external teams\nVery detail-oriented and highly organized\nLeadership and/or Project Management skills a plus\nUnderstanding of IT asset management, networking equipment, and contract management a plus
# 4    None Found
# ..          ...
# 115  None Found
# 116  None Found
# 117  \nRTD EcoPass which can be used seven days a week. We are across the street from Iliff Light Rail Station.\nDiscount Home Warranty program.\nOn-site fitness center in Aurora.\nModern and professional work environment.\nMany great events such as Monthly Social Gatherings, Social Responsibility Events, Jeans Days, and on-site food trucks (typically 2–3 days a week).
# 118  \nExperience working with large data sets\nExperience working with Healthcare data in all forms\nExcellent verbal and written communication skills\nExcellent team collaboration skills\nAbility to accurately determine data quality and define best programming practices as it relates to Healthcare data\nFamiliarity with data transfer methods (e.g. FTP, SFTP, FTPS) and Encryption methods (e.g. PGP, GPG. ASC)\nCreative problem solving.
# 119  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Responsibilities  \
# 0    \nLeverage SQL development skills to perform full-lifecycle data mining activities including requirements analysis, data quality assessment, data profiling, design and development of analytic data sets, data extraction, transformation, and loading (ETL) from both relational databases and flat-file sources.\nWork with internal clients to understand requirements and potential uses for predictive models, descriptive models, and marketing reports.\nProvide analytical support for strategy development, measurement design, and post-campaign analysis.\nProvide support for ad-hoc analytical projects, including customer-level analysis, segmentation analysis, product affinity, and customer profiling analysis.\nWork with unstructured data sets and cleanse that data to make recommendations, using various tools like Redshift, Teradata, Tableau, and SQL server.#LI-JS1\n
# 1    None Found
# 2    None Found
# 3    \nWork with internal and external teams to collect, analyze, and report data to meet customer/business needs\nUse Excel and other tools to mine, explore, clean up, organize, and do initial analysis on large data sets\nCreate ETL process and data models to achieve desired outcome, primarily using Qlik Sense scripting\nCreate dashboards, stories, and processes primarily using Qlik Sense\nWork with Project Managers and others to explore problems and conduct data analysis\nPerform exploratory data analysis and audit reports to locate and resolve errors and discover actionable insights\nGather and build requirements documents and task out projects\nMaintains internal data sets and tables within tools or standard templates\nDrive implementation, training, and adaptation of tools and reports\nInteract with and proactively communicate with teams regarding issues and new ideas\nSupport tools and processes for data analysis and reporting\nDocument standards and procedures when creating reports\nUse advanced analytical techniques when required\nOther duties as assigned
# 4    \n4 Year College Degree in Business, Mathematics, Finance, Economics, or Management Information Systems\n1-2 years of experience in data analysis or data management preferred\nWorking knowledge of SQL (PostgreSQL, Oracle, and/or Microsoft SQL Server)\nAttention to detail and accuracy\nEffective interpersonal and relationship building skills to effectively work with teammates and business partners\nMilitary education or experience may be considered in lieu of civilian requirements listed
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
# 115  None Found
# 116  \nBecome the primary Client contact post-sales, quarterbacking strategy, implementations, and communication. You “own” the account and drive Client success and satisfaction.\nEstablish a trusting relationship with clients (technology owners, stakeholders and executive sponsors)\nInterface and collaborate with other teams (both Big Footprint and the Client) to complete project goals\nCommunicate our value and manage our role, answer questions, provide updates and data, ensure client enacts changes based on their best interest (if you have to Google what a 301 redirect is, you’re probably not the right fit\nAnalyze and monitor engagement progress, providing reporting on Client’s success metrics.\nPartner with the Sales team on any revenue opportunities to scope, sell and drive value. Big Footprint specializes in “consultative selling” and you will need to understand and excel in this concept.\nEstablish core metrics with Clients and report against those metrics to illustrate value and gain renewals.\nDevelop and evolve Big Footprint’s Client Onboarding process to ensure long-term success.\n
# 117  \nDevelop systems to track and report sales/net sales, sales effectiveness, promotional activities, etc.\nWork with Financial Planning & Analysis to develop and implement solutions, post program analysis and effectiveness of key sales initiatives\nAnalyze and report on business metrics utilizing Salesforce.com and other internal systems, including but not limited to: user compliance, key performance indicators and account activity\nAssist in the creation and documentation of Standard Operating Procedures as well as interdepartmental policies and procedures\nAssist with document control of sales operations contractual templates and executed agreements\nHelp designed sales education program with our internal training department\nPrepare monthly reporting for senior and executive leadership teams\nOther duties as assigned
# 118  None Found
# 119  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                           Education  \
# ...
# 117  The Sales Data Analyst works to increase sales productivity, provide client satisfaction and grow profits for the New Home divisions. This position supports both the VP Sales, VP Operations and works closely with Salesforce Administrator, Regional Vice Presidents and field sales teams. Interactions with the company's top executives is routinely required as part of the overall reporting responsibilities.\nDuties and Responsibilities include the following:\nDevelop systems to track and report sales/net sales, sales effectiveness, promotional activities, etc.\nWork with Financial Planning & Analysis to develop and implement solutions, post program analysis and effectiveness of key sales initiatives\nAnalyze and report on business metrics utilizing Salesforce.com and other internal systems, including but not limited to: user compliance, key performance indicators and account activity\nAssist in the creation and documentation of Standard Operating Procedures as well as interdepartmental policies and procedures\nAssist with document control of sales operations contractual templates and executed agreements\nHelp designed sales education program with our internal training department\nPrepare monthly reporting for senior and executive leadership teams\nOther duties as assigned\nQualifications\nSales experience in a corporate environment is preferred. Must have well-rounded, hands on experience with all facets of sales, to include and exceed duties listed in this job description. Must have outstanding computer skills in a Microsoft Windows with proficiency in Excel, Word, and other MS programs. Experience with Salesforce.com and SQL is preferable. Sales process knowledge and presentation capabilities with the ability to convey complex features and benefits in a simple to understand manner is advantageous. Strong interpersonal skills for building cross functional relationships and excellent organizational skills. Minimum amount of travel may be required.\n\nEducation and/or Experience\nBachelor's degree (B.A.) from a four-year college or university required; or four to six years of equivalent work experience in an analytical support role.\nLanguage Skills\nExcellent interpersonal skills: ability to speak to both tactical and strategic decision makers; ability to take a consultative approach to engaging with senior executives.\nMathematical Skills\nAbility to calculate figures and amounts such as discounts, interest, commissions, proportions, percentages, area, circumference, and volume. Ability to apply mathematical concepts to spreadsheets and other analytical tools.\nReasoning Ability\nAbility to apply common sense understanding to carry out instructions furnished in written, oral, or diagram form. Ability to deal with problems involving several concrete variables in standardized situations.\nPhysical Demands\nThe physical demands described here are representative of those that must be met by an employee to successfully perform the essential functions of this job. Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions.\nWork Environment\nThe work environment characteristics described here are representative of those an employee encounters while performing the essential functions of this job. Reasonable accommodations may be made to enable individuals with disabilities to perform the essential functions.\nBENEFITS and PERKS\nBenefits are an integral part of the overall compensation package provided by 2-10 Home Buyers Warranty and a key tool in recruiting and retaining great employees. It is our objective to offer comprehensive coverage that meets our employees’ needs.\nBenefits Overview\n2-10 Home Buyers Warranty offers the following benefits:\nMedical insurance, Health savings account, Dental insurance, Vision insurance, Flexible spending accounts, Basic life and AD&D insurance, Supplemental life and AD&D insurance, Disability insurance, Additional Colonial insurance, Empl ...
# 118  Welltok is a data-driven, enterprise SaaS company that delivers the healthcare industry's leading consumer activation platform. Welltok's solutions empower leading health plans, employers, providers and public entities to connect consumers with personalized health improvement resources, making it easy and rewarding for consumers to complete actions that optimize their health and wellbeing.\n\nWelltok was named one of five healthcare companies on the Forbes 2018 Cloud 100 list, ranked #1 on the 2019 Tech Tribune's Best Technology Startups in Colorado and #2 in Colorado on Deloitte's 2017 Technology Fast 500.\n\nAt Welltok, we're proud of what we're accomplishing and are committed to building a company where smart, passionate people can thrive and succeed. Join us as we make healthcare more personal and rewarding!\nPosition Summary\nAs a data analyst within Analytic Solutions, you will be responsible for data management throughout the organization. You will utilize industry standard database languages, data-marshalling tools, and other data management applications to create, configure, maintain, and enhance data solutions that facilitate machine learning systems, data mining analytic services, communications platforms, and other internal and external systems. Ideal candidates will possess hands-on experience with Healthcare industry data and systems, familiarity with common issues and concerns around data transformation, be willing to quickly learn new tools and techniques, and be able to work in a fast-paced environment with team members dedicated to ensuring the highest level of quality in solution delivery.\n\nKey responsibilities include:\nAcquiring, validating, standardizing, and warehousing incoming client data in all forms and frequencies, from membership information to wearable device data, long cycle to near real time\nCreating and maintaining the environment and processes that govern this data\nFacilitating in-depth data discussions with clients and data vendors, as well as internal customers\nPartnering with internal and external customer teams to ensure the continuity and consistency of our client deliverables\nAnalyzing and critically thinking about data issues, then developing and executing a plan to resolve them\nReview and contribute to documentation knowledge base\nMaintaining knowledge of the latest industry tools and best practices\nExperience\nRequirements:\n4-year degree or equivalent experience in a computer science and/or data engineering discipline. An equivalent degree in mathematics, statistics, or a Healthcare data-related discipline with demonstrated programming experience is also acceptable.\n1+ years of hands-on experience within a Healthcare industry setting, including such responsibilities as:\nData requirements gathering\nProcess documentation\nData acquisition and validation techniques\nData staging\nData preservation, integrity, traceability, and transparency.\nFluency in database or data analysis language is strongly preferred; fluency in another programming language with demonstrated competency in programming concepts is acceptable.\nDemonstrated ability to self-direct, work, and lead with minimal supervision\nAdditional consideration will be given to candidates who express an interest or have experience in ETL system design\nDesired Competencies/Skills:\nExperience working with large data sets\nExperience working with Healthcare data in all forms\nExcellent verbal and written communication skills\nExcellent team collaboration skills\nAbility to accurately determine data quality and define best programming practices as it relates to Healthcare data\nFamiliarity with data transfer methods (e.g. FTP, SFTP, FTPS) and Encryption methods (e.g. PGP, GPG. ASC)\nCreative problem solving.\nWelltok celebrates respects and supports diversity in the workplace. Welltok is an equal opportunity employer. We are committed to considering all qualified candidates regardless of race, color, ancestry, relig ...
# 119  Welcome to Centura Health\nWelcome to the largest health ecosystem in Colorado and western Kansas. Welcome to living your mission among thousands of people on fire to live theirs too. Welcome to options, possibilities and values that guide exceptional care. Welcome to extremely important industry challenges and opportunities to solve complex problems. Welcome to highly intelligent teams, overflowing community and the wholeness of mind, body and spirit that is Centura Health.\nFlourishing Begins Here\nYou have a purpose, unique talents and NOW is the time to embrace it, live it and put it to work. At Centura Health, we value incredible people with incredible skills – but your commitment to a greater cause is something we value even more.\nResponsible for physician reimbursement analytics and contract management system maintenance. Role focuses on physician rates, coding, reimbursement methodologies, data tools, reporting, managing provider revenue and maintaining system integrity. Must have analytical mind that can be applied to queries, reports, data, spreadsheets and system customization. Must be able to work in a close-knit, team-oriented environment and be dedicated to finding solutions, enhancing processes and meeting department and corporate goals.\nWhat You Bring/Job Requirements\nIn addition to bringing your whole self to the workplace each day, qualified candidates will need the following:\n5 years of healthcare analytical experience\n2 years of reimbursement experience\nEpic system knowledge a plus\nHigh school diploma/GED required\nBachelor degree preferred in mathematics, finance, economics or actuarial\nSedentary work -(prolonged periods of sitting and exert up to 10lbs force occasionally)\nYour Connected Community\nWhen people and places align, incredible things happen. Just like the 21,000+ amazing associates who work here, every community within Centura Health’s connected ecosystem has its own unique history, story and personality.\n\nCentura Health is headquartered in Centennial, CO, with additional business office locations throughout the Denver Tech Center. The Corporate Service Center is home to our leaders and centralized teams that support our hospitals, clinics and people – including marketing, human resources, employee benefits, finance, billing, talent acquisition/development, payor relations, IT, project management, community benefit and more. Whether you work in the corporate headquarters or one of our nearby offices, you’ll experience a culture of collaboration and community where incredible people are doing incredible things every day.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ...
#
# [120 rows x 12 columns]

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_DataAnalyst_Denver.csv')
