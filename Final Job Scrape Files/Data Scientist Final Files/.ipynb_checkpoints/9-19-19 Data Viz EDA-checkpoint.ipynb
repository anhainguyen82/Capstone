# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
from os import path
# %matplotlib inline

# %%
df=pd.read_csv("Descriptions_df_DataScientist.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                   Title             Location  \
# 0           0              Entry Level Data Scientist        United States
# 1           1  Entry Level - Associate Data Scientist        United States
# 2           2                      Jr. Data Scientist   New York, NY 10036
# 3           3      Intern Conversion - Data Scientist        United States
# 4           4                          Data Scientist  Englewood, CO 80113
#
#                                       Qualifications      Skills  \
# 0                                         None Found  None Found
# 1                                         None Found  None Found
# 2  Bachelor’s or Master’s degree in a quantitativ...  None Found
# 3                                         None Found  None Found
# 4                                         None Found  None Found
#
#                                     Responsibilities   Education Requirement
# ...

# %%
print("There are {} observations and {} features in this dataset. \n".format(df.shape[0],df.shape[1]))

print("There are {} different job titles in this dataset such as {}... \n".format(len(df.Title.unique()),
                                                                           ", ".join(df.Title.unique()[0:5])))

print("There are {} unique locations of the jobs in this dataset such as {}... \n".format(len(df.Location.unique()),
                                                                                      ", ".join(df.Location.unique()[0:5])))
# Out:
# There are 2751 observations and 8 features in this dataset.
#
# There are 351 different job titles in this dataset such as Entry Level Data Scientist, Entry Level - Associate Data Scientist, Jr. Data Scientist, Intern Conversion - Data Scientist, Data Scientist...
#
# There are 417 unique locations of the jobs in this dataset such as United States, New York, NY 10036, Englewood, CO 80113, Boston, MA, Redmond, WA...

# %%
df[["Title", "Location"]].head()
# Out:
#                                     Title             Location
# 0              Entry Level Data Scientist        United States
# 1  Entry Level - Associate Data Scientist        United States
# 2                      Jr. Data Scientist   New York, NY 10036
# 3      Intern Conversion - Data Scientist        United States
# 4                          Data Scientist  Englewood, CO 80113

# %%
Location=df.groupby("Location")
Location.describe().head()
# Out:
#                      Unnamed: 0                                               \
#                           count     mean         std    min      25%     50%
# Location
# Abbott Park, IL             2.0  1231.50  335.875721  994.0  1112.75  1231.5
# Akron, OH                   1.0   364.00         NaN  364.0   364.00   364.0
# Alabama                     4.0   810.25   62.500000  748.0   765.25   804.0
# Alexandria, VA             20.0  1252.00  258.224708  758.0  1096.75  1298.5
# Alexandria, VA 22314        2.0  1265.00  427.092496  963.0  1114.00  1265.0
#
#
#                           75%     max
# Location
# Abbott Park, IL       1350.25  1469.0
# Akron, OH              364.00   364.0
# Alabama                849.00   885.0
# Alexandria, VA        1408.25  1695.0
# Alexandria, VA 22314  1416.00  1567.0

# %%
plt.figure(figsize=(15,10))
Location.size().sort_values(ascending=False).plot.bar()
plt.xticks(rotation=50)
plt.xlabel("Job Location")
plt.ylabel("Number of Jobs Posted")
plt.show()

# %%
text = np.array(df['Title'])

wordcloud = WordCloud(width=800, height=400).generate(' '.join(text))

plt.figure( figsize=(30,20) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
text = np.array(df['Title'])

wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(' '.join(text))
plt.figure( figsize=(30,20) )
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text1 = np.array(df['Location'])

wordcloud = WordCloud(width=800, height=400).generate(' '.join(text1))

plt.figure( figsize=(30,20) )
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
