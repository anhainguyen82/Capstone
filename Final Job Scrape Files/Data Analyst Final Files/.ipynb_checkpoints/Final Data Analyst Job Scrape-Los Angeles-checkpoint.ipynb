# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Data+Analyst%22&l=Los+Angeles%2C+CA&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 318

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 318

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 189

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                                  Title  \
# 0    Data Analyst
# 1    Sales and Marketing Data Analyst I
# 2    Data Analyst Intern
# 3    Marketing Analytics – Data Analyst
# 4    Media Data Analyst
# ..                  ...
# 184  Health Information Consultant (Data & Reporting Analyst) - Cerritos, CA (PS27789)
# 185  Data Analyst
# 186  Data Analyst, SQL
# 187  Data Analyst - SAS/SQL
# 188  Business Data Analyst
#
#                   Location         City State         Zip     Country  \
# 0    Los Angeles, CA        Los Angeles  CA    None Found  None Found
# 1    Los Angeles, CA 90017  Los Angeles  CA    90017       None Found
# 2    Los Angeles, CA 90064  Los Angeles  CA    90064       None Found
# 3    Brea, CA               Brea         CA    None Found  None Found
# 4    Los Angeles, CA        Los Angeles  CA    None Found  None Found
# ..               ...                ...  ..           ...         ...
# 184  Downey, CA             Downey       CA    None Found  None Found
# 185  Los Angeles, CA        Los Angeles  CA    None Found  None Found
# 186  Los Angeles, CA        Los Angeles  CA    None Found  None Found
# 187  Pasadena, CA           Pasadena     CA    None Found  None Found
# 188  Los Angeles, CA 90045  Los Angeles  CA    90045       None Found
#
#     Qualifications  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    None Found
# ..          ...
# 184  None Found
# 185  None Found
# 186  None Found
# 187  None Found
# 188  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Skills  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    Strong proficiency with MS Excel, PowerPoint or Keynote are a mustExperience/familiarity in ad-serving and web analytics tools (Google DFA, Atlas, Google Analytics, Omniture, etc.)Experience or familiarity with syndicated research sources/tools (MRI, Simmons, Scarborough, IMS, Nielsen, comScore)Experience or familiarity with digital ad effectiveness researchExperience or familiarity with visualization tools such as Tableau/QlikView are a plusExperience/familiarity with concepts of database design and SQL are a plusFamiliarity with web technologies including HTML and Java script
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 184  None Found
# 185  None Found
# 186  None Found
# 187  \nTranslates business and technical needs, issues, and ideas into effective strategies and action plans.\nElicits detailed business requirements and builds effective, data driven and analytical solutions to meet requirements (requires SQL, SAS, and integration from data from multiple db/file formats)\nFormulates specific implementation plans and evaluates the effectiveness of actions/programs implemented.\nCommunicates results/recommendations to project sponsors, clients, and various management-level audiences\nParticipates in the development of process improvements and related outcomes\nWorks closely with business, IT, and non-Clients partners\nVery strong analytic and critical thinking skills, writing skills, communication skills, consulting skills, and ability to work within a team.\nExperience with provider demographic data.\n
# 188  \nAnalytical thinking skills\nAttention to detail\nBasic business knowledge; knowledge of the software development cycle is a plus.\nAdvanced Excel skills and navigation including formulas, concatenate, if-statements, Vlookups, pivot tables and other functions\nHighly proficient with SQL or other data manipulation languages\nAbility to thrive in a demanding environment while prioritizing multiple tasks and meeting tight deadlines\nOutstanding communication skills, both written and verbal\nEqually capable of working as part of a team or independently\nCurious nature, filled with initiative, addicted to follow-through\n
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Responsibilities  \
# 0    None Found
# 1    None Found
# 2    \n Analyzing project/product needs, anticipating and collecting requirements, uncovering areas for improvement and suggesting solutions to the Engineering team\nPerforming independent research of medical concepts, competition landscape and regulation affairs regarding medical devices, and organizing and presenting findings to the R&D team\nDocumenting supportive materials of product development, deployment and maintenance which includes but not limited to product manuals and sprint meeting records\nAnalyzing medical records data (EMR) and product usage data\nCollecting product/project needs by communicating with Chinese and U.S. medical professionals and other collaborators\nPerforming simple feature and product testing and working closely with developers for refinements\nGathering critical information from meetings with various stakeholders and producing useful reports
# 3    None Found
# 4    None Found
# ..          ...
# 184  None Found
# 185  \nDelivering commercial insights to the Merchandise, Salon Operations, IT, Finance, and Marketing functions to enable effective decision making\nDeveloping the decision-making tools required that can be used globally to have a consistent view of metrics and data\nDevelop global reporting focussed and aligned to the business commercial objectives\nIdentify, develop and execute globally aligned consistent reporting and analysis for commercial KPIs\nAnalysis support for space/range strategies to maximize sales and margins\nContinuously develop tools and processes to support decision making and enhance the marketing and merchandise strategies\nDevelop methodology for reviewing and reporting trials to develop commercial understanding\nProvide detailed information and analysis of events, marketing campaigns and specific product ranges to improve future decisions\nWork with and manipulate reports in our systems (Looker, NetSuite, POS and salesforce) to gain the maximum amount of information possible\n
# 186  None Found
# 187  None Found
# 188  \nTrack software development and testing KPI’s, metrics (defect, test coverage, build and release, documentation analysis, etc)\nIdentify patterns and prepare presentation of results in the most effective and appropriate display for the intended audience\nValidate data for problem identification, identify bottlenecks and significance across multiple reports and data sources\nFind, pull, crunch, and interpret large amounts of historical and predictive data from a variety of sources to develop insights, make recommendations and answer key business questions\nTrack both general and specific business activity and provide clear, compelling reports and presentations on a regular basis\nPartner with leaders & stakeholders across the tech organization as the data and system subject matter expert to ensure we are effectively using data to drive informed decision making\nDevelop and improve data visualization and analytics tools to help teams identify trends and best practices, and support in their monitoring of quarterly or annual goals\nProvides input to the development of quality information metrics\nCritically evaluate information gathered from multiple sources, test and evaluate information and reconcile any differences from expected results and ensure consistency among similar reports when necessary\nCommunicate findings and results to leadership, and project partners\nAssist team members and internal clients with timely problem reporting and resolution\n
#
#                                                                                                                                           Education  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    Bachelor’s degree in Statistics, Math, Business, Marketing, Economics, Social Science or other related field of study is required at a minimum
# ..                                                                                                                                              ...
# 184  None Found
# 185  None Found
# 186  BA/BS in Business, Economics, Finance, Data Science, Computer Science or related field\n
# 187  None Found
# 188  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Requirement  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    1-3 years of experience working with data driven field, utilizing quantitative techniques to solve problems such as campaign analysis, optimization, customer segmentation, and/or predictive modelingA strong desire to learn and passion for digital marketing, research and analyticsAbility to work well with others and work in cross functional teamsAbility to manage and prioritize a number of concurrent tasks in a fast-paced environmentAbility to clearly explain complex technical ideas to multiple audiences both verbally and in writingStrong attention to detail
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 184  None Found
# 185  None Found
# 186  None Found
# 187  None Found
# 188  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# 0    In this role you will:\nUse data to drive business decisions across multiple organizations within the company\nDesign, automate, and optimize pipelines, dashboards, and insight delivery methods\nSupport ideation of new features and business initiatives from beginning to end by evaluating potential impact, implementing new tracking, and performing post analysis\nConduct ad hoc analyses as well as deep dives with a focus on growing and improving the business\nRecommend improvements and optimizations highlighted by data across all elements of company’s activities and eco-system\nBecome an expert of our data and evangelize data driven decision making\nBe flexible to manage other assignments as they come up\nWe are looking for:\n2+ years experience in data analytics, ideally in e-commerce or at a startup\nMastery of SQL\nExcellent communication and relationship building skills with an ability to prioritize, negotiate, and work with a variety of internal and external stakeholders\nA quick learner, a self-starter, able to work independently, and you're willing (and able) to handle the pressures of an increasing level of responsibility\nBenefits and perks:\nJoin the early team and work closely with founders on all aspects of the company\nMedical, dental and vision coverage\nCompetitive salary and generous equity grants\nDaily catered lunches from LA’s best restaurants\nUnlimited vacation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ...
# ...
# 186  About Herbalife Nutrition\n\nHerbalife Nutrition is a global nutrition company whose purpose is to make the world healthier and happier. We have been on a mission for nutrition - changing people's lives with great nutrition products & programs - since 1980. Together with our Herbalife Nutrition independent distributors, we are committed to providing solutions to the worldwide problems of poor nutrition and obesity, an aging population, skyrocketing public healthcare costs and a rise in entrepreneurs of all ages. Herbalife Nutrition offers high-quality, science-backed products, most of which are produced in Company-operated facilities, one-on-one coaching with an Herbalife Nutrition independent distributor, and a supportive community approach that inspires customers to embrace a healthier, more active lifestyle.\n\nHerbalife Nutrition’s targeted nutrition, weight-management, energy and fitness and personal care products are available exclusively to and through dedicated distributors in more than 90 countries.\nThrough our corporate social responsibility efforts, Herbalife Nutrition supports the Herbalife Nutrition Foundation (HNF) and its Casa Herbalife programs to help bring good nutrition to children in need. Herbalife Nutrition is also proud to sponsor more than 190 world-class athletes, teams and events around the globe, including Cristiano Ronaldo, the LA Galaxy, and numerous Olympic teams.\nHerbalife has over 8,000 employees worldwide, and our shares are traded on the New York Stock Exchange (NYSE: HLF) with net sales of approximately $4.4 billion in 2017. To learn more, visit Herbalife.com or IAmHerbalife.com.\n\nPOSITION SUMMARY STATEMENT:\nThe Data Analyst will be responsible for data mining and integrating data from various sources, ensuring data consistency, create analysis-ready data sets (SQL, R), conducting analysis and providing appropriate output to support the business through data analytics. The Data Analyst will focus on specific high priority projects that will support different internal business stakeholders (including Senior Executives, Legal Department and Operations). The responsibilities will include writing complex SQL queries, developing and maintaining Store Procedures for company Key Metrics, employing various modeling (e.g. attribution, predictive, regression, etc.) and data visualization techniques on a regular and ad-hoc basis.\n\nDETAILED RESPONSIBILITIES/DUTIES:\nProactively analyze data to answer key questions from stakeholders or out of self-initiated curiosity with an eye for what drives business performance.\nDevelop logic, build from scratch and maintain Member analytical reports (both ad-hoc and scheduled) using SQL, Excel, BI/Micro Strategy and/or Access programs.\nDevelop SQL code to automate and improve efficiencies, quality and timeliness of current routine reports and processes.\nWrite and run complex queries using SQL to validate data and investigate discrepancies, build/augment reporting functionality, develop systematic processes to routinely maintain and update data.\nCreate and maintain rich interactive visualizations through data interpretation and analysis integrating various reporting components from multiple data sources.\nExtract data to manipulate/calculate/format into presentable reports, charts, and graphs for PowerPoint presentations.\nSupport monthly and quarterly Key Metrics and trends validation process to ensure accuracy. The validation process includes ensuring that data is accurately captured from various data sources, understanding and interpretation of data formulas, and calculations and troubleshooting of variances.\nCollaborates with IS and Business Intelligence team, in ongoing decisions regarding data collection, validation, methodology and integration of new functionalities.\nParticipate in the projects supporting company strategic initiatives\nREQUIRED QUALIFICATIONS:\nSkills:\nKnowledge and experience with different types of databases such as SQL Ser ...
# 187  Contract to Hire Position - Only considering candidates who can convert to FTE.\nNO SPONSORSHIP\nPLEASE DO NOT APPLY IF INTERNSHIP IS ONLY EXPERIENCE\nSUMMARY\nThis position is responsible for supporting improvements and systems solutions for Client's provider/practitioner network.\nThe primary focus of this position is to build logical datasets from various sources, build/augment reporting functionality, develop systematic processes to routinely maintain and update data, and reduce variation across reporting platforms.\nExperience Level: 5+ Years. Bachelors Degree Required\n\nSkill Set:\nBusiness analysis.\nBusiness process modeling - enterprise to department level.\nAbility to interpret Entity Relationship Diagrams.\n\nTop 3-5 Required Skills:\n1. Strong skills in SQL, SAS programming languages.\n2. Demonstrated experience in gathering business requirements and execution of report and query design.\n3. Experience with MS Access.\n4. Ability to synthesize complex business/report requirements and connect them across efforts to anticipate reporting needs.\n\nDesired Skills:\n1. Experience with developing/implementing SQL Server solutions.\n\nSoft Skills:\n1. Strong written and verbal communication skills; demonstrated work experience with both business and technical teams.\n2. Values teamwork; listens/responds constructively to needs of team members and stakeholders.\n3. Demonstrates flexibility and openness to changes (sometimes last-minute) that need to be made in work products.\nBUSINESS ANALYST SKILLS\n\nTranslates business and technical needs, issues, and ideas into effective strategies and action plans.\nElicits detailed business requirements and builds effective, data driven and analytical solutions to meet requirements (requires SQL, SAS, and integration from data from multiple db/file formats)\nFormulates specific implementation plans and evaluates the effectiveness of actions/programs implemented.\nCommunicates results/recommendations to project sponsors, clients, and various management-level audiences\nParticipates in the development of process improvements and related outcomes\nWorks closely with business, IT, and non-Clients partners\nVery strong analytic and critical thinking skills, writing skills, communication skills, consulting skills, and ability to work within a team.\nExperience with provider demographic data.\n\nTECHNICAL SKILLS\n\nExperience with analytical manipulation and interpretation of large databases required.\nDesigns and enhances databases and alternative solutions.\nDesigns systems that are effective and user-friendly.\nConducts data analysis and develops reports with accurate, easy to read, useful information.\nDesigns and manages data quality tracking and monitoring tools.\nValidates and maintains data integrity across multiple databases and data sources (SQL, internal SAS, DB2, VSAM; external: Adobe, Excel, SAS parsing routines, COBOL).\nBuilds and maintains statistical routines using macros, vendor software, and software written by self and others.\n\nTop 3-5 Daily Responsibilities:\n1. Identify business requirements for provider network data reporting needs; develop systematic/programmatic solutions based on business requirements.\n2. Optimize existing database used to collect provider demographic data; design and implement additional existing databases, based on data management needs.\n3. Identify solution options for more systematic intake of provider demographic data changes and updates.\n\nPosition Description:\nProvide data architectural leadership in developing enterprise data/process models, and logical/physical database designs.\nProvide data and database development, maintenance, and production support.\nParticipate in IT and Business project to define system requirements.                                                                                                                                                                                                                 ...
# 188  We’re looking for a Business Data Analyst to assist in our Technology organization who has excellent critical thinking skills, is highly skilled at problem solving and maintains a strong attention to detail. Our Quality Assurance team is looking for someone that can assist in using data & metrics to tell a story. If you are an intelligent, professional, and friendly person with a passion for turning data into relevant information, we want you on our team!\n\nResponsibilities:\n\nTrack software development and testing KPI’s, metrics (defect, test coverage, build and release, documentation analysis, etc)\nIdentify patterns and prepare presentation of results in the most effective and appropriate display for the intended audience\nValidate data for problem identification, identify bottlenecks and significance across multiple reports and data sources\nFind, pull, crunch, and interpret large amounts of historical and predictive data from a variety of sources to develop insights, make recommendations and answer key business questions\nTrack both general and specific business activity and provide clear, compelling reports and presentations on a regular basis\nPartner with leaders & stakeholders across the tech organization as the data and system subject matter expert to ensure we are effectively using data to drive informed decision making\nDevelop and improve data visualization and analytics tools to help teams identify trends and best practices, and support in their monitoring of quarterly or annual goals\nProvides input to the development of quality information metrics\nCritically evaluate information gathered from multiple sources, test and evaluate information and reconcile any differences from expected results and ensure consistency among similar reports when necessary\nCommunicate findings and results to leadership, and project partners\nAssist team members and internal clients with timely problem reporting and resolution\n\nRequired Skills:\n\nAnalytical thinking skills\nAttention to detail\nBasic business knowledge; knowledge of the software development cycle is a plus.\nAdvanced Excel skills and navigation including formulas, concatenate, if-statements, Vlookups, pivot tables and other functions\nHighly proficient with SQL or other data manipulation languages\nAbility to thrive in a demanding environment while prioritizing multiple tasks and meeting tight deadlines\nOutstanding communication skills, both written and verbal\nEqually capable of working as part of a team or independently\nCurious nature, filled with initiative, addicted to follow-through\n\n                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
#
# [189 rows x 12 columns]

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_DataAnalyst_LA.csv')
