# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Data+Analyst%22&l=San+Francisco%2C+CA&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 327

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 327

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 220

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                       Title  \
# 0    Business Operations, Senior Analyst
# 1    Data Analyst
# 2    Manager or Senior Manager Finance Technology and Purchasing Operations
# 3    Sr. Analyst, Marketing Strategy and Analytics
# 4    Underwriter
# ..           ...
# 215  Senior Data Analyst
# 216  Pricing Data Analyst
# 217  Sr. Live Producer
# 218  Senior Associate, Data Analyst
# 219  Business Intelligence Analyst
#
#                     Location           City State         Zip     Country  \
# 0    San Francisco, CA 94103  San Francisco  CA    94103       None Found
# 1    Oakland, CA              Oakland        CA    None Found  None Found
# 2    San Francisco, CA 94105  San Francisco  CA    94105       None Found
# 3    San Francisco, CA 94107  San Francisco  CA    94107       None Found
# 4    Oakland, CA              Oakland        CA    None Found  None Found
# ..           ...                  ...        ..           ...         ...
# 215  San Francisco, CA 94105  San Francisco  CA    94105       None Found
# 216  San Mateo, CA 94402      San Mateo      CA    94402       None Found
# 217  Redwood City, CA 94065   Redwood City   CA    94065       None Found
# 218  San Mateo, CA            San Mateo      CA    None Found  None Found
# 219  San Mateo, CA            San Mateo      CA    None Found  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Qualifications  \
# 0    \nBachelor’s degree in Statistics, Mathematics, Physics, Computer Science, Engineering, Analytics or a related quantitative field\nFluent English Speaker\nExperience with Microsoft Excel and/or other data analysis tools\nExperience with querying data using SQL\nProven technical experience and the aptitude to quickly learn new technologies\nPrior internship experience where you have demonstrated an ability to work in teams, problem solve, and communicate effectively and/or related analysis course work
# 1    None Found
# 2    5 years of relevant experience\nTeam management experience, cross-geo a plus\nFlexible mindset and willingness to embrace and own change\nSAP experience would be a significant plus, but is not absolutely required\nExperience with the many tools we use or willingness to dig in and learn them:\nAriba, Concur, Anaplan, Vertex, and other finance related applications\nBusiness Objects, Power BI, QlikView, Cognos, SharePoint, Tableau\nAlteryx, UI Path or other ETL/RPA tools
# 3    None Found
# 4    None Found
# ..          ...
# 215  Master's degree in related field, or an equivalent combination of education and experience\nDetailed understanding of how to pull data from a database, then analyze and report information for strategic decision\nExperience working with complex data\nExcellent organizational and time management\nAbility to work collaboratively with a service oriented\nStrong conceptual, analytical, and problem-solving skills\nExperience with SQL and Tableau\nExperience using Ellucian products, in particular Colleague and Recruit, and Salesforce (preferred)\n
# 216  \n2+ years relevant industry experience, a focus on data visualization preferred\nRetail/eCommerce experience is required\nAbility to identify and communicate key insights from data\nSkilled at building interactive visualizations and dashboards\nFamiliarity with design principles\nDeep expertise with data visualization and BI tools\nSuperior project management and attention to detail\nStrong communication skills\nUnderstanding of data models\nExpert with SQL required; Python and/or JavaScript a plus\nBe a team player who can wear multiple hats to accommodate business needs\nEmbrace autonomy and ability to drive projects forward with minimal direction\nEffective verbal and written communication skills. Should be able to adapt communication style to suit different audiences.
# 217  None Found
# 218  None Found
# 219  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Skills  \
# 0    None Found
# 1    None Found
# 2    None Found
# 3    None Found
# 4    None Found
# ..          ...
# 215  None Found
# 216  \n2+ years relevant industry experience, a focus on data visualization preferred\nRetail/eCommerce experience is required\nAbility to identify and communicate key insights from data\nSkilled at building interactive visualizations and dashboards\nFamiliarity with design principles\nDeep expertise with data visualization and BI tools\nSuperior project management and attention to detail\nStrong communication skills\nUnderstanding of data models\nExpert with SQL required; Python and/or JavaScript a plus\nBe a team player who can wear multiple hats to accommodate business needs\nEmbrace autonomy and ability to drive projects forward with minimal direction\nEffective verbal and written communication skills. Should be able to adapt communication style to suit different audiences.
# 217  None Found
# 218  None Found
# 219  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Responsibilities  \
# 0    \nPartner with executive level functional stakeholders to identify, scope, and complete optimization projects in their functions\nWork with the broader BizOps team on cross functional innovation initiatives\nUnderstand Mavenlink’s database systems and know how to pull the required information for ad-hoc requests from managers\nMaintain the integrity of databases/data systems and Business Intelligence infrastructure\nInterpret data, analyze results using statistical techniques and provide ongoing reports\nLeverage network and expertise to implement industry best practices
# 1    \nDive into our clickstream data to understand user behavior, providing insights to guide product improvement efforts and level up our data architecture\nWork closely with the creative, product, data science, and engineering teams to develop new customer-facing initiatives\nProvide insights that will enhance our understanding of customer lifetime value\nCreate and maintain KPI dashboards to support team decision making
# 2    Be a technology enthusiast, to help Financial Services bring new technologies to our team, explore new ways of working and generate excitement about learning new technologies\nLive the Autodesk cultural values by being Smart, Innovative, Adaptable, Inclusive, Impactful, Humble, Courageous, Accountable, Pragmatic and Customer Focus. Drive adoption of values within team\nCultivate a leadership presence in the broader Finance organization\nManage two analysts responsible for supplier data management and processes. This includes validating the legitimacy of global suppliers and establishing them in SAP\nFunction as the procurement and sourcing organization’s lead for all things Ariba, SAP, Concur, and Fieldglass. This includes managing two team members that handle daily operations - such as supplier catalog additions, system performance issues or enhancements, and supplier enablement in Ariba - and working closely with our IT organization to prioritize projects\nManage data analyst responsible for creating and updating spend-related dashboards; understand stakeholder analytical needs and drive ongoing improvement
# 3    None Found
# 4    \nUnderwrite and decision agency conforming and jumbo residential mortgage loans\nVerify and analyze all necessary financial information and documentation; ensure that loan files contain all necessary credit and legal documents\nReview appraisal reports to identify and resolve any discrepancies discovered within\nPerform thorough analysis of applicant's income and expense data, asset documentation, credit reports, and property valuations in order to affirm borrower qualifies for loan\nCalculate qualifying ratios, determine creditworthiness; provide risk opinions\n
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# 215  Collect, extract and analyze programmatic data to support strategic and operational planning\nIdentify trends, prepare high-level reports, and communicate findings to support data-driven decision making\nWork closely with the Vice President of Enrollment Strategy and Services, Office of Admissions, Office of Student Financial Aid, and the Finance Office regarding budget\nCreate and maintain effective admission and yield models which advise admission and financial aid decisions, and provide interval estimates of first-year enrollment\nInitiate, lead, define, develop and produce original research projects addressing enrollment management questions and issues\nMaintains and develops ad-hoc reports as needed\nDevelops procedures to automate manually performed procedures\nWorks closely with IT staff to improve database operations and data import/export processes; monitors, filters and corrects data and troubleshoots system related issues\nSynchronizes prospective student information between web application and database and develops procedures related to handling of data\nResponsible for the operational maintenance and data integrity of the Admissions databases including, but not limited to Salesforce and Ellucian products\nEnsures accuracy of data by developing methods to check for discrepancies\nBuilds and maintains data mapping and import and export rules of a wide range of source files\nRespond to other requests on a case by case basis\nActively and with regularity meet and coordinate with Enrollment Services and Financial Aid to avoid redundancies and to ensure mutual learning\n
# 216  \nWork with project stakeholders (both internal and external clients) to identify business needs and gather requirements for data visualization or deployment of BI tools\nConvey meaningful insights via effective displays and reports to translate complex data into actionable strategies and techniques to drive sales and enhance marketing efforts\nDevelop interactive dashboards for exploring data analysis results\nLeverage existing tools to allow clients to explore data in new ways\nConsistently search for ways to improve the way we visualize data\nPlay a key role in developing insights with some of Wiser's largest customers\nMaintain regular and reliable work attendance
# 217  Work with Game Development and Marketing to help define and develop product strategy and roadmap.
# 218  \nAnalyze and capture detailed business and technical requirements focused on delivering enterprise data cleansing, data quality and migration solutions.\nUsing data discovery and profiling methodology to perform source data model analysis, target data model analysis and the associated data movement throughout the various systems.\nCapture business rules/transformation, meta data descriptions and definitions for the Data Dictionary and Source-to-Target Mapping artifacts.\nCreate and own the necessary project deliverable templates and artifacts - primarily the business requirements document and the source-to-target mappings.\nWork with QA and the solution owners to help develop data reconciliation, data completeness test plans, test cases and perform testing.
# 219  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Education  \
# 0    None Found
# 1    None Found
# 2    None Found
# ...
# 217  You are the Senior Live Producer. You collect and study data to reveal ways to improve the product. You enjoy working with large data sets and coming up with logical conclusions based on that data. You work closely as a consultant to both Marketing and Game Development to ensure that your product remains competitive and relevant.\n\nYou help develop product features by identifying and analyzing competitive products; conducting market research; generating product requirements; determining specifications, production timetables, pricing, and time-integrated plans for product introduction; developing marketing narratives with respect to the content.\n\nYou build product features from existing ideas, and help to develop new ideas based on your industry experience and your contact with customers and prospects. You possess a unique blend of business and technical savvy, a big-picture vision, and the drive to make that vision a reality. You enjoy spending time in the market to understand factors of success, and find innovative ways to meet those specifications.\n\nResponsibilities\n\nWork with Game Development and Marketing to help define and develop product strategy and roadmap.\nIntroduce and market new product features by developing time-integrated plans with sales, advertising, and production.\nGain a deep understanding of customer experience, identify and fill product gaps and generate new ideas that grow market share, improve customer experience and drive growth.\nCreate buy-in for the product vision with partners.\nTranslate product strategy into detailed requirements and prototypes.\nScope and prioritize activities based on business and customer impact.\nEvaluate promotional plans to ensure that they are consistent with product-line strategy and that the message is effectively conveyed.\nDeliver MRDs and PRDs with prioritized features and corresponding justification.\nConduct research and analysis of product-related KPIs, formulate cohesive and accurate narratives regarding the data, and help the organization make better business decisions.\nPrepare statistical and narrative reports and recommendations, and participate in the analysis and interpretation of data as appropriate.\nConduct full lifecycle analysis to include requirements, activities, design, and result. Monitor performance to identify improvements.\nPresent findings and translates data into understandable documents. Speak clearly, easily communicating complex ideas.\nAnalyze numbers, trends, and data and comes to conclusions based on findings.\nRemain vigilant in ensuring proper data to ensure that analysis and conclusions are correct.\nResearch and help develop new data collection nodes, proposing both tools and methods by which this new data will be collected and evaluated.\nProvide regular reports to the company on product health.\nWork with Game Development and Marketing and provide financial and user forecasts.\n\nRequirements\n\n5 years in the gaming industry, at least one of which were as a Product Manager or Product Data Analyst.\n3 year of experience with analyzing data.\nProven work experience in product management.\nProven work experience as a data analyst or business data analyst.\nProven ability to influence cross-functional teams without formal authority.\nProven track record of managing all aspects of a successful product throughout its lifecycle.\nProven ability to develop product and marketing narratives and effectively communicate recommendations to related stakeholders.\nProven success defining and launching excellent products.\nMS/BS degree in Mathematics, Economics, Computer Science, Information Management or Statistics, or equivalent experience.\nStrong background in understanding and/or hands-on experience in game development.\nStrong problem solving skills and willingness to roll up one’s sleeves to complete the job.\nSkilled at working effectively with cross functional teams in a matrix organization.\nStrong analytical skills with the  ...
# 218  Responsibilities\nAnalyze and capture detailed business and technical requirements focused on delivering enterprise data cleansing, data quality and migration solutions.\nUsing data discovery and profiling methodology to perform source data model analysis, target data model analysis and the associated data movement throughout the various systems.\nCapture business rules/transformation, meta data descriptions and definitions for the Data Dictionary and Source-to-Target Mapping artifacts.\nCreate and own the necessary project deliverable templates and artifacts - primarily the business requirements document and the source-to-target mappings.\nWork with QA and the solution owners to help develop data reconciliation, data completeness test plans, test cases and perform testing.\nJob Requirement\n8+ years’ experience working on data cleansing, data quality and over all data management projects.\nStrong understanding of legacy data structures, formats and their mappings to Salesforce objects\nStrong business analysis experience to capture data requirements and able to translate to technical specifications for source-to-target design and development.\nExtensive experience in data warehouse projects, data visualization tools and/or Business Intelligence (BI) platforms across the entire SDLC.\nExperience with data lineage, data cataloging, and quality implementation\nExcellent verbal, presentation and articulation skill to co-ordinate technical issues to non-technical audiences                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 219  Our Operations team is looking for the first Business Intelligence Analyst who is passionate about data, analytics, and business strategy. You will be the owner of our Business Intelligence infrastructure while working in a highly collaborative environment of data engineers, and business leaders to deliver data solutions for our business needs. You will help the team learn more about our business, teach others in the company about analytics, and improve the use of our data so SendBird can transform into a data-driven organization. You'll be an integral part of providing data-driven insights that guide our company to set the new growth benchmark for B2B SaaS companies.\n\nWHAT YOU WILL DO\n----------------\n\n\nPartner with teams across the organization to understand their analytics needs and create dashboards and reporting that allow them to execute more effectively\nWork with business leaders to define key metrics and build reporting to monitor and understand performance along those metrics\nBuild and maintain scalable ETL processes and pipelines to bring the data into our data warehouse\nWork directly with internal partners and business/product/design/engineering audiences to understand the reporting needs and develop scalable solutions keeping reusability in mind.\nBuild, Maintain and administer Looker as our BI tools and be the driving force behind the adoption and effective use of Looker within every team at SendBird\nMaintain the data quality and data integrity of the data warehouse in partnership with our Data Engineers/Platform Engineers\nDeep dive into large set of data sets to answer business questions, perform ad-hoc analysis\nReconcile data between various systems, find opportunities to innovate, and drive improvements\n\nWHO YOU ARE\n-----------\n\n\nAble to thrive in a dynamic and fast-paced environment; intellectually curious; PM skills\nProven track record of collaboration with a variety of decision makers to drive impact\nShare a creative approach in developing actionable analysis and guidance\nExpert in visualization technologies including Looker, Tableau and/or another BI tool\nStrong active listener with solid written and verbal communication skills\n\nEXPERIENCE AND SKILLS\n---------------------\n\n\n4-5 years of experience with large complex data sets from various sources, ideally with a focus on marketing, sales, or customer acquisition\nKnowledge of relational databases or data warehouses (Redshift, PostgreSQL, MySQL, Snowflake etc.)\nConfident with a scripting language (Python, Ruby, etc.) to build data models and ETLs\nAbility to work cross-functionally, building and maintaining trust with internal stakeholders\nBachelor's degree in Math/Statistics/Engineering or other equivalent quantitative discipline\n\nBENEFITS\n--------\n\n\nPick your new laptop!\n4 weeks PTO!\n99.99 ( http://99.0.0.99/ )% Paid Benefits\n12 US Paid Holidays\nFun work environment!\nFlexible work schedule\nOpportunity to work for one of the hottest startups on the planet!\n\nABOUT SENDBIRD\n--------------\n\nSendBird is the world's leading chat & messaging platform as a service. Our mission is to digitize human interactions for businesses. Our platform delivers billions of messages per month to help people connect through the products and apps they love.\n\nWe're a Y Combinator alumnus (W16) and have raised over $120M from leading investors including ICONIQ Capital, Tiger Global Management, Shasta Ventures, August Capital, and FundersClub. We are headquartered in San Mateo, CA with offices in Seoul, Singapore, London and Bangalore.                                                                                                                                                                                                                                                                                                                                                                                                                    ...
#
# [220 rows x 12 columns]

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_DataAnalyst_SF.csv')
