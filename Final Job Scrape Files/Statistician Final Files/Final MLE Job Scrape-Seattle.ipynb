# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Statistician%22&l=Seattle%2C+WA&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 319

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 319

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 23

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                 Title  \
# 0   Principal Statistician (Cell Therapy CMC)
# 1   Head Coach – Cross Country
# 2   Statistician
# 3   Senior Biostatistician II
# 4   Project Director, Statsitical (Biostatistican)
# 5   Data Scientist, AWS Training & Certification
# 6   INSTITUTIONAL ANALYST
# 7   19/20 - Coach - Assistant Softball Coach
# 8   Survey Statistician, GS-1530-11/12, Census-DHA-SM
# 9   Head Coach – Track & Field
# 10  Principal Biostatistician
# 11  19/20 - Coach - Assistant Girls' Basketball
# 12  SENIOR BIOSTATISTICIAN 18-09-217
# 13  Data Scientist Technical Lead
# 14  19/20 - Assistant Coach - Boys' Swim & Dive
# 15  Senior Biostatistician
# 16  Data Scientist
# 17  19/20 - Coach - Assistant Gymnastics
# 18  19/20 - Coach - Assistant Girls' Golf
# 19  Manager, Data Science and Statistician
# 20  19/20 Coach - Assistant Boys' Dive
# 21  Senior Manager, Data Science and Statistician
# 22  Statistician
#
#                    Location           City State         Zip  \
# 0   Seattle, WA 98109        Seattle        WA    98109
# 1   Redmond, WA 98053        Redmond        WA    98053
# 2   Seattle, WA              Seattle        WA    None Found
# 3   Seattle, WA              Seattle        WA    None Found
# 4   Seattle, WA 98121        Seattle        WA    98121
# 5   Seattle, WA              Seattle        WA    None Found
# 6   Seattle, WA              Seattle        WA    None Found
# 7   Mercer Island, WA 98040  Mercer Island  WA    98040
# 8   Seattle, WA              Seattle        WA    None Found
# 9   Redmond, WA 98053        Redmond        WA    98053
# 10  Seattle, WA              Seattle        WA    None Found
# 11  Mercer Island, WA 98040  Mercer Island  WA    98040
# 12  Seattle, WA 98121        Seattle        WA    98121
# 13  Seattle, WA              Seattle        WA    None Found
# 14  Mercer Island, WA 98040  Mercer Island  WA    98040
# 15  Seattle, WA 98109        Seattle        WA    98109
# 16  Seattle, WA              Seattle        WA    None Found
# 17  Mercer Island, WA 98040  Mercer Island  WA    98040
# 18  Mercer Island, WA 98040  Mercer Island  WA    98040
# 19  Seattle, WA              Seattle        WA    None Found
# 20  Mercer Island, WA 98040  Mercer Island  WA    98040
# 21  Seattle, WA              Seattle        WA    None Found
# 22  Seattle, WA              Seattle        WA    None Found
#
#                                                                                                                                                                     Country  \
# 0   None Found
# 1   \nThe head coach organizes, coordinates and promotes a comprehensive athletic program.\nTeaching position may be available dependent on subject matter and grade level.
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  None Found
# 17  None Found
# 18  None Found
# 19  None Found
# 20  None Found
# 21  None Found
# 22  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Qualifications  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   \nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred
# 8   \nSkill in reviewing and/or writing presentations, working papers and/or publications presenting social science, economic, or demographic analysis to a variety of audiences.\nKnowledge of tools used in quantitative social science research on a variety of social science topics.\nAbility to analyze economic or household survey data to address research questions related to survey goals.\nKnowledge of theories related to statistical research.\nKnowledge of project management techniques to complete projects within specific time frames.\n
# 9   None Found
# 10  None Found
# 11  \nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred
# 12  \nMaster's degree in Statistics, Biostatistics, or Public Health with 3 years of post-graduation experience in pharmaceutical industry as a lead statistician with high independency for complicated studies; or PhD in Statistics, Biostatistics or Public Heath with 2 years of post-graduation experience in pharmaceutical industry including CRO as a study statistician.\nSound knowledge of Clinical trials and Data Monitoring Committee\nKnowledge and experience to exercise independent judgment and provide oversight to programmers, and junior statisticians\nPrevious experience providing leadership to team members\nInterpersonal skills\nExcellent verbal and written communication skills\nProficiency with SAS procedures and programming language
# 13  None Found
# 14  \nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred
# 15  None Found
# 16  None Found
# 17  \nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred
# 18  \nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred
# 19  Required:\n\nMaster’s degree in statistics, manufacturing/industrial engineering, operations research, computer science, or a related field\nMinimum of 2+ years with a PhD or 5 years with a MS of relevant industry experience in measuring and improving complex processes\nProficient in a statistical programming (R, Python, STATA, etc..)\nExcellent written and spoken English\nPreferred\nUnderstanding of implementing statistical monitoring at scale / server based\nSpecific experience in Application Web Services (AWS)\nExperience in healthcare\nPeer reviewed publications demonstrating scientific leadership
# 20  \nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred
# 21  Required:\n\nMaster’s degree in statistics, manufacturing/industrial engineering, operations research, computer science, or a related field\nMinimum of 5+ years with a PhD or 7 years with a MS of relevant industry experience in measuring and improving complex processes\nProficient in a statistical programming (R, Python, STATA, etc..)\nExcellent written and spoken English\nPreferred\nUnderstanding of implementing statistical monitoring at scale / server based\nSpecific experience in Application Web Services (AWS)\nExperience in healthcare\nPeer reviewed publications demonstrating scientific leadership
# 22  Conducting studies requiring analysis of statistical data for program requirements; ANDUtilizing various software and computer platforms to prepare analytical data files, perform statistical data analyses and report findings.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Skills  \
# 0   Master’s degree or Ph.D. in statistics,Biostatistics, mathematics, or related field;\n8+ years of prior experience in a CMC drug-development environment;\nExperience or training with a wide-range of skills including JMP/ SAS programming and other relevant statistical software such as Minitab and / or R, statistical methodology and theories, and analysis;\nExcellent computer skills in the following programs: MS Word, PowerPoint, and Excel;\nExperience writing technical documents, reports, and presentations;\nAbility to manage multiple and diverse issues;\nKey Competencies:\nProfessionalism and customer service orientation\nCommunication skills - written and verbal\nPlanning, organizing and multi-tasking\nPrioritizing and time management\nProblem assessment and problem solving\nInformation gathering and information monitoring\nAttention to detail and accuracy\nFlexibility, adaptability and teamwork
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  None Found
# 17  None Found
# 18  None Found
# 19  None Found
# 20  None Found
# 21  None Found
# 22  None Found
#
# ...
# 20  COACH POSITION: Boy's Dive Team - Assistant Coach (Winter Season, starting November 18th)\n\nSalary: Per the negotiated agreement\n\nGeneral Functions:\nSupports the High School in all of its athletic programs and demonstrates commitment to strengthen relations withthe educational system as well as the coaching profession.\nDemonstrates loyalty and support the head coach in conducting the athletic program of that particular sport.\nKnowledgeable and aware of rules and regulations concerning his/her sport.\nAssumes any duties assigned to him/her by the head coach pertaining to the overall athletic program of that particular sport and assumes responsibilities of the head coach in the absence of the head coach.\nAssists and be accountable to the head coach, athletic director, and principal.\nAccompanies and directs the assigned team to all games and practices.\nHolds a current first aid and CPR card.\nKeeps current on all clock hours depending on coaching level.\nExemplifies good sportsmanship and is held to the same sportsmanship expectations as the head coach.\nEssential Functions\nInstructs students in the fundamentals of the sport s/he is coaching.\nMaintains facilities and equipment.\nSupervises team players at practice, contests, in locker room and during travel.\nPromotes sportsmanship and fair play among all teams and players by always setting a good example for participants and fans to follow, exemplifies the highest moral and ethical behavior; instructs participants in proper sportsmanship responsibilities and demands they make sportsmanship a high priority; respects judgment of contest officials, abides by rules of the event and displays no behavior that could incite fans; treats opposing coaches, participants, fans and media members with respect; develops and enforces penalties for participants who do not abide by sportsmanship standards; and develops a method to publicly recognize good sportsmanship.\nReports contest results to League Statistician as directed.\nMinimum Qualifications\nHigh school diploma or equivalent\nHold a current and valid First Aid and CPR card\nMust be at least 21 years of age\nPrior coaching experience preferred\n\nIf you need help with the online process please call (206) 236-3318 or use the District Job Kiosk in the District Administration Building located at 4160 86th Ave SE, Mercer Island.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 21  CSATS is recruiting for a Senior Manager, Data Science and Statistician located in Seattle, WA.\n\nJohnson and Johnson Medical Device Companies\nThe Johnson & Johnson Medical Devices Companies have been working to make surgery better for more than a century. With substantial breadth and depth in surgical technologies, orthopedic and interventional solutions, we aspire to improve and enhance medical care for people worldwide. Together, we are working to shape the future of health through differentiated products and services.\nCSATS is hiring a Senior Manager, Data Science and Statistician to work on measuring healthcare surgical outcome variability and the development and implementation of real-time monitoring focusing on surgeon and hospital clinical and economic improvement, learning curve, and outlier detection. Complex data sets include surgeon performance metrics extracted from operative video (e.g. operative time, task completion time, general performance metrics) along with hospital Electronic Health Records and big data Real-World Data (such as Medicare, private insurance claims, aggregate hospital billing data, and registry data) and ergonomic and clinical studies. Projects will include measuring the impact of surgeon improvement and healthcare improvement interventions including simulation, practice labs, and decision support solutions. In addition, he/she will evaluate the impact of the introduction of new technology such as decision support, medical devices, and new surgical approaches.\nThe candidate will be responsible for applying modern statistical techniques including statistics (Bayesian and frequentist), signal detection, novel visualization, and machine learning as applied to process measurement to create scalable implementation that can be interpreted by various levels of statistical experience. Responsibilities include:\nUse a combination of state of the art statistical and other modern analytical techniques to create and implement a real-time measurement system for surgeon / hospital performance for both internal and external presentation\nTranslate point in time ‘causal inference’ outcomes research studies into real-time monitoring\nIdentify and connect new data sources to develop an improving learning measurement system\nMeasure the effect of training, educational content, and other quality improvement healthcare solutions\nImplement an internal quality control system\nDevelop predictive models for forecasting, clinical and economic outcomes, and performance improvement\nCollaborate with statisticians, surgeons, researchers, machine learning experts, and engineering to research and develop new statistical methods focusing on learning curve and measuring surgeon/hospital improvement\n\nQualifications\nRequired:\n\nMaster’s degree in statistics, manufacturing/industrial engineering, operations research, computer science, or a related field\nMinimum of 5+ years with a PhD or 7 years with a MS of relevant industry experience in measuring and improving complex processes\nProficient in a statistical programming (R, Python, STATA, etc..)\nExcellent written and spoken English\nPreferred\nUnderstanding of implementing statistical monitoring at scale / server based\nSpecific experience in Application Web Services (AWS)\nExperience in healthcare\nPeer reviewed publications demonstrating scientific leadership\nJohnson & Johnson is an Affirmative Action and Equal Opportunity Employer. All qualified applicants will receive consideration for employment without regard to race, color, religion, sex, sexual orientation, gender identity, age, national origin, or protected veteran status and will not be discriminated against on the basis of disability\n\nPrimary Location\nUnited States-Washington-Seattle-\nOrganization\nCSATS Inc.(6261).\nJob Function\nBiostatistics\nRequisition ID\n4695191004                                                                                                                                 ...
# 22  Duties\nSummary\nOIG is organized into three line elements: the Offices of Investigations, Audits and Evaluations, and Healthcare Inspections; along with the Office of Contract Review, the Office of Management and Administration and the Office of Special Review. In addition to the Washington, DC, headquarters, OIG has offices located in more than 30 cities throughout the country.\n\nResponsibilities\nThis position is 100% telework and can be filled in any city; the selected candidate will be expected to work remotely. Some travel will be expected.\n\nThe Statistician located in the Office of Inspector General (OIG) is responsible for provides statistical leadership to OIG staff on projects and initiatives that requires statistical expertise, as well as assisting on study design, data collection, and statistical data analysis and interpretation.\n\nThe following are the duties of this position at the GS-14. If you are selected at a lower grade level, you will have the opportunity to learn to perform all these duties, and will receive training to help you grow in this position.\nServe as the OIG’s authoritative source in statistical areas with respect to all phases of study design, data analysis, and statistical interpretation of the results relating to projects under consideration.Lead the application of analytic techniques and defines study objectives and strategic direction where no clear precedence exists.Apply standard statistical and/or data management software package(s) to execute data processing, data modeling, and technically complicated data analysis with minimal or no supervision.Work in conjunction with the Director to ensure that statistical studies and priorities are in line with organizational objectives.Maintain control of full study design including assisting OIG staff in developing the generally stated project objectives into clearly defined specific study questions, study populations and/or samples and appropriately defined outcome measures; developing strategies to data collection, overseeing data collection, and statistical data analysis plan.\nTravel Required\n25% or less - 1-5 Nights per month. Travel nationwide under tight deadlines. The incumbent should anticipate frequent walking and standing as a component of this travel.\nSupervisory status\nNo\nPromotion Potential\n14\nJob family (Series)\n1530 Statistics\nSimilar jobs\nStatisticians\nRequirements\n\nRequirements\nConditions of Employment\nPlease refer to "Conditions of Employment."\nClick "Print Preview" to review the entire announcement before applying.\nThe experience may have been gained in either the public, private sector or volunteer service. One year of experience refers to full-time work; part-time work is considered on a prorated basis. To ensure full credit for your work experience, please indicate dates of employment by month/day/year, and indicate number of hours worked per week on your résumé.\nQualifications\nYou must meet the following requirements by the closing date of this announcement.\n\nSpecialized experience: For the GS-13, you must have one year of specialized experience at a level of difficulty and responsibility equivalent to the GS-12 grade level in the Federal Service. Specialized experience for this position includes:\nConducting studies requiring analysis of statistical data for program requirements; ANDUtilizing various software and computer platforms to prepare analytical data files, perform statistical data analyses and report findings.\nEducation\nA. Degree: that included 15 semester hours in statistics (or in mathematics and statistics, provided at least 6 semester hours were in statistics), and 9 additional semester hours in one or more of the following: physical or biological sciences, medicine, education, or engineering; or in the social sciences including demography, history, economics, social welfare, geography, international relations, social or cultural anthropology, health sociology, political science,  ...

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Statistician_Seattle.csv')
