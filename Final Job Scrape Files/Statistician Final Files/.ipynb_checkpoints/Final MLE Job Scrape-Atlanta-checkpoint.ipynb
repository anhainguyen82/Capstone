# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Statistician%22&l=Atlanta%2C+GA&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 358

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 358

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 19

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                               Title  \
# 0   Consulting Statistician, Manager – US Research & Insights, Deloitte Services LP
# 1   Statistician (Health)
# 2   Senior Loyalty Statistician (Data Analytics)
# 3   Epidemiologist/Statistical Programmer
# 4   Biostatistician
# 5   Fellowship in Lower Anogenital Screening & Treatment
# 6   Statistician (Health) (Direct Hire)
# 7   GIS Public Health Analyst I
# 8   Senior Data Scientist
# 9   Senior Statistician
# 10  Statistician (Data Scientist), GS-1530-13, Census-MP-TST
# 11  Health Statistician
# 12  Senior Director, Analytics – Global Identity and Fraud
# 13  Infection Preventionist
# 14  Statistician (Health) (Direct Hire)
# 15  AI Model Development Lead For Marketing (Analytics Manager 5)
# 16  Senior Director, Bank Analytics
# 17  Statistician
# 18  AI Model Development Lead for Virtual Channels (Analytic Manager 5)
#
#              Location     City State         Zip     Country  \
# 0   Atlanta, GA 30303  Atlanta  GA    30303       None Found
# 1   Atlanta, GA 30305  Atlanta  GA    30305       None Found
# 2   Atlanta, GA 30346  Atlanta  GA    30346       None Found
# 3   Atlanta, GA 30330  Atlanta  GA    30330       None Found
# 4   Atlanta, GA        Atlanta  GA    None Found  None Found
# 5   Atlanta, GA        Atlanta  GA    None Found  None Found
# 6   Atlanta, GA 30305  Atlanta  GA    30305       None Found
# 7   Atlanta, GA 30330  Atlanta  GA    30330       None Found
# 8   Atlanta, GA 30309  Atlanta  GA    30309       None Found
# 9   Atlanta, GA        Atlanta  GA    None Found  None Found
# 10  Atlanta, GA 30308  Atlanta  GA    30308       None Found
# 11  Atlanta, GA 30303  Atlanta  GA    30303       None Found
# 12  Atlanta, GA 30309  Atlanta  GA    30309       None Found
# 13  Atlanta, GA 30330  Atlanta  GA    30330       None Found
# 14  Atlanta, GA 30305  Atlanta  GA    30305       None Found
# 15  Atlanta, GA        Atlanta  GA    None Found  None Found
# 16  Atlanta, GA 30307  Atlanta  GA    30307       None Found
# 17  Atlanta, GA 30318  Atlanta  GA    30318       None Found
# 18  Atlanta, GA        Atlanta  GA    None Found  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Qualifications  \
# 0   PhD in statistics or one of the quantitative social sciences\n5+ years of experience doing hands-on, statistics-intensive work\nSolid experience working in a consulting statistician capacity: ideating with clients, manifesting good communication skills, balancing multiple projects\nBroad, solid knowledge of statistics with depth in one or more areas such as survey design/analysis, econometrics, or causal inference\nFlair for Exploratory Data Analysis\nKnowledge of core machine learning methods\nAbility and eagerness to keep abreast of data-intensive developments in such fields as text analysis, social network analysis, Computational Social Science\n\nTo apply\nApply with a letter explaining why you are interested in this role and expanding upon your qualifications. Please include a full CV and two writing samples, ideally sole- or first-authored. One sample should be shorter (i.e., <1000 words) and one longer (i.e., >2000 words).
# 1   None Found
# 2   None Found
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  \nVRA (GS-11 or below)\nVEOA (permanent positions)\n30% or more disabled\nPersons with Disabilities\nCTAP\nICTAP\n
# 11  None Found
# 12  None Found
# 13  BA/BS/BSN degree. Degree should be in a health related disciplineRequires a minimum of 10 years of related experience, of which approximately five (5) years must be specialized in the area of Infection Prevention and Control.US Citizen or US Person (Green Card Holder) with the ability to obtain a NACI clearanceInfection Control Certification is highly desirable.
# 14  None Found
# 15  \n8+ years of experience in analytics, modeling, or a combination of both\n6+ years of management experience; or 6+ years of leadership experience in an advanced quantitative analytics function\nA Master's degree or higher\n5 + years of experience using quantitative machine learning techniques\n4+ years of experience working with digital data science including analyzing cookie-level data
# 16  None Found
# 17  None Found
# 18  \n8+ years of experience in analytics, modeling, or a combination of both\n6+ years of management experience; or 6+ years of leadership experience in an advanced quantitative analytics function\nA Master's degree or higher\n5 + years of experience using quantitative machine learning techniques
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Skills  \
# 0   None Found
# 1   None Found
# 2   \nDemonstrated programming experience with statistical and database software (SQL and Tableau required, SAS preferred). Exposure to Alteryx, R or Python a plus.\nDemonstrated strategic agility and problem solving abilities using a hypothesis led approach.\nExperience conducting complex analysis by aggregating large data sets from multiple sources to deliver insights on business/program performance and/or opportunities\nExperience developing dynamic models or dashboards in Tableau and MS Excel\nExperience conducting quantitative analyses including some or all of the following: market segmentation, product positioning, product pricing, concept testing or market sizing.\nStrong communication skills, both oral and written, and proficiency with MS Word and PowerPoint for the purpose of translating technical and statistical information into actionable business insights for senior management.\nFamiliarity with financial concepts preferred: ROI, NPV, pro forma modeling.\nDemonstrated critical thinking abilities and curiosity to find the underlying causes/drivers of performance\nSelf-motived with ability to manage multiple projects and priorities
# 3   None Found
# 4   None Found
# 5   None Found
# 6   None Found
# 7   None Found
# 8   None Found
# 9   None Found
# 10  None Found
# 11  None Found
# 12  None Found
# 13  None Found
# 14  None Found
# 15  None Found
# 16  None Found
# 17  None Found
# 18  None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Responsibilities  \
# ...
# 16  The big picture\n\nCardlytics makes marketing more relevant and measurable through our Purchase Intelligence™ platform. Partnering with financial institutions (FIs) to run their banking rewards programs, Cardlytics has a secure view into where and when consumers are spending their money. By applying advanced analytics to this massive aggregation of purchase data, we make it actionable, helping marketers/ advertisers identify, reach and influence likely buyers at scale, and measure the true sales impact of their marketing spend.\n\nAbout the role\n\nAs the leader of our Bank Analytics and Program Strategy team, you will be guiding strategies to leveraging data to help provide actionable insights around consumer engagement and card usage. You'll be knee deep in data at times, and other times you'll be crafting the story and presenting your findings to executives within Cardlytics and at our bank partners.\n\n\nPlay a key leadership role at Cardlytics as we continue to evolve our relationships with our bank partners and grow our advertising platform\nBuild and lead a team of managers and analysts, serving as a coach, mentor and subject matter expert for your group\nWork on problems impacting some of the largest banks in the U.S. often presenting complex custom projects to executive audiences\nLead our Program Strategy function to learn and act on the key trends and drivers of our advertising platform performance\nWork with internal teams to develop new product strategies and analytic methodologies\nMine purchase data to understand consumer spending habits, competitive landscapes, and customer journeys\n\nWhat you will accomplish\n\n\nYou and your team will work with Cardlytics Bank Account Managers and our bank partners to:\nUnderstand what various changes to user experience will do to engagement and company economics\nTeach the company about what drives engagement on the Cardlytics Network\nProvide relevant data points to inform stakeholders of what is happening at our banks\nInform future bank marketing campaigns\nWork across disparate teams throughout the organization to grow our Program Strategy function:\nDevelop strategies for new products and analytic methodologies\nBuild the organization's understanding of drivers of consumer engagement and network performance across all bank partners through rigorous testing and experimental design\nLead analytic efforts to ensure we deliver a personalized experience to bank consumers – the right offer to the right person at the right time\nDevelop and standardize new analytic approaches and tools for use by the broader organization team\nCraft engaging analytic stories using PowerPoint and Tableau that answer client specific business questions\nPresent to executive leaders at major financial institutions\nPrioritize workload across multiple initiatives and distribute to your team based on skillset and availability\nManage and develop members of the analytics team to augment their technical skills and refine their client facing soft skills\nFind opportunities for streamlining and automation of existing processes\n10% travel for client meetings\n\nSkills and experiences that will make you successful\n\n\nSkills\nStrong ability to interpret complex analytical results and transform into a client ready deliverable\nProven ability to lead and influence strategic and tactical business decisions based on statistical and quantitative analysis\nKnowledge of advanced statistical modeling, testing design and data mining techniques\nAdvanced Excel and PowerPoint skills required\nProficient in SQL and R\nAbility to present to a non-technical marketer or a statistician\nStrong team and project/workstream management skills\nAbility to juggle multiple projects & clients at a time\nStrong critical thinking ability and proactive problem-solving capabilities\nOutstanding communication, presentation and interpersonal skills\nPatient and adaptable\nEntrepreneurial and team-oriented spirit\n\nExperience\n ...
# 17  Job Duties: Responsible for the collation, evaluation, interpretation, and presentation of quality data. Provides insight and recommendations for improvement.\nLeads and conducts analytics projects to support various quality and process improvement initiatives involving data collection and statistical analysis, data visualization, as well as preparing and updating score cards, benchmarking, and progress reports. Develops decision supporting tools, including MIS, Tableau and Epic dashboards, balanced scorecards and drill-down/roll-up type reporting.\nProvides analytical and statistical expertise to Quality Department by creating and demonstrating templates and other statistical tools. Assists team members with their data analysis and shares knowledge and expertise. Trains and mentors more junior members of the team in process improvement, data analysis, and statistical\nmethods. Researches statistical modeling & analytical tools and how it can be applied to healthcare to drive improvement within the organization.\n\nRequirements\nEducation and Experience: Bachelor’s degree in Industrial Engineering, Health Systems Engineering, Statistics or Operations Research, plus two years of experience in data analytics and statistics.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 18  Overview:\nWells Fargo technology teams drive innovation to create a more powerful and fulfilling financial experience for our customers and team members. You will join more than 24,000 team members supporting 95 billion transactions annually in 10 countries. Our career opportunities span the technology spectrum: advanced analytics, big data, information security, application development, cloud enablement, project management and more.\n\nSUCCESS PROFILE\nCheck out the top traits we're looking for and see if you have the right mix. Additional related traits listed below.\n\nAnalytical\nDetail-oriented\nInsightful\nInventive\nProblem Solver\nCurious\nBenefits\nWells Fargo wants to help you get more out of life and take care of things outside the office to make life a little easier. We provide:\n\nMedical, Dental and Vision\nEmployer Matching 401(k)\nTuition Reimbursment\nMaternity and Paternity Leave\nPaid Time Off\nResponsibilties\nJob Description\nAt Wells Fargo, we want to satisfy our customers’ financial needs and help them succeed financially. We’re looking for talented people who will put our customers at the center of everything we do. Join our diverse and inclusive team where you’ll feel valued and inspired to contribute your unique skills and experience.\nHelp us build a better Wells Fargo. It all begins with outstanding talent. It all begins with you.\nEnterprise Finance drives financial management for the company and maintains and enhances risk and financial controls. Key functions within Enterprise Finance include finance and accounting; Treasury; corporate development, mergers, and acquisitions; Data Management and Insights, the Customer Remediation Center of Excellence, Enterprise Shared Services, Business Process Management, and Corporate Strategy. Enterprise Finance informs shareholders, regulators, taxing authorities, team members, and leaders of the company’s financial performance through earnings releases, investor meetings and conferences, and meetings with regulators and credit rating agencies, following appropriate reporting guidelines. They also maintain and enhance risk and financial controls and lead many of the company’s shared services functions including corporate properties, security, and global services.\nAs part of the newly formed AI Model Development COE in Enterprise Analytics and Data Science (EADS), which focuses on building, implementing, and monitoring AI models for the enterprise, the AI model development team for personalization, Virtual Channels, and virtual channels is looking for an experienced AI leader to manage the development of AI models for Virtual Channels.\n\nThis leader will be responsible for building and managing a team of data scientists to design, develop, and implement AI models focused on Virtual Channels’ AI priorities. Partnering with Wells Fargo AI technology team, Wells Fargo AI business solution team, and Virtual Channels executives, you and your team will deliver and deploy AI models on the Well Fargo AI open source platform to scale these solutions and embed them in our operational processes.\n\nKEY RESPONSIBILITIES INCLUDE:\nBuild and grow a team of data scientists responsible for AI model development in support of Virtual Channels\nDesign, develop, and deploy AI models using state of the art AI techniques available in the open stack and/or vendor solutions\nPartner with Virtual Channels executives to frame the problem, manage the model development process, and business relationship\nManage a portfolio of the data science projects including the following responsibilities:\nHelp finalize project scope working with business partners\nOn-going touch-base with business partners and governance stakeholders\nDefine priorities in partnership with the business partners during on-going development\nWork with AI technology and production teams to operationalize models\nWill be called upon to review vendor models and solutions and/or models developed outside of EADS\nDiv ...

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Statistician_Atlanta.csv')
