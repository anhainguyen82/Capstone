# %%
from bs4 import BeautifulSoup
import urllib
from urllib.request import urlopen
import re
import pandas as pd
import requests
from requests import get
import re

# %% [markdown]
# # Pulling all links off of the search pages (up to 3000) and putting them in a dataframe to scrape.

# %%
url_template="http://www.indeed.com/jobs?q=%22Database+Administrator%22&l=Houston%2C+TX&start={}"
max_results=250
Linkdf=[]

for start in range(0, max_results, 7):
    url=url_template.format(start)
    html=requests.get(url)
    soup=BeautifulSoup(html.content,'html.parser', from_encoding="utf-8")
    
    #for each in soup.find_all(a_="href"):
    page_links=soup.find_all('a',{'href':re.compile("/rc/")})
    for items in page_links:
        Linkdf.append(items['href'])

# %%
#Sanity Check
len(Linkdf)
#print(Linkdf)
# Out:
# 284

# %%
#This code allows the code to display the full website instead of truncating
pd.set_option('display.max_colwidth',-1)

#Moving it to a data frame
data = {'links':Linkdf}
df = pd.DataFrame(data, columns=['links'])

#append indeed.com to the front of each
df['Web'] = 'https://www.indeed.com'
df['URL'] = df.Web.str.cat(df.links)

#pull out just a list of the websites.
websites=list(df['URL'])

#Sanity Check
#print(websites)
len(websites)
# Out:
# 284

# %%
websites1=set(websites)

# %%
len(websites1)
# Out:
# 32

# %% [markdown]
# # Looping through websites....

# %%
Title=[]
Descriptions=[]
Location=[]
FullDescriptions=[]

for url in websites1:
    response=get(url)
    soup=BeautifulSoup(response.text,'html.parser')
    
    description_containers= soup.find(class_='jobsearch-jobDescriptionText')
    title_containers=soup.find('h3')
    try:
        location_containers=soup.find('',{'class':'jobsearch-CompanyInfoWithoutHeaderImage'}).find_all('div')[-1]
    except:
        location_containers='None Found'
    
    job_descriptions=str(description_containers)
    job_title=str(title_containers.text)
    try:
        locations=str(location_containers.text)
    except AttributeError:
        locations = 'None Found'
    try:
        full_descriptions = str(description_containers.text)
    except AttributeError:
        full_descriptions= 'None Found'
    
    Descriptions.append(job_descriptions)
    Title.append(job_title)
    Location.append(locations)
    FullDescriptions.append(full_descriptions)

# %% [markdown]
# # Extracting what we want from the Descriptions Column

# %%
#'Location' left in for sanity check. Should be removed once code is confirmed to work
Descriptions_df = pd.DataFrame(columns = ['Title', 'Location','City', 'State', 'Zip', 'Country', 'Qualifications', 'Skills', 'Responsibilities', 'Education', 'Requirement', 'FullDescriptions'])
Country = ['US', 'USA', 'United States', 'United States of Americal']
States = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA',
          'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND',
          'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

for index, element in enumerate(Descriptions):
    soup=BeautifulSoup(element,'lxml')
    for values in list(Descriptions_df):
        temp_tag = soup.find('b', text=re.compile(values))
        try:
            ul_tag = temp_tag.find_next('ul')
            Descriptions_df.at[index,values] = ul_tag.text
        except AttributeError:
            Descriptions_df.at[index,values]="None Found"
        Descriptions_df.at[index,"Title"]=Title[index]
        Descriptions_df.at[index,"Location"]=Location[index]
        Descriptions_df.at[index,"FullDescriptions"]=FullDescriptions[index]
        words = '|'.join(Country)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Country"] = temp[0]
        words = '|'.join(States)
        temp = re.findall(words, Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"State"] = temp[0]
        temp = re.findall(r'\d+', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"Zip"] = temp[0]  
            
        temp = re.findall(r'[\w w]+,', Location[index])
        if len(temp) != 0:
            Descriptions_df.at[index,"City"] = re.sub(',', '', temp[0])

# %%
Descriptions_df
# Out:
#                                                                          Title  \
# 0   EPIC Resolute Hospital Billing Clinical Application Support Analyst IV
# 1   Pulse Fee Billing Database Administrator
# 2   Fund Accounting Manager
# 3   Sales Operations Administrator
# 4   Senior Specialist - SQL DBA
# 5   Principal Database Administrator - IT
# 6   Systems Administrator II
# 7   Data Manager/Project Coordinator III
# 8   Secretary - Executive Director of Assessment and Evaluation
# 9   Database Administrator
# 10  Technical Lab Coordinator
# 11  Senior Analyst Programmer II
# 12  Database Administrator – Informatica
# 13  EPIC Resolute Professional Billing Clinical Application Support Analyst IV
# 14  NoSQL Database Administrator
# 15  Admissions Representative
# 16  Operations Coordinator
# 17  Senior Database Administrator
# 18  Operational Support Administrator
# 19  Database Administrator
# 20  Fund Accounting Assistant Manager
# 21  Database Administrator
# 22  ETL/Data Developer (Microsoft BI Stack Experience only)
# 23  SAP Security-A Roles Database Administrator
# 24  Junior Database Administrator
# 25  Principal Database Administrator - Information Technology
# 26  IT Network Manager
# 27  Sr. Subcontracts Administrator
# 28  SENIOR ADMINISTRATIVE ASSISTANT
# 29  HR Operations Manager (m/w/d)
# 30  SQL Server DBA
# 31  Lunar Gateway Space Vehicle Data Software Developer
#
#              Location         City State         Zip     Country  \
# 0   Houston, TX        Houston      TX    None Found  None Found
# 1   Houston, TX        Houston      TX    None Found  None Found
# 2   Houston, TX 77046  Houston      TX    77046       None Found
# 3   Houston, TX        Houston      TX    None Found  None Found
# 4   Houston, TX        Houston      TX    None Found  None Found
# 5   Houston, TX 77002  Houston      TX    77002       None Found
# 6   Houston, TX 77036  Houston      TX    77036       None Found
# 7   Houston, TX        Houston      TX    None Found  None Found
# 8   League City, TX    League City  TX    None Found  None Found
# 9   Houston, TX        Houston      TX    None Found  None Found
# 10  Baytown, TX 77520  Baytown      TX    77520       None Found
# 11  League City, TX    League City  TX    None Found  None Found
# 12  Houston, TX        Houston      TX    None Found  None Found
# 13  Houston, TX        Houston      TX    None Found  None Found
# 14  Houston, TX        Houston      TX    None Found  None Found
# 15  Houston, TX 77024  Houston      TX    77024       None Found
# 16  Houston, TX        Houston      TX    None Found  None Found
# 17  Houston, TX 77089  Houston      TX    77089       None Found
# 18  Houston, TX        Houston      TX    None Found  None Found
# 19  Webster, TX        Webster      TX    None Found  None Found
# 20  Houston, TX 77046  Houston      TX    77046       None Found
# 21  Houston, TX 77008  Houston      TX    77008       None Found
# 22  Houston, TX        Houston      TX    None Found  None Found
# 23  Houston, TX        Houston      TX    None Found  None Found
# 24  Houston, TX        Houston      TX    None Found  None Found
# 25  Houston, TX 77002  Houston      TX    77002       None Found
# 26  Houston, TX        Houston      TX    None Found  None Found
# 27  Houston, TX 77027  Houston      TX    77027       None Found
# 28  Houston, TX        Houston      TX    None Found  None Found
# 29  Houston, TX        Houston      TX    None Found  None Found
# 30  Houston, TX 77001  Houston      TX    77001       None Found
# 31  Houston, TX 77058  Houston      TX    77058       None Found
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Qualifications  \
# 0   None Found
# 1   None Found
# 2   None Found
# 3   None Found
# 4   \nAbility to function well in a fast-paced, dynamic environment with competing priorities.\nAbility to build strong working relationships across the organization.\nEager to learn and apply knowledge.\nStrong communications, both written and verbal, in leading teams and coordinating with peers and other disciplines on driving projects/issues to closure.\nAbility to monitor and troubleshoot database performance.\nAbility to modify database structures.\nAbility to develop backup and recovery procedures.\nAbility to coordinate allocation of storage and forecast storage usage.\nAbility to perform software upgrades and patching.\nHave experience with high availability and disaster recovery techniques.\nHave working knowledge of one or more current programming languages.
# 5   None Found
# 6   Programing languages such as Python or similar language for upkeep of current scripts and creation of new
# 7   None Found
# 8   \nOrganize and manage routine work activities in the office of assessment, accountability, and program evaluation.\nPerform office routines and practices associated with a productive office; exercise good telephone etiquette, take reliable messages, and route to appropriate staff.\nDesign and maintain manual and computerized correspondence and filing systems for all areas of responsibility.\nPrepare and disseminate ad hoc and required reports, public and confidential, as required and requested.\nProvide support to the Executive Director through database and spreadsheet development.\nAssist with the ordering of materials to conduct the district testing program.\nMaintain and monitor all budgets, prepare and process all purchase orders, inventory and order all necessary supplies for the office.\nWork with purchasing division on any bid specifications and requests.\nWork cooperatively with co-workers and supervisors to ensure that the goals of the school/department are met.\nAssist in the preparation of presentations to the Board of Trustees as part of the district’s program evaluation system.\nAssist the executive director in monitoring key performance measures of the district’s accountability system.\nStay informed of and comply with all federal, state, and district policies and regulations concerning areas of responsibility.\nAssist campus and program staff with questions regarding testing, planning, evaluation, and accountability.\nRespond to requests for information from administrators, campus staff, and the public as appropriate.\nAssist with planning, preparation, and implementation of district training sessions.\nPrepare and update TAKS, TAAS, SDAA, RPTE, TELPAS, End of course, achievement testing, C testing, planning, program evaluation and accountability forms and documents.\nAssist in the preparation, documentation, receipt, distribution, and return of all TAKS, TAAS, SDAA, RPTE, TELPAS, End of Course, Credit by Exam, and any other achievement testing materials.\nAssist with scheduling staff for summer statewide assessment administration.\nAssist with scheduling students and staff for Credit by Examination for Acceleration testing.\nAssist with switchboard relief.\nExhibit CCISD Core Values of trustworthiness, respect, responsibility, fairness, caring, and citizenship.\nStay up-to-date professionally through the selection of quality professional learning opportunities for personal growth.\nResearch district policy, precedent, and current practices prior to taking action.\nParticipate as an effective team member who contributes to district, department, and content goals.\nDemonstrates proficient levels of technology applications.\nParticipates fully in drills and safety exercises to provide for the safety and overall emotional wellbeing of students.\nUtilize time wisely for effective management of job responsibilities.\nMaintain punctuality in daily work times, appointments, and meetings.\nMeet task completion deadlines established by supervisor.\nMaintain friendly customer-service-driven interactions with all stakeholders, students, teachers, administrators, and co-workers.\nWork cooperatively with co-workers and supervisors to ensure that the goals of the school/department are met.\nMaintain a positive and professional tone in all communication (i.e. email, written, and verbal).\nPerform other duties and accept other responsibilities as assigned.\n
# 9   None Found
# 10  None Found
# ...
# 29  Founded in 1947, Marquard & Bahls has grown into one of the leading independent companies in supply, trading and logistics of energy & chemicals. The core operating units include tank storage logistics, trading and aviation fuelling.\n\nThrough its subsidiaries, Marquard & Bahls has a presence in 36 countries in Europe, America, Asia and Africa and employs about 7,500 people.\n\nWe are looking for a\n\nHR Operations Manager (m/w/d)\n\nPayroll\nExecute all aspects of the payroll function in the preparation and processing of the bank’s semi-monthly and monthly payroll, including maintenance changes, scheduled deductions, wage garnishments, and tax reporting.\nManage W-2 controls (reconciliation) and distribution, and auditing of the of the payroll process.\nAudit payroll process to ensure accuracy of the payroll process, compile data from a wide variety of sources (e.g. time sheets/payroll, salary adjustments, tax deposits, etc.) for the purpose of analyzing issues, make recommendations regarding policies and procedures and ensure compliance with mandated requirements.\nPrepare and oversee the preparation of a variety of payroll-related documents (e.g. payment adjustments, retirement plan transfers, stop payments) and research discrepancies of payroll information (e.g. time sheets, leave accruals, overpayments, underpayments, etc.) for the purpose of documenting activities and issues; meeting compliance requirements, and providing audit references.\nPrepare monthly report reconciling payroll entries and general ledger entries.\nMaintain relationships with internal and external auditors and state and federal agencies and ensures compliance with established financial, legal and/or administrative requirements.\nEnsure compliance with federal and state laws, regulations and company policies/procedures; stays abreast of changes and new developments by researching and interpreting regulatory requirements including FLSA, Wage & Hour and Texas Payday Law; resolves wage/hour issues for payroll processing.\nWork closely with internal audit and outside auditors regarding completion of payroll audit and other HR audits.\nEvaluate and modifies the company’s payroll policies to make sure that all programs are competitive and in compliance with legal requirements.\nPrepare and distribute written and verbal communication to inform management and employees of payroll and or any other policies.\nCompensation / reward\nWork with the Regional HR Director to develop rewards strategy\nManage compensation (i.e. develop compensation structure, assist with budgeting process, provide comp updates, salary surveys, assist with developing & managing bonus programs).\nDevelop and manage bonus and salary review processes\nHRIS\nResponsible for the management of HRIS.\nOversees and maintains data integrity of the HRIS and all modules are properly integrated.\nManage and design the mapping of all HRIS tables to ensure accurate data capture that promotes prudent compliance and enables comprehensive reporting.\nProcesses corporate group changes (division, location, class, home department, and pay group) to ensure that corporate structure is accurately reflected in the system for proper pay and benefits assignments.\nResponsible for benefits management in HRIS including, but not limited to benefits plan setup, creation and maintenance of provider information, and coding updates for premium payments.\nResponsible for managing the payroll/ time and attendance module in HRIS, including set up, maintenance of employees, manager security groups, company and system options.\nServe as the workforce portal administrator, including maintenance and administration of manager self-service, and employee self-service. Includes set up and maintenance of users, assigning employee access rights and security access management.\nIdentifies training needs of end users and develops and provides necessary training to meet those needs.\nServe as subject matter expert for HRIS, inclu ...
# 30  Cognizant is hiring for “SQL Server DBA” @ Houston, TX. We are looking for someone local and candidates who are interested in relocation can also apply.\n\nRequired Skills: SQL Server, SQL Instance/databases, Backup and Restore\n\nJob Description:\nShould have overall 10 years of experience.\nBuild New SQL instances as per the requirement\nMigration of SQL Databases using Backup and Restore method\nCheck Application feasibilities to migrate databases\nUpgrade of SQL Instance/databases\nDecommission of SQL Instance/databases\n\nSkill Sets:\nSQL Server DB Administration.\nDemonstrated capability to support MS SQL Server databases across multiple versions and in multiple location including in high availability scenarios.\nDemonstrated capability to deliver document deliverables\nDemonstrated ability to work with stakeholders and internal technology teams.\nCapability to deliver the engagement outcomes\n\nEmployee Status : Full Time Employee\nShift : Day Job\nTravel : No\nJob Posting : Sep 16 2019\n\nAbout Cognizant Cognizant (Nasdaq-100: CTSH) is one of the world's leading professional services companies, transforming clients' business, operating and technology models for the digital era. Our unique industry-based, consultative approach helps clients envision, build and run more innovative and efficient businesses. Headquartered in the U.S., Cognizant is ranked 193 on the Fortune 500 and is consistently listed among the most admired companies in the world. Learn how Cognizant helps clients lead with digital at www.cognizant.com or follow us @Cognizant.\nCognizant is recognized as a Military Friendly Employer and is a coalition member of the Veteran Jobs Mission. Our Cognizant Veterans Network assists Veterans in building and growing a career at Cognizant that allows them to leverage the leadership, loyalty, integrity, and commitment to excellence instilled in them through participation in military service.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# 31  Job Description\nCACI is looking for an experienced Lunar Gateway Space Vehicle Data Software Developer to provide NASA Johnson Space Center with software skills in the design and development of software to manage and configure the Lunar Gateway’s data-driven flight software infrastructure. The individual will work on the Lunar Gateway project, a human-tended space station in orbit around the moon. This work will involve prototyping, requirements definition, design, development, test and verification, integration and certification of data-driven tools to configure and manage the Lunar Gateway’s flight software.\nThis position requires a self-motivated, capable person with strong verbal and written communication skills. In addition to outstanding technical expertise, the individual must be very people savvy, have strong customer relationship skills, possess a positive team-player attitude, be flexible and willing to take on new assignments and responsibilities as they arise, and be an articulate speaker able to communicate complex technical ideas in a convincing manner. The individual must share our passion for our Nation's Space Program and share in the excitement of developing the next human-rated space vehicles.\nWhat You’ll Get to Do:\nDesign and develop back-end, middle-ware, and front-end web service based data toolchain software.\nDesign overall database schema and toolchain architecture.\nPerform systems engineering in support of software requirements and interface definitions, design, and performance analysis.\nPerform software integration, test, and verification.\nIntegrate and test software/hardware in avionics test bed and flight certification environments.\nCollaborate with engineering teams and contractors across multiple NASA programs and projects.\nEnsure adherence to JSC standard software process practices.\nThis work takes place at NASA/JSC in Houston, TX, a highly stimulating and dynamic environment that is critical in human space flight and the space exploration initiative.\n\nYou’ll Bring These Qualifications:\nMust be a U.S. Citizen or Permanent Resident for access to USG facilities.\nB.S. in Computer Science, Software Engineering, Aerospace Engineering, Electrical / Computer Engineering or related disciplines with strong software backgrounds.\nAt least four years of experience in developing software for data and web services including database back-end, middle-ware, and front-end enterprise software using Java, C#, XML, SQL, REST, and SOAP.\nExperience in database schema design and the implementation and creation of database tables.\nExperience in user interface design and implementation\nMust have significant experience in the entire software life cycle.\nMust be flexible, open to new challenges in a dynamic environment, and possess strong technical expertise combined with strong verbal and written communication skills.\nRequires the ability to manage multiple priorities with little supervision.\nMust be a highly responsible, team-oriented individual with strong work ethic.\nThese Qualifications Would be Nice to Have:\nM.S. in Computer Science, Software Engineering or related disciplines.\nExperience in human-rated space vehicle software.\nStrong Python development skills.\nStrong C++ development skills.\nLinux experience.\nDatabase Administrator (DBA) experience.\nFamiliarity with CMMI Level 3 (or above) process areas.\nExperience in the entire software life cycle.\nExperience with Time-Triggered Ethernet\nWhat We Can Offer You:\n\nWe’ve been named a Best Place to Work by the Washington Post.\nOur employees value the flexibility at CACI that allows them to balance quality work and their personal lives.\nWe offer competitive benefits and learning and development opportunities.\nWe are mission-oriented and ever vigilant in aligning our solutions with the nation’s highest priorities.\nFor over 55 years, the principles of CACI’s unique, character-based culture have been the driving force behind our succ ...

# %% [markdown]
# # Move to csv

# %%
Descriptions_df.to_csv('Descriptions_df_Database_Houston.csv')
